# %%
import tensorflow as tf
from tensorflow import keras

if tf.test.gpu_device_name()=='':
    print('You do not have GPU access.')
    # !nvidia-smi

else:
  print('You have GPU access')
  # !nvidia-smi

# from tensorflow.python.client import device_lib 
# device_lib.list_local_devices()

# print the tensorflow version
print('TensorFlow {}; Keras {}'.format(tf.__version__, keras.__version__))
tf.test.gpu_device_name()
# Out:
# You have GPU access
# Fri Feb 25 16:40:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 471.41       Driver Version: 471.41       CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro P5000       WDDM  | 00000000:91:00.0  On |                  Off |
# | 26%   34C    P8     8W / 180W |  16311MiB / 16384MiB |     11%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1388    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A      3924    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A      4068    C+G   ...nnector\DesktopClient.exe    N/A      |
# |    0   N/A  N/A      6028    C+G   C:\Windows\explorer.exe         N/A      |
# TensorFlow 2.6.0; Keras 2.6.0
# |    0   N/A  N/A      8008    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# '/device:GPU:0'
# |    0   N/A  N/A      8660    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A      9104    C+G   ...ekyb3d8bbwe\YourPhone.exe    N/A      |
# |    0   N/A  N/A      9356    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A     13092    C+G   ...zilla Firefox\firefox.exe    N/A      |
# |    0   N/A  N/A     18452    C+G   ...ffice\program\soffice.bin    N/A      |
# |    0   N/A  N/A     22240    C+G   ...bbwe\Microsoft.Photos.exe    N/A      |
# |    0   N/A  N/A     22608    C+G   ...zilla Firefox\firefox.exe    N/A      |
# |    0   N/A  N/A     28560    C+G   ...wekyb3d8bbwe\Video.UI.exe    N/A      |
# |    0   N/A  N/A     30420    C+G   ...Fiji.app\ImageJ-win64.exe    N/A      |
# |    0   N/A  N/A     55020      C   ...conda3\envs\tf\python.exe    N/A      |
# |    0   N/A  N/A     65036    C+G   ...p-2.9.6\GitHubDesktop.exe    N/A      |
# |    0   N/A  N/A     70488    C+G   ...kyb3d8bbwe\Calculator.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# This network is trained as v1, but the input data is not scrutinized for empty patches. Maybe this will suppress some signal from debris.

# %%
from tensorflow.keras import layers
import os
import tifffile as tiff
import numpy as np
from matplotlib import pyplot as plt
from patchify import patchify
from tensorflow import keras


def patch_image(img, SIZE=288):
    #breaks up image to SIZExSIZE non-overlapping patches, returns reshaped array
    # img.shape = (2304, 2304)
    patches = patchify(img, patch_size=(SIZE, SIZE), step=(SIZE, SIZE))
    #patches.shape = (8, 8, 288, 288)

    #return.shape = (64, 288 ,288)
    return patches.reshape(patches.shape[0]*patches.shape[1], SIZE, SIZE, 1)

def patch_stack(img, SIZE=288, DEPTH=3, STRIDE=1):
    # breaks up image to SIZExSIZE non-overlapping patches, returns reshaped array
    # img.shape = (12, 2304, 2304)
    patches = patchify(img, patch_size=(DEPTH, SIZE, SIZE), step=(STRIDE, SIZE, SIZE))
    # patches.shape = (10, 8, 8, 3, 288, 288)

    # return.shape = (64, 3, 288 ,288)
    return patches.reshape(patches.shape[0] * patches.shape[1] * patches.shape[2], -1,  SIZE, SIZE)


# Normalization functions from Martin Weigert
def normalizePercentile(x, pmin=1, pmax=99.8, axis=None, clip=False, eps=1e-20, dtype=np.float32):
    """This function is adapted from Martin Weigert"""
    """Percentile-based image normalization."""

    mi = np.percentile(x, pmin, axis=axis, keepdims=True)
    ma = np.percentile(x, pmax, axis=axis, keepdims=True)
    return normalize_mi_ma(x, mi, ma, clip=clip, eps=eps, dtype=dtype)


def normalize_mi_ma(x, mi, ma, clip=False, eps=1e-20, dtype=np.float32):  # dtype=np.float32
    """This function is adapted from Martin Weigert"""
    if dtype is not None:
        x = x.astype(dtype, copy=False)
        mi = dtype(mi) if np.isscalar(mi) else mi.astype(dtype, copy=False)
        ma = dtype(ma) if np.isscalar(ma) else ma.astype(dtype, copy=False)
        eps = dtype(eps)

    try:
        import numexpr
        x = numexpr.evaluate("(x - mi) / ( ma - mi + eps )")
    except ImportError:
        x = (x - mi) / (ma - mi + eps)

    if clip:
        x = np.clip(x, 0, 1)

    return x


# Simple normalization to min/max fir the Mask
def normalizeMinMax(x, dtype=np.float32):
    x = x.astype(dtype, copy=False)
    x = (x - np.amin(x)) / (np.amax(x) - np.amin(x))
    return x

# %%
def get_model_memory_usage(batch_size, model):
    import numpy as np
    try:
        from keras import backend as K
    except:
        from tensorflow.keras import backend as K

    shapes_mem_count = 0
    internal_model_mem_count = 0
    for l in model.layers:
        layer_type = l.__class__.__name__
        if layer_type == 'Model':
            internal_model_mem_count += get_model_memory_usage(batch_size, l)
        single_layer_mem = 1
        out_shape = l.output_shape
        if type(out_shape) is list:
            out_shape = out_shape[0]
        for s in out_shape:
            if s is None:
                continue
            single_layer_mem *= s
        shapes_mem_count += single_layer_mem

    trainable_count = np.sum([K.count_params(p) for p in model.trainable_weights])
    non_trainable_count = np.sum([K.count_params(p) for p in model.non_trainable_weights])

    number_size = 4.0
    if K.floatx() == 'float16':
        number_size = 2.0
    if K.floatx() == 'float64':
        number_size = 8.0

    total_memory = number_size * (batch_size * shapes_mem_count + trainable_count + non_trainable_count)
    gbytes = np.round(total_memory / (1024.0 ** 3), 3) + internal_model_mem_count
    return gbytes

# %%
train_path = r"Bactnet/Training data/stacks"

batch_size = 16
SIZE = 288
image_dataset = None
mask_dataset = None

def prepare_data(train_path, PATCH_SIZE):
    stacks = os.listdir(os.path.join(train_path, "training_source"))
    image_dataset = None
    mask_dataset = None
    for stack in stacks:
        if (stack.split(".")[-1]=="tif"):
            img = tiff.imread(os.path.join(train_path, "training_source",stack))
            mask = tiff.imread(os.path.join(train_path, "training_target", stack))

            img = patch_stack(img, PATCH_SIZE)
            mask =patch_stack(mask, PATCH_SIZE)
            mask = mask[:, 1, :, :].reshape((mask.shape[0], 1, mask.shape[2], -1))

            #print(stack, img.shape, mask.shape)
            mask = normalizeMinMax(mask)
            #not_ok_idxs = checkEmptyMask(mask)
            #mask = np.delete(mask, not_ok_idxs, axis=0)
            #img = np.delete(img, not_ok_idxs, axis=0)

            img = normalizePercentile(img, 0.1, 99.9, clip=True)

            #print(stack, img.shape, mask.shape)

            if image_dataset is not None:
                image_dataset = np.concatenate((image_dataset, img))

            if mask_dataset is not None:
                mask_dataset = np.concatenate((mask_dataset, mask))

            if image_dataset is None:
                image_dataset = img

            if mask_dataset is None:
                mask_dataset = mask

            #print(image_dataset.shape, mask_dataset.shape)

    return image_dataset, mask_dataset

# %%
image_dataset, mask_dataset = prepare_data(train_path, SIZE)
print(image_dataset.shape, mask_dataset.shape)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size = 0.15, random_state = 8)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1664, 3, 288, 288) (1664, 1, 288, 288)
# (1414, 3, 288, 288) (250, 3, 288, 288) (1414, 1, 288, 288) (250, 1, 288, 288)

# %%
#Sanity check, view few mages
import random

image_number = random.randint(0, X_test.shape[0])
plt.figure(figsize=(12, 6))
plt.subplot(231)
plt.imshow(X_test[image_number, 0, :, :])
plt.subplot(232)
plt.imshow(X_test[image_number, 1, :, :])
plt.subplot(233)
plt.imshow(X_test[image_number, 2, :, :])
plt.subplot(235)
plt.imshow(y_test[image_number, 0, :, :])
plt.show()

###############################################################

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.layers import Activation, MaxPool2D, Concatenate


def conv_block(input, num_filters):
    t = Conv2D(num_filters, 3, padding="same",  data_format="channels_first", activation='relu')(input)
    t = BatchNormalization()(t)
    t = Dropout(0.1)(t)
    t = Conv2D(num_filters, 3, padding="same",  data_format="channels_first", activation='relu')(t)
    t = BatchNormalization()(t)
    t = Dropout(0.1)(t)
    return t

#Encoder block: Conv block followed by maxpooling

def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = MaxPool2D((2, 2), data_format="channels_first")(x)
    return x, p

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same", data_format="channels_first")(input)
    x = Concatenate(axis=1)([x, skip_features])
    x = conv_block(x, num_filters)
    return x

#Build Unet using the blocks
def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024) #Bridge

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid", data_format="channels_first")(d4)  #Binary (can be multiclass)

    model = Model(inputs, outputs, name="U-Net")
    return model

# %%
keras.backend.clear_session() # Free up RAM in case the model definition cells were run multiple times


#from keras_unet_collection import models
from keras_unet_collection import losses


# Build model
def hybrid_loss(y_true, y_pred):

    loss_focal = losses.focal_tversky(y_true, y_pred, alpha=0.5, gamma=4/3)
    loss_iou = losses.iou_seg(y_true, y_pred)
    
    # (x) 
    #loss_ssim = losses.ms_ssim(y_true, y_pred, max_val=1.0, filter_size=4)
    
    return loss_focal+loss_iou #+loss_ssim

SIZE=288
input_shape = (3, SIZE, SIZE)
batch_size = 8

model = build_unet(input_shape)
model.compile(loss=[hybrid_loss, hybrid_loss, hybrid_loss, hybrid_loss, hybrid_loss],
                  loss_weights=[0.25, 0.25, 0.25, 0.25, 1.0],
                  optimizer=keras.optimizers.Adam(learning_rate=1e-4), metrics=[losses.dice_coef, losses.iou_seg])
model.summary()
print(get_model_memory_usage(batch_size, model))
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 3, 288, 288) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 288, 288) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 288, 288) 1152        conv2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64, 288, 288) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 288, 288) 36928       dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 288, 288) 1152        conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 288, 288) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 144, 144) 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 144, 144 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 144, 144 576         conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128, 144, 144 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 144, 144 147584      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 144, 144 576         conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128, 144, 144 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 72, 72)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 72, 72)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 256, 72, 72)  288         conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 256, 72, 72)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 256, 72, 72)  590080      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 256, 72, 72)  288         conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 256, 72, 72)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 256, 36, 36)  0           dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 512, 36, 36)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 512, 36, 36)  144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512, 36, 36)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 512, 36, 36)  2359808     dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 512, 36, 36)  144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 512, 36, 36)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 512, 18, 18)  0           dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 1024, 18, 18) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 1024, 18, 18) 72          conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 1024, 18, 18) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 1024, 18, 18) 9438208     dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 1024, 18, 18) 72          conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 1024, 18, 18) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 512, 36, 36)  2097664     dropout_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1024, 36, 36) 0           conv2d_transpose[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 512, 36, 36)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 512, 36, 36)  144         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 512, 36, 36)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 512, 36, 36)  2359808     dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 512, 36, 36)  144         conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 512, 36, 36)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 256, 72, 72)  524544      dropout_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 512, 72, 72)  0           conv2d_transpose_1[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 256, 72, 72)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 256, 72, 72)  288         conv2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 256, 72, 72)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 256, 72, 72)  590080      dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 256, 72, 72)  288         conv2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 256, 72, 72)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 144, 144 131200      dropout_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 144, 144 0           conv2d_transpose_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 144, 144 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128, 144, 144 576         conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 128, 144, 144 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 144, 144 147584      dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 144, 144 576         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 128, 144, 144 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 288, 288) 32832       dropout_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 288, 288 0           conv2d_transpose_3[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 288, 288) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 288, 288) 1152        conv2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 64, 288, 288) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 288, 288) 36928       dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 288, 288) 1152        conv2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 64, 288, 288) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 1, 288, 288)  65          dropout_17[0][0]
# ==================================================================================================
# Total params: 31,040,529
# Trainable params: 31,036,137
# Non-trainable params: 4,392
# __________________________________________________________________________________________________
# 4.708

# %%
#New generator with rotation and shear where interpolation that comes with rotation and shear are thresholded in masks. 
#This gives a binary mask rather than a mask with interpolated values. 
seed=1337
from keras.preprocessing.image import ImageDataGenerator

img_data_gen_args = dict(rotation_range=180,
                     width_shift_range=0.3,
                     height_shift_range=0.3,
                     shear_range=0.5,
                     zoom_range=0.3,
                     horizontal_flip=True,
                     vertical_flip=True,
                     fill_mode='reflect',
                     data_format="channels_first")

mask_data_gen_args = dict(rotation_range=180,
                     width_shift_range=0.3,
                     height_shift_range=0.3,
                     shear_range=0.5,
                     zoom_range=0.3,
                     horizontal_flip=True,
                     vertical_flip=True,
                     fill_mode='reflect',
                     data_format="channels_first",
                     preprocessing_function = lambda x: np.where(x>0, 1, 0).astype(x.dtype)) #Binarize the output again. 

image_data_generator = ImageDataGenerator(**img_data_gen_args)
#image_data_generator.fit(X_train, augment=True, seed=seed)

image_generator = image_data_generator.flow(X_train, seed=seed, batch_size=batch_size)
valid_img_generator = image_data_generator.flow(X_test, seed=seed, batch_size=batch_size) #Default batch size 32, if not specified here

mask_data_generator = ImageDataGenerator(**mask_data_gen_args)
#mask_data_generator.fit(y_train, augment=True, seed=seed)
mask_generator = mask_data_generator.flow(y_train, seed=seed, batch_size=batch_size)
valid_mask_generator = mask_data_generator.flow(y_test, seed=seed, batch_size=batch_size)  #Default batch size 32, if not specified here

def my_image_mask_generator(image_generator, mask_generator):
    train_generator = zip(image_generator, mask_generator)
    for (img, mask) in train_generator:
        yield (img, mask)

my_generator = my_image_mask_generator(image_generator, mask_generator)

validation_datagen = my_image_mask_generator(valid_img_generator, valid_mask_generator)


x = valid_img_generator.next()
y = valid_mask_generator.next()
print(x.shape, y.shape)
for i in range(len(x)):
    image = x[i]
    fig1 = plt.subplot(4, 4, i+1)
    fig1.set_xticks([])  #Turn off axis
    fig1.set_yticks([])
    plt.imshow(image[1, :,:], cmap='gray')
    #plt.subplot(4,4,2)
    #plt.imshow(mask[0,:,:])
plt.show()

for i in range(len(x)):
    image = y[i]
    fig1 = plt.subplot(4, 4, i+1)
    fig1.set_xticks([])  #Turn off axis
    fig1.set_yticks([])
    plt.imshow(image[0, :,:], cmap='gray')
    #plt.subplot(4,4,2)
    #plt.imshow(mask[0,:,:])
plt.show()


steps_per_epoch = 3*(len(X_train))//batch_size
# Out:
# (8, 3, 288, 288) (8, 1, 288, 288)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger

epochs = 2000
#model.load_weights(r"/models/bactunet_3frame_local.hdf5")

#ModelCheckpoint callback saves a model at some interval.

filepath=r"models/bactunet_3frame_dice_noEmpty.hdf5" 
#Use Mode = max for accuracy and min for loss. 
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

#https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=100, verbose=1)
#This callback will stop the training when there is no improvement in
# the validation loss for 10 consecutive epochs.

#CSVLogger logs epoch, acc, loss, val_acc, val_loss
log_csv = CSVLogger(r'models/bactnet_v2_logs.csv', separator=',', append=False)

callbacks_list = [checkpoint, early_stop, log_csv]

#We can now use these generators to train our model. 
#Give this a name so we can call it later for plotting loss, accuracy etc. as a function of epochs.

history = model.fit(
        my_generator,
        steps_per_epoch=steps_per_epoch,   
        epochs=epochs,
        validation_data=validation_datagen,
        validation_steps=steps_per_epoch,
        callbacks=callbacks_list)
# Out:
# Epoch 1/2000
# 530/530 [==============================] - 414s 778ms/step - loss: 0.4550 - dice_coef: 0.1327 - iou_seg: 0.9233 - val_loss: 0.4280 - val_dice_coef: 0.2109 - val_iou_seg: 0.8740
#
# Epoch 00001: val_loss improved from inf to 0.42799, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 2/2000
# 530/530 [==============================] - 406s 766ms/step - loss: 0.4360 - dice_coef: 0.1872 - iou_seg: 0.8900 - val_loss: 0.4301 - val_dice_coef: 0.2017 - val_iou_seg: 0.8797
#
# Epoch 00002: val_loss did not improve from 0.42799
# Epoch 3/2000
# 530/530 [==============================] - 406s 767ms/step - loss: 0.4052 - dice_coef: 0.2700 - iou_seg: 0.8344 - val_loss: 0.4789 - val_dice_coef: 0.0658 - val_iou_seg: 0.9655
#
# Epoch 00003: val_loss did not improve from 0.42799
# Epoch 4/2000
# 530/530 [==============================] - 405s 765ms/step - loss: 0.3479 - dice_coef: 0.4167 - iou_seg: 0.7274 - val_loss: 0.3958 - val_dice_coef: 0.2968 - val_iou_seg: 0.8188
#
# Epoch 00004: val_loss improved from 0.42799 to 0.39575, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 5/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.3273 - dice_coef: 0.4644 - iou_seg: 0.6871 - val_loss: 0.3681 - val_dice_coef: 0.3630 - val_iou_seg: 0.7688
#
# Epoch 00005: val_loss improved from 0.39575 to 0.36814, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 6/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.3216 - dice_coef: 0.4754 - iou_seg: 0.6752 - val_loss: 0.3191 - val_dice_coef: 0.4799 - val_iou_seg: 0.6735
#
# Epoch 00006: val_loss improved from 0.36814 to 0.31913, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 7/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.3152 - dice_coef: 0.4892 - iou_seg: 0.6625 - val_loss: 0.3123 - val_dice_coef: 0.4946 - val_iou_seg: 0.6591
#
# Epoch 00007: val_loss improved from 0.31913 to 0.31233, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 8/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.3101 - dice_coef: 0.5020 - iou_seg: 0.6522 - val_loss: 0.3166 - val_dice_coef: 0.4851 - val_iou_seg: 0.6667
#
# Epoch 00008: val_loss did not improve from 0.31233
# Epoch 9/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.3077 - dice_coef: 0.5066 - iou_seg: 0.6477 - val_loss: 0.3031 - val_dice_coef: 0.5149 - val_iou_seg: 0.6362
#
# Epoch 00009: val_loss improved from 0.31233 to 0.30310, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 10/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.3029 - dice_coef: 0.5177 - iou_seg: 0.6378 - val_loss: 0.3075 - val_dice_coef: 0.5069 - val_iou_seg: 0.6479
#
# Epoch 00010: val_loss did not improve from 0.30310
# Epoch 11/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.3025 - dice_coef: 0.5176 - iou_seg: 0.6367 - val_loss: 0.2958 - val_dice_coef: 0.5321 - val_iou_seg: 0.6242
#
# Epoch 00011: val_loss improved from 0.30310 to 0.29575, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 12/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.3007 - dice_coef: 0.5216 - iou_seg: 0.6332 - val_loss: 0.2787 - val_dice_coef: 0.5644 - val_iou_seg: 0.5908
#
# Epoch 00012: val_loss improved from 0.29575 to 0.27874, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 13/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.3002 - dice_coef: 0.5229 - iou_seg: 0.6322 - val_loss: 0.3171 - val_dice_coef: 0.4837 - val_iou_seg: 0.6702
#
# Epoch 00013: val_loss did not improve from 0.27874
# Epoch 14/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2978 - dice_coef: 0.5278 - iou_seg: 0.6268 - val_loss: 0.3083 - val_dice_coef: 0.5056 - val_iou_seg: 0.6504
#
# Epoch 00014: val_loss did not improve from 0.27874
# Epoch 15/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2903 - dice_coef: 0.5441 - iou_seg: 0.6117 - val_loss: 0.2853 - val_dice_coef: 0.5532 - val_iou_seg: 0.6041
#
# Epoch 00015: val_loss did not improve from 0.27874
# Epoch 16/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.2919 - dice_coef: 0.5408 - iou_seg: 0.6155 - val_loss: 0.3059 - val_dice_coef: 0.5112 - val_iou_seg: 0.6409
#
# Epoch 00016: val_loss did not improve from 0.27874
# Epoch 17/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2892 - dice_coef: 0.5459 - iou_seg: 0.6100 - val_loss: 0.3154 - val_dice_coef: 0.4863 - val_iou_seg: 0.6613
#
# Epoch 00017: val_loss did not improve from 0.27874
# Epoch 18/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2838 - dice_coef: 0.5581 - iou_seg: 0.5987 - val_loss: 0.3530 - val_dice_coef: 0.4038 - val_iou_seg: 0.7391
#
# Epoch 00018: val_loss did not improve from 0.27874
# Epoch 19/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2873 - dice_coef: 0.5507 - iou_seg: 0.6061 - val_loss: 0.3221 - val_dice_coef: 0.4732 - val_iou_seg: 0.6777
#
# Epoch 00019: val_loss did not improve from 0.27874
# Epoch 20/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.2858 - dice_coef: 0.5549 - iou_seg: 0.6033 - val_loss: 0.2839 - val_dice_coef: 0.5563 - val_iou_seg: 0.6026
#
# Epoch 00020: val_loss did not improve from 0.27874
# Epoch 21/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2853 - dice_coef: 0.5555 - iou_seg: 0.6023 - val_loss: 0.2786 - val_dice_coef: 0.5659 - val_iou_seg: 0.5917
#
# Epoch 00021: val_loss improved from 0.27874 to 0.27859, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 22/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2830 - dice_coef: 0.5597 - iou_seg: 0.5972 - val_loss: 0.2935 - val_dice_coef: 0.5320 - val_iou_seg: 0.6246
#
# Epoch 00022: val_loss did not improve from 0.27859
# Epoch 23/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2784 - dice_coef: 0.5703 - iou_seg: 0.5880 - val_loss: 0.2992 - val_dice_coef: 0.5256 - val_iou_seg: 0.6317
#
# Epoch 00023: val_loss did not improve from 0.27859
# Epoch 24/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2806 - dice_coef: 0.5649 - iou_seg: 0.5925 - val_loss: 0.2886 - val_dice_coef: 0.5433 - val_iou_seg: 0.6133
#
# Epoch 00024: val_loss did not improve from 0.27859
# Epoch 25/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2785 - dice_coef: 0.5696 - iou_seg: 0.5879 - val_loss: 0.2900 - val_dice_coef: 0.5402 - val_iou_seg: 0.6146
#
# Epoch 00025: val_loss did not improve from 0.27859
# Epoch 26/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2742 - dice_coef: 0.5785 - iou_seg: 0.5790 - val_loss: 0.2699 - val_dice_coef: 0.5857 - val_iou_seg: 0.5719
#
# Epoch 00026: val_loss improved from 0.27859 to 0.26994, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 27/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2841 - dice_coef: 0.5563 - iou_seg: 0.5990 - val_loss: 0.2663 - val_dice_coef: 0.5907 - val_iou_seg: 0.5671
#
# Epoch 00027: val_loss improved from 0.26994 to 0.26635, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 28/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2773 - dice_coef: 0.5722 - iou_seg: 0.5856 - val_loss: 0.2969 - val_dice_coef: 0.5299 - val_iou_seg: 0.6280
#
# Epoch 00028: val_loss did not improve from 0.26635
# Epoch 29/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2734 - dice_coef: 0.5805 - iou_seg: 0.5776 - val_loss: 0.2796 - val_dice_coef: 0.5651 - val_iou_seg: 0.5944
#
# Epoch 00029: val_loss did not improve from 0.26635
# Epoch 30/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2710 - dice_coef: 0.5852 - iou_seg: 0.5725 - val_loss: 0.2732 - val_dice_coef: 0.5795 - val_iou_seg: 0.5787
#
# Epoch 00030: val_loss did not improve from 0.26635
# Epoch 31/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2780 - dice_coef: 0.5701 - iou_seg: 0.5868 - val_loss: 0.2953 - val_dice_coef: 0.5329 - val_iou_seg: 0.6254
#
# Epoch 00031: val_loss did not improve from 0.26635
# Epoch 32/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2780 - dice_coef: 0.5701 - iou_seg: 0.5870 - val_loss: 0.2702 - val_dice_coef: 0.5838 - val_iou_seg: 0.5732
#
# Epoch 00032: val_loss did not improve from 0.26635
# Epoch 33/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2724 - dice_coef: 0.5819 - iou_seg: 0.5751 - val_loss: 0.2751 - val_dice_coef: 0.5773 - val_iou_seg: 0.5806
#
# Epoch 00033: val_loss did not improve from 0.26635
# Epoch 34/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2665 - dice_coef: 0.5943 - iou_seg: 0.5639 - val_loss: 0.2682 - val_dice_coef: 0.5839 - val_iou_seg: 0.5719
#
# Epoch 00034: val_loss did not improve from 0.26635
# Epoch 35/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2735 - dice_coef: 0.5793 - iou_seg: 0.5775 - val_loss: 0.2702 - val_dice_coef: 0.5834 - val_iou_seg: 0.5751
#
# Epoch 00035: val_loss did not improve from 0.26635
# Epoch 36/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.2666 - dice_coef: 0.5932 - iou_seg: 0.5628 - val_loss: 0.3435 - val_dice_coef: 0.4267 - val_iou_seg: 0.7183
#
# Epoch 00036: val_loss did not improve from 0.26635
# Epoch 37/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2715 - dice_coef: 0.5846 - iou_seg: 0.5740 - val_loss: 0.2905 - val_dice_coef: 0.5407 - val_iou_seg: 0.6169
#
# Epoch 00037: val_loss did not improve from 0.26635
# Epoch 38/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2694 - dice_coef: 0.5876 - iou_seg: 0.5688 - val_loss: 0.2634 - val_dice_coef: 0.5990 - val_iou_seg: 0.5602
#
# Epoch 00038: val_loss improved from 0.26635 to 0.26337, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 39/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2699 - dice_coef: 0.5874 - iou_seg: 0.5705 - val_loss: 0.2817 - val_dice_coef: 0.5637 - val_iou_seg: 0.5959
#
# Epoch 00039: val_loss did not improve from 0.26337
# Epoch 40/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2720 - dice_coef: 0.5816 - iou_seg: 0.5740 - val_loss: 0.3026 - val_dice_coef: 0.5158 - val_iou_seg: 0.6410
#
# Epoch 00040: val_loss did not improve from 0.26337
# Epoch 41/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2688 - dice_coef: 0.5884 - iou_seg: 0.5676 - val_loss: 0.2754 - val_dice_coef: 0.5691 - val_iou_seg: 0.5872
#
# Epoch 00041: val_loss did not improve from 0.26337
# Epoch 42/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2657 - dice_coef: 0.5954 - iou_seg: 0.5614 - val_loss: 0.2749 - val_dice_coef: 0.5746 - val_iou_seg: 0.5849
#
# Epoch 00042: val_loss did not improve from 0.26337
# Epoch 43/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2658 - dice_coef: 0.5955 - iou_seg: 0.5619 - val_loss: 0.2525 - val_dice_coef: 0.6225 - val_iou_seg: 0.5350
#
# Epoch 00043: val_loss improved from 0.26337 to 0.25249, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 44/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2711 - dice_coef: 0.5844 - iou_seg: 0.5733 - val_loss: 0.2596 - val_dice_coef: 0.6023 - val_iou_seg: 0.5540
#
# Epoch 00044: val_loss did not improve from 0.25249
# Epoch 45/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2626 - dice_coef: 0.6026 - iou_seg: 0.5555 - val_loss: 0.2782 - val_dice_coef: 0.5697 - val_iou_seg: 0.5905
#
# Epoch 00045: val_loss did not improve from 0.25249
# Epoch 46/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2594 - dice_coef: 0.6095 - iou_seg: 0.5487 - val_loss: 0.2596 - val_dice_coef: 0.6056 - val_iou_seg: 0.5512
#
# Epoch 00046: val_loss did not improve from 0.25249
# Epoch 47/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2633 - dice_coef: 0.6004 - iou_seg: 0.5565 - val_loss: 0.2700 - val_dice_coef: 0.5817 - val_iou_seg: 0.5738
#
# Epoch 00047: val_loss did not improve from 0.25249
# Epoch 48/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2614 - dice_coef: 0.6046 - iou_seg: 0.5526 - val_loss: 0.2754 - val_dice_coef: 0.5753 - val_iou_seg: 0.5838
#
# Epoch 00048: val_loss did not improve from 0.25249
# Epoch 49/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2615 - dice_coef: 0.6042 - iou_seg: 0.5525 - val_loss: 0.2651 - val_dice_coef: 0.5949 - val_iou_seg: 0.5631
#
# Epoch 00049: val_loss did not improve from 0.25249
# Epoch 50/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2636 - dice_coef: 0.6010 - iou_seg: 0.5578 - val_loss: 0.2603 - val_dice_coef: 0.6037 - val_iou_seg: 0.5529
#
# Epoch 00050: val_loss did not improve from 0.25249
# Epoch 51/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2643 - dice_coef: 0.6001 - iou_seg: 0.5593 - val_loss: 0.2761 - val_dice_coef: 0.5738 - val_iou_seg: 0.5845
#
# Epoch 00051: val_loss did not improve from 0.25249
# Epoch 52/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2582 - dice_coef: 0.6104 - iou_seg: 0.5458 - val_loss: 0.2593 - val_dice_coef: 0.6052 - val_iou_seg: 0.5520
#
# Epoch 00052: val_loss did not improve from 0.25249
# Epoch 53/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2597 - dice_coef: 0.6086 - iou_seg: 0.5495 - val_loss: 0.2549 - val_dice_coef: 0.6148 - val_iou_seg: 0.5424
#
# Epoch 00053: val_loss did not improve from 0.25249
# Epoch 54/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2671 - dice_coef: 0.5925 - iou_seg: 0.5645 - val_loss: 0.2622 - val_dice_coef: 0.6020 - val_iou_seg: 0.5556
#
# Epoch 00054: val_loss did not improve from 0.25249
# Epoch 55/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2651 - dice_coef: 0.5969 - iou_seg: 0.5604 - val_loss: 0.2713 - val_dice_coef: 0.5796 - val_iou_seg: 0.5780
#
# Epoch 00055: val_loss did not improve from 0.25249
# Epoch 56/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2620 - dice_coef: 0.6039 - iou_seg: 0.5540 - val_loss: 0.2705 - val_dice_coef: 0.5829 - val_iou_seg: 0.5750
#
# Epoch 00056: val_loss did not improve from 0.25249
# Epoch 57/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2571 - dice_coef: 0.6137 - iou_seg: 0.5438 - val_loss: 0.2646 - val_dice_coef: 0.5919 - val_iou_seg: 0.5631
#
# Epoch 00057: val_loss did not improve from 0.25249
# Epoch 58/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.2605 - dice_coef: 0.6070 - iou_seg: 0.5510 - val_loss: 0.2532 - val_dice_coef: 0.6167 - val_iou_seg: 0.5412
#
# Epoch 00058: val_loss did not improve from 0.25249
# Epoch 59/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2599 - dice_coef: 0.6080 - iou_seg: 0.5496 - val_loss: 0.2526 - val_dice_coef: 0.6192 - val_iou_seg: 0.5379
#
# Epoch 00059: val_loss did not improve from 0.25249
# Epoch 60/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2535 - dice_coef: 0.6207 - iou_seg: 0.5363 - val_loss: 0.2653 - val_dice_coef: 0.5965 - val_iou_seg: 0.5623
#
# Epoch 00060: val_loss did not improve from 0.25249
# Epoch 61/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2574 - dice_coef: 0.6130 - iou_seg: 0.5445 - val_loss: 0.2632 - val_dice_coef: 0.5993 - val_iou_seg: 0.5597
#
# Epoch 00061: val_loss did not improve from 0.25249
# Epoch 62/2000
# 530/530 [==============================] - 403s 760ms/step - loss: 0.2567 - dice_coef: 0.6148 - iou_seg: 0.5429 - val_loss: 0.2497 - val_dice_coef: 0.6257 - val_iou_seg: 0.5314
#
# Epoch 00062: val_loss improved from 0.25249 to 0.24974, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 63/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2578 - dice_coef: 0.6123 - iou_seg: 0.5454 - val_loss: 0.2575 - val_dice_coef: 0.6102 - val_iou_seg: 0.5482
#
# Epoch 00063: val_loss did not improve from 0.24974
# Epoch 64/2000
# 530/530 [==============================] - 402s 759ms/step - loss: 0.2533 - dice_coef: 0.6219 - iou_seg: 0.5360 - val_loss: 0.2531 - val_dice_coef: 0.6211 - val_iou_seg: 0.5359
#
# Epoch 00064: val_loss did not improve from 0.24974
# Epoch 65/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2576 - dice_coef: 0.6110 - iou_seg: 0.5445 - val_loss: 0.2700 - val_dice_coef: 0.5843 - val_iou_seg: 0.5742
#
# Epoch 00065: val_loss did not improve from 0.24974
# Epoch 66/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2540 - dice_coef: 0.6199 - iou_seg: 0.5372 - val_loss: 0.2521 - val_dice_coef: 0.6229 - val_iou_seg: 0.5343
#
# Epoch 00066: val_loss did not improve from 0.24974
# Epoch 67/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.2515 - dice_coef: 0.6256 - iou_seg: 0.5322 - val_loss: 0.2646 - val_dice_coef: 0.5976 - val_iou_seg: 0.5613
#
# Epoch 00067: val_loss did not improve from 0.24974
# Epoch 68/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.2504 - dice_coef: 0.6267 - iou_seg: 0.5296 - val_loss: 0.2610 - val_dice_coef: 0.6050 - val_iou_seg: 0.5532
#
# Epoch 00068: val_loss did not improve from 0.24974
# Epoch 69/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2613 - dice_coef: 0.6057 - iou_seg: 0.5528 - val_loss: 0.2577 - val_dice_coef: 0.6072 - val_iou_seg: 0.5488
#
# Epoch 00069: val_loss did not improve from 0.24974
# Epoch 70/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2554 - dice_coef: 0.6163 - iou_seg: 0.5401 - val_loss: 0.2594 - val_dice_coef: 0.6031 - val_iou_seg: 0.5508
#
# Epoch 00070: val_loss did not improve from 0.24974
# Epoch 71/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2517 - dice_coef: 0.6244 - iou_seg: 0.5325 - val_loss: 0.2572 - val_dice_coef: 0.6120 - val_iou_seg: 0.5445
#
# Epoch 00071: val_loss did not improve from 0.24974
# Epoch 72/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2509 - dice_coef: 0.6258 - iou_seg: 0.5307 - val_loss: 0.2694 - val_dice_coef: 0.5843 - val_iou_seg: 0.5741
#
# Epoch 00072: val_loss did not improve from 0.24974
# Epoch 73/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2526 - dice_coef: 0.6224 - iou_seg: 0.5342 - val_loss: 0.2608 - val_dice_coef: 0.6029 - val_iou_seg: 0.5564
#
# Epoch 00073: val_loss did not improve from 0.24974
# Epoch 74/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2504 - dice_coef: 0.6267 - iou_seg: 0.5299 - val_loss: 0.2564 - val_dice_coef: 0.6117 - val_iou_seg: 0.5447
#
# Epoch 00074: val_loss did not improve from 0.24974
# Epoch 75/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2546 - dice_coef: 0.6183 - iou_seg: 0.5385 - val_loss: 0.2635 - val_dice_coef: 0.5990 - val_iou_seg: 0.5594
#
# Epoch 00075: val_loss did not improve from 0.24974
# Epoch 76/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2515 - dice_coef: 0.6239 - iou_seg: 0.5323 - val_loss: 0.2588 - val_dice_coef: 0.6087 - val_iou_seg: 0.5498
#
# Epoch 00076: val_loss did not improve from 0.24974
# Epoch 77/2000
# 530/530 [==============================] - 405s 764ms/step - loss: 0.2521 - dice_coef: 0.6237 - iou_seg: 0.5336 - val_loss: 0.2549 - val_dice_coef: 0.6195 - val_iou_seg: 0.5400
#
# Epoch 00077: val_loss did not improve from 0.24974
# Epoch 78/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2526 - dice_coef: 0.6229 - iou_seg: 0.5346 - val_loss: 0.2525 - val_dice_coef: 0.6224 - val_iou_seg: 0.5352
#
# Epoch 00078: val_loss did not improve from 0.24974
# Epoch 79/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2483 - dice_coef: 0.6316 - iou_seg: 0.5257 - val_loss: 0.3008 - val_dice_coef: 0.5207 - val_iou_seg: 0.6361
#
# Epoch 00079: val_loss did not improve from 0.24974
# Epoch 80/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2489 - dice_coef: 0.6300 - iou_seg: 0.5267 - val_loss: 0.2556 - val_dice_coef: 0.6163 - val_iou_seg: 0.5431
#
# Epoch 00080: val_loss did not improve from 0.24974
# Epoch 81/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2508 - dice_coef: 0.6261 - iou_seg: 0.5305 - val_loss: 0.2460 - val_dice_coef: 0.6317 - val_iou_seg: 0.5247
#
# Epoch 00081: val_loss improved from 0.24974 to 0.24598, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 82/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2491 - dice_coef: 0.6303 - iou_seg: 0.5275 - val_loss: 0.2575 - val_dice_coef: 0.6119 - val_iou_seg: 0.5476
#
# Epoch 00082: val_loss did not improve from 0.24598
# Epoch 83/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2458 - dice_coef: 0.6381 - iou_seg: 0.5209 - val_loss: 0.2513 - val_dice_coef: 0.6181 - val_iou_seg: 0.5389
#
# Epoch 00083: val_loss did not improve from 0.24598
# Epoch 84/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2422 - dice_coef: 0.6441 - iou_seg: 0.5132 - val_loss: 0.2417 - val_dice_coef: 0.6415 - val_iou_seg: 0.5143
#
# Epoch 00084: val_loss improved from 0.24598 to 0.24174, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 85/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.2442 - dice_coef: 0.6400 - iou_seg: 0.5169 - val_loss: 0.2525 - val_dice_coef: 0.6150 - val_iou_seg: 0.5398
#
# Epoch 00085: val_loss did not improve from 0.24174
# Epoch 86/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2509 - dice_coef: 0.6264 - iou_seg: 0.5313 - val_loss: 0.2570 - val_dice_coef: 0.6127 - val_iou_seg: 0.5456
#
# Epoch 00086: val_loss did not improve from 0.24174
# Epoch 87/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2447 - dice_coef: 0.6388 - iou_seg: 0.5180 - val_loss: 0.2546 - val_dice_coef: 0.6127 - val_iou_seg: 0.5437
#
# Epoch 00087: val_loss did not improve from 0.24174
# Epoch 88/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2453 - dice_coef: 0.6379 - iou_seg: 0.5198 - val_loss: 0.2501 - val_dice_coef: 0.6234 - val_iou_seg: 0.5338
#
# Epoch 00088: val_loss did not improve from 0.24174
# Epoch 89/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2442 - dice_coef: 0.6399 - iou_seg: 0.5169 - val_loss: 0.2521 - val_dice_coef: 0.6214 - val_iou_seg: 0.5347
#
# Epoch 00089: val_loss did not improve from 0.24174
# Epoch 90/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2468 - dice_coef: 0.6339 - iou_seg: 0.5228 - val_loss: 0.2511 - val_dice_coef: 0.6250 - val_iou_seg: 0.5322
#
# Epoch 00090: val_loss did not improve from 0.24174
# Epoch 91/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2430 - dice_coef: 0.6410 - iou_seg: 0.5143 - val_loss: 0.2465 - val_dice_coef: 0.6317 - val_iou_seg: 0.5255
#
# Epoch 00091: val_loss did not improve from 0.24174
# Epoch 92/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2471 - dice_coef: 0.6326 - iou_seg: 0.5225 - val_loss: 0.2459 - val_dice_coef: 0.6324 - val_iou_seg: 0.5232
#
# Epoch 00092: val_loss did not improve from 0.24174
# Epoch 93/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2469 - dice_coef: 0.6343 - iou_seg: 0.5228 - val_loss: 0.2659 - val_dice_coef: 0.5927 - val_iou_seg: 0.5654
#
# Epoch 00093: val_loss did not improve from 0.24174
# Epoch 94/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2500 - dice_coef: 0.6275 - iou_seg: 0.5291 - val_loss: 0.2671 - val_dice_coef: 0.5956 - val_iou_seg: 0.5649
#
# Epoch 00094: val_loss did not improve from 0.24174
# Epoch 95/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2455 - dice_coef: 0.6361 - iou_seg: 0.5192 - val_loss: 0.2536 - val_dice_coef: 0.6179 - val_iou_seg: 0.5397
#
# Epoch 00095: val_loss did not improve from 0.24174
# Epoch 96/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2431 - dice_coef: 0.6426 - iou_seg: 0.5154 - val_loss: 0.2523 - val_dice_coef: 0.6161 - val_iou_seg: 0.5402
#
# Epoch 00096: val_loss did not improve from 0.24174
# Epoch 97/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2463 - dice_coef: 0.6356 - iou_seg: 0.5217 - val_loss: 0.2480 - val_dice_coef: 0.6300 - val_iou_seg: 0.5287
#
# Epoch 00097: val_loss did not improve from 0.24174
# Epoch 98/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2445 - dice_coef: 0.6390 - iou_seg: 0.5176 - val_loss: 0.2444 - val_dice_coef: 0.6363 - val_iou_seg: 0.5195
#
# Epoch 00098: val_loss did not improve from 0.24174
# Epoch 99/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.2475 - dice_coef: 0.6330 - iou_seg: 0.5240 - val_loss: 0.2404 - val_dice_coef: 0.6467 - val_iou_seg: 0.5093
#
# Epoch 00099: val_loss improved from 0.24174 to 0.24035, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 100/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2441 - dice_coef: 0.6400 - iou_seg: 0.5169 - val_loss: 0.2489 - val_dice_coef: 0.6249 - val_iou_seg: 0.5324
#
# Epoch 00100: val_loss did not improve from 0.24035
# Epoch 101/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2375 - dice_coef: 0.6533 - iou_seg: 0.5034 - val_loss: 0.2458 - val_dice_coef: 0.6334 - val_iou_seg: 0.5245
#
# Epoch 00101: val_loss did not improve from 0.24035
# Epoch 102/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2438 - dice_coef: 0.6400 - iou_seg: 0.5162 - val_loss: 0.2554 - val_dice_coef: 0.6157 - val_iou_seg: 0.5430
#
# Epoch 00102: val_loss did not improve from 0.24035
# Epoch 103/2000
# 530/530 [==============================] - 405s 764ms/step - loss: 0.2495 - dice_coef: 0.6276 - iou_seg: 0.5274 - val_loss: 0.2511 - val_dice_coef: 0.6239 - val_iou_seg: 0.5329
#
# Epoch 00103: val_loss did not improve from 0.24035
# Epoch 104/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2365 - dice_coef: 0.6539 - iou_seg: 0.5005 - val_loss: 0.2501 - val_dice_coef: 0.6270 - val_iou_seg: 0.5316
#
# Epoch 00104: val_loss did not improve from 0.24035
# Epoch 105/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2393 - dice_coef: 0.6490 - iou_seg: 0.5067 - val_loss: 0.2476 - val_dice_coef: 0.6284 - val_iou_seg: 0.5286
#
# Epoch 00105: val_loss did not improve from 0.24035
# Epoch 106/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2420 - dice_coef: 0.6439 - iou_seg: 0.5124 - val_loss: 0.2645 - val_dice_coef: 0.5959 - val_iou_seg: 0.5636
#
# Epoch 00106: val_loss did not improve from 0.24035
# Epoch 107/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2427 - dice_coef: 0.6429 - iou_seg: 0.5138 - val_loss: 0.2556 - val_dice_coef: 0.6164 - val_iou_seg: 0.5423
#
# Epoch 00107: val_loss did not improve from 0.24035
# Epoch 108/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2346 - dice_coef: 0.6587 - iou_seg: 0.4972 - val_loss: 0.2615 - val_dice_coef: 0.5986 - val_iou_seg: 0.5580
#
# Epoch 00108: val_loss did not improve from 0.24035
# Epoch 109/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2419 - dice_coef: 0.6432 - iou_seg: 0.5119 - val_loss: 0.2731 - val_dice_coef: 0.5809 - val_iou_seg: 0.5786
#
# Epoch 00109: val_loss did not improve from 0.24035
# Epoch 110/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2374 - dice_coef: 0.6531 - iou_seg: 0.5027 - val_loss: 0.2583 - val_dice_coef: 0.6104 - val_iou_seg: 0.5482
#
# Epoch 00110: val_loss did not improve from 0.24035
# Epoch 111/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2351 - dice_coef: 0.6578 - iou_seg: 0.4982 - val_loss: 0.2441 - val_dice_coef: 0.6377 - val_iou_seg: 0.5188
#
# Epoch 00111: val_loss did not improve from 0.24035
# Epoch 112/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.2390 - dice_coef: 0.6493 - iou_seg: 0.5059 - val_loss: 0.2448 - val_dice_coef: 0.6339 - val_iou_seg: 0.5221
#
# Epoch 00112: val_loss did not improve from 0.24035
# Epoch 113/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2438 - dice_coef: 0.6390 - iou_seg: 0.5155 - val_loss: 0.2916 - val_dice_coef: 0.5411 - val_iou_seg: 0.6160
#
# Epoch 00113: val_loss did not improve from 0.24035
# Epoch 114/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2391 - dice_coef: 0.6506 - iou_seg: 0.5067 - val_loss: 0.2452 - val_dice_coef: 0.6367 - val_iou_seg: 0.5208
#
# Epoch 00114: val_loss did not improve from 0.24035
# Epoch 115/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2428 - dice_coef: 0.6419 - iou_seg: 0.5138 - val_loss: 0.2404 - val_dice_coef: 0.6406 - val_iou_seg: 0.5145
#
# Epoch 00115: val_loss did not improve from 0.24035
# Epoch 116/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2336 - dice_coef: 0.6609 - iou_seg: 0.4950 - val_loss: 0.2524 - val_dice_coef: 0.6220 - val_iou_seg: 0.5356
#
# Epoch 00116: val_loss did not improve from 0.24035
# Epoch 117/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2365 - dice_coef: 0.6552 - iou_seg: 0.5008 - val_loss: 0.2653 - val_dice_coef: 0.5958 - val_iou_seg: 0.5626
#
# Epoch 00117: val_loss did not improve from 0.24035
# Epoch 118/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2382 - dice_coef: 0.6529 - iou_seg: 0.5051 - val_loss: 0.2531 - val_dice_coef: 0.6194 - val_iou_seg: 0.5357
#
# Epoch 00118: val_loss did not improve from 0.24035
# Epoch 119/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.2334 - dice_coef: 0.6609 - iou_seg: 0.4945 - val_loss: 0.2478 - val_dice_coef: 0.6309 - val_iou_seg: 0.5278
#
# Epoch 00119: val_loss did not improve from 0.24035
# Epoch 120/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2373 - dice_coef: 0.6535 - iou_seg: 0.5030 - val_loss: 0.2437 - val_dice_coef: 0.6364 - val_iou_seg: 0.5197
#
# Epoch 00120: val_loss did not improve from 0.24035
# Epoch 121/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2357 - dice_coef: 0.6567 - iou_seg: 0.4991 - val_loss: 0.2518 - val_dice_coef: 0.6205 - val_iou_seg: 0.5353
#
# Epoch 00121: val_loss did not improve from 0.24035
# Epoch 122/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2383 - dice_coef: 0.6503 - iou_seg: 0.5042 - val_loss: 0.2416 - val_dice_coef: 0.6445 - val_iou_seg: 0.5122
#
# Epoch 00122: val_loss did not improve from 0.24035
# Epoch 123/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2350 - dice_coef: 0.6581 - iou_seg: 0.4978 - val_loss: 0.2525 - val_dice_coef: 0.6220 - val_iou_seg: 0.5357
#
# Epoch 00123: val_loss did not improve from 0.24035
# Epoch 124/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2365 - dice_coef: 0.6547 - iou_seg: 0.5007 - val_loss: 0.2461 - val_dice_coef: 0.6309 - val_iou_seg: 0.5242
#
# Epoch 00124: val_loss did not improve from 0.24035
# Epoch 125/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2286 - dice_coef: 0.6695 - iou_seg: 0.4840 - val_loss: 0.2397 - val_dice_coef: 0.6487 - val_iou_seg: 0.5096
#
# Epoch 00125: val_loss improved from 0.24035 to 0.23972, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 126/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2413 - dice_coef: 0.6448 - iou_seg: 0.5110 - val_loss: 0.2496 - val_dice_coef: 0.6271 - val_iou_seg: 0.5310
#
# Epoch 00126: val_loss did not improve from 0.23972
# Epoch 127/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2358 - dice_coef: 0.6571 - iou_seg: 0.4996 - val_loss: 0.2435 - val_dice_coef: 0.6391 - val_iou_seg: 0.5170
#
# Epoch 00127: val_loss did not improve from 0.23972
# Epoch 128/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.2311 - dice_coef: 0.6659 - iou_seg: 0.4897 - val_loss: 0.2528 - val_dice_coef: 0.6188 - val_iou_seg: 0.5378
#
# Epoch 00128: val_loss did not improve from 0.23972
# Epoch 129/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2333 - dice_coef: 0.6604 - iou_seg: 0.4938 - val_loss: 0.2441 - val_dice_coef: 0.6399 - val_iou_seg: 0.5176
#
# Epoch 00129: val_loss did not improve from 0.23972
# Epoch 130/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2279 - dice_coef: 0.6716 - iou_seg: 0.4825 - val_loss: 0.2613 - val_dice_coef: 0.6047 - val_iou_seg: 0.5537
#
# Epoch 00130: val_loss did not improve from 0.23972
# Epoch 131/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2320 - dice_coef: 0.6639 - iou_seg: 0.4914 - val_loss: 0.2464 - val_dice_coef: 0.6351 - val_iou_seg: 0.5226
#
# Epoch 00131: val_loss did not improve from 0.23972
# Epoch 132/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2331 - dice_coef: 0.6608 - iou_seg: 0.4936 - val_loss: 0.2496 - val_dice_coef: 0.6262 - val_iou_seg: 0.5321
#
# Epoch 00132: val_loss did not improve from 0.23972
# Epoch 133/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.2334 - dice_coef: 0.6604 - iou_seg: 0.4938 - val_loss: 0.2411 - val_dice_coef: 0.6432 - val_iou_seg: 0.5132
#
# Epoch 00133: val_loss did not improve from 0.23972
# Epoch 134/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2306 - dice_coef: 0.6665 - iou_seg: 0.4885 - val_loss: 0.2449 - val_dice_coef: 0.6340 - val_iou_seg: 0.5228
#
# Epoch 00134: val_loss did not improve from 0.23972
# Epoch 135/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2345 - dice_coef: 0.6583 - iou_seg: 0.4964 - val_loss: 0.2628 - val_dice_coef: 0.6033 - val_iou_seg: 0.5565
#
# Epoch 00135: val_loss did not improve from 0.23972
# Epoch 136/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2346 - dice_coef: 0.6590 - iou_seg: 0.4968 - val_loss: 0.2567 - val_dice_coef: 0.6174 - val_iou_seg: 0.5436
#
# Epoch 00136: val_loss did not improve from 0.23972
# Epoch 137/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2382 - dice_coef: 0.6511 - iou_seg: 0.5042 - val_loss: 0.2628 - val_dice_coef: 0.6003 - val_iou_seg: 0.5583
#
# Epoch 00137: val_loss did not improve from 0.23972
# Epoch 138/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2323 - dice_coef: 0.6630 - iou_seg: 0.4922 - val_loss: 0.2496 - val_dice_coef: 0.6225 - val_iou_seg: 0.5327
#
# Epoch 00138: val_loss did not improve from 0.23972
# Epoch 139/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2360 - dice_coef: 0.6543 - iou_seg: 0.4994 - val_loss: 0.2572 - val_dice_coef: 0.6052 - val_iou_seg: 0.5492
#
# Epoch 00139: val_loss did not improve from 0.23972
# Epoch 140/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2357 - dice_coef: 0.6560 - iou_seg: 0.4993 - val_loss: 0.2542 - val_dice_coef: 0.6149 - val_iou_seg: 0.5398
#
# Epoch 00140: val_loss did not improve from 0.23972
# Epoch 141/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2308 - dice_coef: 0.6656 - iou_seg: 0.4886 - val_loss: 0.2481 - val_dice_coef: 0.6270 - val_iou_seg: 0.5286
#
# Epoch 00141: val_loss did not improve from 0.23972
# Epoch 142/2000
# 530/530 [==============================] - 403s 760ms/step - loss: 0.2301 - dice_coef: 0.6681 - iou_seg: 0.4878 - val_loss: 0.2377 - val_dice_coef: 0.6497 - val_iou_seg: 0.5059
#
# Epoch 00142: val_loss improved from 0.23972 to 0.23772, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 143/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2269 - dice_coef: 0.6735 - iou_seg: 0.4805 - val_loss: 0.2406 - val_dice_coef: 0.6451 - val_iou_seg: 0.5107
#
# Epoch 00143: val_loss did not improve from 0.23772
# Epoch 144/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2322 - dice_coef: 0.6633 - iou_seg: 0.4916 - val_loss: 0.2478 - val_dice_coef: 0.6292 - val_iou_seg: 0.5258
#
# Epoch 00144: val_loss did not improve from 0.23772
# Epoch 145/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2367 - dice_coef: 0.6536 - iou_seg: 0.5012 - val_loss: 0.2547 - val_dice_coef: 0.6155 - val_iou_seg: 0.5413
#
# Epoch 00145: val_loss did not improve from 0.23772
# Epoch 146/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2295 - dice_coef: 0.6696 - iou_seg: 0.4865 - val_loss: 0.2470 - val_dice_coef: 0.6266 - val_iou_seg: 0.5288
#
# Epoch 00146: val_loss did not improve from 0.23772
# Epoch 147/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2297 - dice_coef: 0.6667 - iou_seg: 0.4862 - val_loss: 0.2400 - val_dice_coef: 0.6451 - val_iou_seg: 0.5115
#
# Epoch 00147: val_loss did not improve from 0.23772
# Epoch 148/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2260 - dice_coef: 0.6751 - iou_seg: 0.4785 - val_loss: 0.2405 - val_dice_coef: 0.6453 - val_iou_seg: 0.5110
#
# Epoch 00148: val_loss did not improve from 0.23772
# Epoch 149/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2302 - dice_coef: 0.6671 - iou_seg: 0.4877 - val_loss: 0.2490 - val_dice_coef: 0.6267 - val_iou_seg: 0.5294
#
# Epoch 00149: val_loss did not improve from 0.23772
# Epoch 150/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2267 - dice_coef: 0.6736 - iou_seg: 0.4803 - val_loss: 0.2411 - val_dice_coef: 0.6434 - val_iou_seg: 0.5121
#
# Epoch 00150: val_loss did not improve from 0.23772
# Epoch 151/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2310 - dice_coef: 0.6656 - iou_seg: 0.4895 - val_loss: 0.2410 - val_dice_coef: 0.6423 - val_iou_seg: 0.5153
#
# Epoch 00151: val_loss did not improve from 0.23772
# Epoch 152/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2307 - dice_coef: 0.6651 - iou_seg: 0.4880 - val_loss: 0.2411 - val_dice_coef: 0.6454 - val_iou_seg: 0.5126
#
# Epoch 00152: val_loss did not improve from 0.23772
# Epoch 153/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2321 - dice_coef: 0.6629 - iou_seg: 0.4912 - val_loss: 0.2402 - val_dice_coef: 0.6447 - val_iou_seg: 0.5107
#
# Epoch 00153: val_loss did not improve from 0.23772
# Epoch 154/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2299 - dice_coef: 0.6670 - iou_seg: 0.4866 - val_loss: 0.2576 - val_dice_coef: 0.6083 - val_iou_seg: 0.5497
#
# Epoch 00154: val_loss did not improve from 0.23772
# Epoch 155/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2314 - dice_coef: 0.6647 - iou_seg: 0.4900 - val_loss: 0.2581 - val_dice_coef: 0.6145 - val_iou_seg: 0.5437
#
# Epoch 00155: val_loss did not improve from 0.23772
# Epoch 156/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2294 - dice_coef: 0.6683 - iou_seg: 0.4859 - val_loss: 0.2588 - val_dice_coef: 0.6072 - val_iou_seg: 0.5502
#
# Epoch 00156: val_loss did not improve from 0.23772
# Epoch 157/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2300 - dice_coef: 0.6658 - iou_seg: 0.4867 - val_loss: 0.2449 - val_dice_coef: 0.6386 - val_iou_seg: 0.5183
#
# Epoch 00157: val_loss did not improve from 0.23772
# Epoch 158/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2275 - dice_coef: 0.6728 - iou_seg: 0.4821 - val_loss: 0.2483 - val_dice_coef: 0.6315 - val_iou_seg: 0.5275
#
# Epoch 00158: val_loss did not improve from 0.23772
# Epoch 159/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2238 - dice_coef: 0.6792 - iou_seg: 0.4740 - val_loss: 0.2561 - val_dice_coef: 0.6143 - val_iou_seg: 0.5443
#
# Epoch 00159: val_loss did not improve from 0.23772
# Epoch 160/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2252 - dice_coef: 0.6762 - iou_seg: 0.4766 - val_loss: 0.2488 - val_dice_coef: 0.6275 - val_iou_seg: 0.5301
#
# Epoch 00160: val_loss did not improve from 0.23772
# Epoch 161/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2262 - dice_coef: 0.6752 - iou_seg: 0.4793 - val_loss: 0.2357 - val_dice_coef: 0.6519 - val_iou_seg: 0.5029
#
# Epoch 00161: val_loss improved from 0.23772 to 0.23570, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 162/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2265 - dice_coef: 0.6731 - iou_seg: 0.4794 - val_loss: 0.2512 - val_dice_coef: 0.6176 - val_iou_seg: 0.5374
#
# Epoch 00162: val_loss did not improve from 0.23570
# Epoch 163/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2257 - dice_coef: 0.6758 - iou_seg: 0.4782 - val_loss: 0.2479 - val_dice_coef: 0.6305 - val_iou_seg: 0.5270
#
# Epoch 00163: val_loss did not improve from 0.23570
# Epoch 164/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2262 - dice_coef: 0.6746 - iou_seg: 0.4790 - val_loss: 0.2545 - val_dice_coef: 0.6135 - val_iou_seg: 0.5435
#
# Epoch 00164: val_loss did not improve from 0.23570
# Epoch 165/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2262 - dice_coef: 0.6753 - iou_seg: 0.4792 - val_loss: 0.2487 - val_dice_coef: 0.6308 - val_iou_seg: 0.5270
#
# Epoch 00165: val_loss did not improve from 0.23570
# Epoch 166/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2275 - dice_coef: 0.6718 - iou_seg: 0.4820 - val_loss: 0.2635 - val_dice_coef: 0.5955 - val_iou_seg: 0.5607
#
# Epoch 00166: val_loss did not improve from 0.23570
# Epoch 167/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2323 - dice_coef: 0.6629 - iou_seg: 0.4917 - val_loss: 0.2469 - val_dice_coef: 0.6344 - val_iou_seg: 0.5245
#
# Epoch 00167: val_loss did not improve from 0.23570
# Epoch 168/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2305 - dice_coef: 0.6650 - iou_seg: 0.4874 - val_loss: 0.2382 - val_dice_coef: 0.6502 - val_iou_seg: 0.5055
#
# Epoch 00168: val_loss did not improve from 0.23570
# Epoch 169/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2266 - dice_coef: 0.6752 - iou_seg: 0.4808 - val_loss: 0.2397 - val_dice_coef: 0.6476 - val_iou_seg: 0.5091
#
# Epoch 00169: val_loss did not improve from 0.23570
# Epoch 170/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2241 - dice_coef: 0.6786 - iou_seg: 0.4747 - val_loss: 0.2467 - val_dice_coef: 0.6336 - val_iou_seg: 0.5221
#
# Epoch 00170: val_loss did not improve from 0.23570
# Epoch 171/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.2259 - dice_coef: 0.6759 - iou_seg: 0.4787 - val_loss: 0.2399 - val_dice_coef: 0.6447 - val_iou_seg: 0.5108
#
# Epoch 00171: val_loss did not improve from 0.23570
# Epoch 172/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2284 - dice_coef: 0.6695 - iou_seg: 0.4836 - val_loss: 0.2533 - val_dice_coef: 0.6209 - val_iou_seg: 0.5363
#
# Epoch 00172: val_loss did not improve from 0.23570
# Epoch 173/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2214 - dice_coef: 0.6846 - iou_seg: 0.4689 - val_loss: 0.2470 - val_dice_coef: 0.6346 - val_iou_seg: 0.5237
#
# Epoch 00173: val_loss did not improve from 0.23570
# Epoch 174/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2203 - dice_coef: 0.6866 - iou_seg: 0.4670 - val_loss: 0.2478 - val_dice_coef: 0.6304 - val_iou_seg: 0.5262
#
# Epoch 00174: val_loss did not improve from 0.23570
# Epoch 175/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2243 - dice_coef: 0.6778 - iou_seg: 0.4752 - val_loss: 0.2443 - val_dice_coef: 0.6372 - val_iou_seg: 0.5196
#
# Epoch 00175: val_loss did not improve from 0.23570
# Epoch 176/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2304 - dice_coef: 0.6660 - iou_seg: 0.4875 - val_loss: 0.2407 - val_dice_coef: 0.6448 - val_iou_seg: 0.5105
#
# Epoch 00176: val_loss did not improve from 0.23570
# Epoch 177/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.2246 - dice_coef: 0.6768 - iou_seg: 0.4755 - val_loss: 0.2468 - val_dice_coef: 0.6318 - val_iou_seg: 0.5236
#
# Epoch 00177: val_loss did not improve from 0.23570
# Epoch 178/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2237 - dice_coef: 0.6800 - iou_seg: 0.4739 - val_loss: 0.2391 - val_dice_coef: 0.6482 - val_iou_seg: 0.5081
#
# Epoch 00178: val_loss did not improve from 0.23570
# Epoch 179/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.2283 - dice_coef: 0.6712 - iou_seg: 0.4836 - val_loss: 0.2495 - val_dice_coef: 0.6285 - val_iou_seg: 0.5292
#
# Epoch 00179: val_loss did not improve from 0.23570
# Epoch 180/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2212 - dice_coef: 0.6847 - iou_seg: 0.4687 - val_loss: 0.2470 - val_dice_coef: 0.6303 - val_iou_seg: 0.5263
#
# Epoch 00180: val_loss did not improve from 0.23570
# Epoch 181/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2207 - dice_coef: 0.6855 - iou_seg: 0.4676 - val_loss: 0.2437 - val_dice_coef: 0.6374 - val_iou_seg: 0.5190
#
# Epoch 00181: val_loss did not improve from 0.23570
# Epoch 182/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2231 - dice_coef: 0.6809 - iou_seg: 0.4730 - val_loss: 0.2472 - val_dice_coef: 0.6310 - val_iou_seg: 0.5242
#
# Epoch 00182: val_loss did not improve from 0.23570
# Epoch 183/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2208 - dice_coef: 0.6844 - iou_seg: 0.4677 - val_loss: 0.2689 - val_dice_coef: 0.5875 - val_iou_seg: 0.5706
#
# Epoch 00183: val_loss did not improve from 0.23570
# Epoch 184/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2234 - dice_coef: 0.6772 - iou_seg: 0.4727 - val_loss: 0.2641 - val_dice_coef: 0.5994 - val_iou_seg: 0.5605
#
# Epoch 00184: val_loss did not improve from 0.23570
# Epoch 185/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2192 - dice_coef: 0.6881 - iou_seg: 0.4645 - val_loss: 0.2319 - val_dice_coef: 0.6591 - val_iou_seg: 0.4961
#
# Epoch 00185: val_loss improved from 0.23570 to 0.23192, saving model to models\bactunet_3frame_dice_noEmpty.hdf5
# Epoch 186/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2254 - dice_coef: 0.6761 - iou_seg: 0.4774 - val_loss: 0.2463 - val_dice_coef: 0.6323 - val_iou_seg: 0.5247
#
# Epoch 00186: val_loss did not improve from 0.23192
# Epoch 187/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.2241 - dice_coef: 0.6782 - iou_seg: 0.4745 - val_loss: 0.2539 - val_dice_coef: 0.6181 - val_iou_seg: 0.5403
#
# Epoch 00187: val_loss did not improve from 0.23192
# Epoch 188/2000
# 530/530 [==============================] - 403s 762ms/step - loss: 0.2235 - dice_coef: 0.6797 - iou_seg: 0.4734 - val_loss: 0.2409 - val_dice_coef: 0.6427 - val_iou_seg: 0.5128
#
# Epoch 00188: val_loss did not improve from 0.23192
# Epoch 189/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.2188 - dice_coef: 0.6882 - iou_seg: 0.4632 - val_loss: 0.2392 - val_dice_coef: 0.6483 - val_iou_seg: 0.5073
#
# Epoch 00189: val_loss did not improve from 0.23192
# Epoch 190/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2201 - dice_coef: 0.6873 - iou_seg: 0.4665 - val_loss: 0.2347 - val_dice_coef: 0.6548 - val_iou_seg: 0.4998
#
# Epoch 00190: val_loss did not improve from 0.23192
# Epoch 191/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2251 - dice_coef: 0.6769 - iou_seg: 0.4771 - val_loss: 0.2454 - val_dice_coef: 0.6336 - val_iou_seg: 0.5211
#
# Epoch 00191: val_loss did not improve from 0.23192
# Epoch 192/2000
# 530/530 [==============================] - 403s 761ms/step - loss: 0.2191 - dice_coef: 0.6882 - iou_seg: 0.4642 - val_loss: 0.2437 - val_dice_coef: 0.6387 - val_iou_seg: 0.5162
#
# ...
#
# Epoch 00580: val_loss did not improve from 0.21283
# Epoch 581/2000
# 530/530 [==============================] - 404s 762ms/step - loss: 0.1634 - dice_coef: 0.7880 - iou_seg: 0.3441 - val_loss: 0.2227 - val_dice_coef: 0.6780 - val_iou_seg: 0.4755
#
# Epoch 00581: val_loss did not improve from 0.21283
# Epoch 582/2000
# 530/530 [==============================] - 405s 765ms/step - loss: 0.1619 - dice_coef: 0.7908 - iou_seg: 0.3409 - val_loss: 0.2223 - val_dice_coef: 0.6791 - val_iou_seg: 0.4740
#
# Epoch 00582: val_loss did not improve from 0.21283
# Epoch 583/2000
# 530/530 [==============================] - 405s 765ms/step - loss: 0.1682 - dice_coef: 0.7791 - iou_seg: 0.3544 - val_loss: 0.2229 - val_dice_coef: 0.6805 - val_iou_seg: 0.4765
#
# Epoch 00583: val_loss did not improve from 0.21283
# Epoch 584/2000
# 530/530 [==============================] - 407s 768ms/step - loss: 0.1662 - dice_coef: 0.7833 - iou_seg: 0.3503 - val_loss: 0.2183 - val_dice_coef: 0.6875 - val_iou_seg: 0.4648
#
# Epoch 00584: val_loss did not improve from 0.21283
# Epoch 585/2000
# 530/530 [==============================] - 405s 765ms/step - loss: 0.1819 - dice_coef: 0.7552 - iou_seg: 0.3844 - val_loss: 0.2174 - val_dice_coef: 0.6909 - val_iou_seg: 0.4611
#
# Epoch 00585: val_loss did not improve from 0.21283
# Epoch 586/2000
# 530/530 [==============================] - 406s 765ms/step - loss: 0.1627 - dice_coef: 0.7892 - iou_seg: 0.3429 - val_loss: 0.2167 - val_dice_coef: 0.6865 - val_iou_seg: 0.4638
#
# Epoch 00586: val_loss did not improve from 0.21283
# Epoch 587/2000
# 530/530 [==============================] - 404s 763ms/step - loss: 0.1694 - dice_coef: 0.7767 - iou_seg: 0.3568 - val_loss: 0.2211 - val_dice_coef: 0.6838 - val_iou_seg: 0.4712
#
# Epoch 00587: val_loss did not improve from 0.21283
# Epoch 588/2000
# 530/530 [==============================] - 407s 767ms/step - loss: 0.1632 - dice_coef: 0.7873 - iou_seg: 0.3432 - val_loss: 0.2160 - val_dice_coef: 0.6955 - val_iou_seg: 0.4573
#
# Epoch 00588: val_loss did not improve from 0.21283
# Epoch 589/2000
# 530/530 [==============================] - 412s 777ms/step - loss: 0.1604 - dice_coef: 0.7923 - iou_seg: 0.3373 - val_loss: 0.2232 - val_dice_coef: 0.6773 - val_iou_seg: 0.4748
#
# Epoch 00589: val_loss did not improve from 0.21283
# Epoch 590/2000
# 530/530 [==============================] - 410s 774ms/step - loss: 0.1657 - dice_coef: 0.7829 - iou_seg: 0.3491 - val_loss: 0.2181 - val_dice_coef: 0.6864 - val_iou_seg: 0.4657
#
# Epoch 00590: val_loss did not improve from 0.21283
# Epoch 591/2000
# 530/530 [==============================] - 410s 774ms/step - loss: 0.1713 - dice_coef: 0.7729 - iou_seg: 0.3607 - val_loss: 0.2178 - val_dice_coef: 0.6843 - val_iou_seg: 0.4662
#
# Epoch 00591: val_loss did not improve from 0.21283
# Epoch 592/2000
# 530/530 [==============================] - 412s 778ms/step - loss: 0.1642 - dice_coef: 0.7867 - iou_seg: 0.3460 - val_loss: 0.2210 - val_dice_coef: 0.6827 - val_iou_seg: 0.4708
#
# Epoch 00592: val_loss did not improve from 0.21283
# Epoch 593/2000
# 530/530 [==============================] - 413s 780ms/step - loss: 0.1624 - dice_coef: 0.7899 - iou_seg: 0.3420 - val_loss: 0.2217 - val_dice_coef: 0.6793 - val_iou_seg: 0.4721
#
# Epoch 00593: val_loss did not improve from 0.21283
# Epoch 594/2000
# 530/530 [==============================] - 409s 772ms/step - loss: 0.1739 - dice_coef: 0.7692 - iou_seg: 0.3667 - val_loss: 0.2199 - val_dice_coef: 0.6870 - val_iou_seg: 0.4668
#
# Epoch 00594: val_loss did not improve from 0.21283
# Epoch 595/2000
# 530/530 [==============================] - 408s 771ms/step - loss: 0.1601 - dice_coef: 0.7930 - iou_seg: 0.3372 - val_loss: 0.2233 - val_dice_coef: 0.6773 - val_iou_seg: 0.4763
# Epoch 00595: val_loss did not improve from 0.21283
# Epoch 596/2000
# 530/530 [==============================] - 408s 770ms/step - loss: 0.1647 - dice_coef: 0.7851 - iou_seg: 0.3466 - val_loss: 0.2289 - val_dice_coef: 0.6684 - val_iou_seg: 0.4852
#
# Epoch 00596: val_loss did not improve from 0.21283
# Epoch 597/2000
# 530/530 [==============================] - 413s 779ms/step - loss: 0.1640 - dice_coef: 0.7862 - iou_seg: 0.3451 - val_loss: 0.2252 - val_dice_coef: 0.6731 - val_iou_seg: 0.4801
#
# Epoch 00597: val_loss did not improve from 0.21283
# Epoch 598/2000
# 530/530 [==============================] - 410s 773ms/step - loss: 0.1633 - dice_coef: 0.7866 - iou_seg: 0.3440 - val_loss: 0.2163 - val_dice_coef: 0.6922 - val_iou_seg: 0.4610
#
# Epoch 00598: val_loss did not improve from 0.21283
# Epoch 599/2000
# 530/530 [==============================] - 408s 769ms/step - loss: 0.1670 - dice_coef: 0.7817 - iou_seg: 0.3520 - val_loss: 0.2294 - val_dice_coef: 0.6649 - val_iou_seg: 0.4896
#
# Epoch 00599: val_loss did not improve from 0.21283
# Epoch 600/2000
# 530/530 [==============================] - 409s 772ms/step - loss: 0.1698 - dice_coef: 0.7757 - iou_seg: 0.3577 - val_loss: 0.2215 - val_dice_coef: 0.6800 - val_iou_seg: 0.4723
#
# Epoch 00600: val_loss did not improve from 0.21283
# Epoch 601/2000
# 530/530 [==============================] - 409s 773ms/step - loss: 0.1637 - dice_coef: 0.7865 - iou_seg: 0.3443 - val_loss: 0.2173 - val_dice_coef: 0.6887 - val_iou_seg: 0.4643
#
# Epoch 00601: val_loss did not improve from 0.21283
# Epoch 602/2000
# 530/530 [==============================] - 409s 772ms/step - loss: 0.1617 - dice_coef: 0.7912 - iou_seg: 0.3407 - val_loss: 0.2233 - val_dice_coef: 0.6782 - val_iou_seg: 0.4764
#
# Epoch 00602: val_loss did not improve from 0.21283
# Epoch 603/2000
# 530/530 [==============================] - 409s 771ms/step - loss: 0.1626 - dice_coef: 0.7882 - iou_seg: 0.3423 - val_loss: 0.2265 - val_dice_coef: 0.6708 - val_iou_seg: 0.4832
#
# Epoch 00603: val_loss did not improve from 0.21283
# Epoch 604/2000
# 530/530 [==============================] - 410s 775ms/step - loss: 0.1617 - dice_coef: 0.7906 - iou_seg: 0.3406 - val_loss: 0.2269 - val_dice_coef: 0.6676 - val_iou_seg: 0.4852
#
# Epoch 00604: val_loss did not improve from 0.21283
# Epoch 605/2000
# 530/530 [==============================] - 410s 774ms/step - loss: 0.1651 - dice_coef: 0.7851 - iou_seg: 0.3481 - val_loss: 0.2221 - val_dice_coef: 0.6791 - val_iou_seg: 0.4736
#
# Epoch 00605: val_loss did not improve from 0.21283
# Epoch 606/2000
# 530/530 [==============================] - 410s 774ms/step - loss: 0.1626 - dice_coef: 0.7892 - iou_seg: 0.3424 - val_loss: 0.2229 - val_dice_coef: 0.6759 - val_iou_seg: 0.4767
#
# Epoch 00606: val_loss did not improve from 0.21283
# Epoch 607/2000
# 530/530 [==============================] - 408s 770ms/step - loss: 0.1656 - dice_coef: 0.7830 - iou_seg: 0.3484 - val_loss: 0.2222 - val_dice_coef: 0.6773 - val_iou_seg: 0.4751
#
# Epoch 00607: val_loss did not improve from 0.21283
# Epoch 608/2000
# 530/530 [==============================] - 409s 773ms/step - loss: 0.1585 - dice_coef: 0.7957 - iou_seg: 0.3333 - val_loss: 0.2206 - val_dice_coef: 0.6836 - val_iou_seg: 0.4689
#
# Epoch 00608: val_loss did not improve from 0.21283
# Epoch 609/2000
# 530/530 [==============================] - 411s 777ms/step - loss: 0.1638 - dice_coef: 0.7865 - iou_seg: 0.3446 - val_loss: 0.2253 - val_dice_coef: 0.6759 - val_iou_seg: 0.4783
#
# Epoch 00609: val_loss did not improve from 0.21283
# Epoch 610/2000
# 530/530 [==============================] - 411s 775ms/step - loss: 0.1622 - dice_coef: 0.7891 - iou_seg: 0.3412 - val_loss: 0.2214 - val_dice_coef: 0.6767 - val_iou_seg: 0.4731
#
# Epoch 00610: val_loss did not improve from 0.21283
# Epoch 611/2000
# 530/530 [==============================] - 408s 770ms/step - loss: 0.1602 - dice_coef: 0.7936 - iou_seg: 0.3374 - val_loss: 0.2180 - val_dice_coef: 0.6837 - val_iou_seg: 0.4677
#
# Epoch 00611: val_loss did not improve from 0.21283
# Epoch 612/2000
# 530/530 [==============================] - 409s 772ms/step - loss: 0.1592 - dice_coef: 0.7954 - iou_seg: 0.3353 - val_loss: 0.2204 - val_dice_coef: 0.6867 - val_iou_seg: 0.4673
#
# Epoch 00612: val_loss did not improve from 0.21283
# Epoch 613/2000
# 530/530 [==============================] - 410s 773ms/step - loss: 0.1646 - dice_coef: 0.7856 - iou_seg: 0.3467 - val_loss: 0.2399 - val_dice_coef: 0.6430 - val_iou_seg: 0.5109
#
# Epoch 00613: val_loss did not improve from 0.21283
# Epoch 614/2000
# 530/530 [==============================] - 410s 773ms/step - loss: 0.1629 - dice_coef: 0.7888 - iou_seg: 0.3430 - val_loss: 0.2226 - val_dice_coef: 0.6810 - val_iou_seg: 0.4738
#
# Epoch 00614: val_loss did not improve from 0.21283
# Epoch 615/2000
# 530/530 [==============================] - 409s 772ms/step - loss: 0.1583 - dice_coef: 0.7960 - iou_seg: 0.3330 - val_loss: 0.2186 - val_dice_coef: 0.6873 - val_iou_seg: 0.4653
#
# Epoch 00615: val_loss did not improve from 0.21283
# Epoch 616/2000
# 530/530 [==============================] - 410s 774ms/step - loss: 0.1666 - dice_coef: 0.7822 - iou_seg: 0.3512 - val_loss: 0.2202 - val_dice_coef: 0.6844 - val_iou_seg: 0.4688
#
# Epoch 00616: val_loss did not improve from 0.21283
# Epoch 617/2000
# 530/530 [==============================] - 411s 775ms/step - loss: 0.1639 - dice_coef: 0.7868 - iou_seg: 0.3450 - val_loss: 0.2232 - val_dice_coef: 0.6784 - val_iou_seg: 0.4758
#
# Epoch 00617: val_loss did not improve from 0.21283
# Epoch 618/2000
# 530/530 [==============================] - 411s 776ms/step - loss: 0.1608 - dice_coef: 0.7927 - iou_seg: 0.3386 - val_loss: 0.2271 - val_dice_coef: 0.6711 - val_iou_seg: 0.4828
#
# Epoch 00618: val_loss did not improve from 0.21283
# Epoch 619/2000
# 530/530 [==============================] - 407s 768ms/step - loss: 0.1646 - dice_coef: 0.7857 - iou_seg: 0.3466 - val_loss: 0.2231 - val_dice_coef: 0.6792 - val_iou_seg: 0.4738
#
# Epoch 00619: val_loss did not improve from 0.21283
# Epoch 620/2000
# 530/530 [==============================] - 410s 774ms/step - loss: 0.1666 - dice_coef: 0.7811 - iou_seg: 0.3506 - val_loss: 0.2268 - val_dice_coef: 0.6699 - val_iou_seg: 0.4849
#
# Epoch 00620: val_loss did not improve from 0.21283
# Epoch 621/2000
# 530/530 [==============================] - 410s 773ms/step - loss: 0.1615 - dice_coef: 0.7905 - iou_seg: 0.3398 - val_loss: 0.2366 - val_dice_coef: 0.6538 - val_iou_seg: 0.5033
#
# Epoch 00621: val_loss did not improve from 0.21283
# Epoch 622/2000
# 530/530 [==============================] - 422s 796ms/step - loss: 0.1642 - dice_coef: 0.7866 - iou_seg: 0.3459 - val_loss: 0.2246 - val_dice_coef: 0.6770 - val_iou_seg: 0.4771
#
# Epoch 00622: val_loss did not improve from 0.21283
# Epoch 623/2000
# 530/530 [==============================] - 425s 803ms/step - loss: 0.1628 - dice_coef: 0.7893 - iou_seg: 0.3430 - val_loss: 0.2263 - val_dice_coef: 0.6721 - val_iou_seg: 0.4815
#
# Epoch 00623: val_loss did not improve from 0.21283
# Epoch 624/2000
# 530/530 [==============================] - 424s 800ms/step - loss: 0.1609 - dice_coef: 0.7923 - iou_seg: 0.3385 - val_loss: 0.2558 - val_dice_coef: 0.6128 - val_iou_seg: 0.5460
#
# Epoch 00624: val_loss did not improve from 0.21283
# Epoch 625/2000
# 530/530 [==============================] - 418s 789ms/step - loss: 0.1602 - dice_coef: 0.7925 - iou_seg: 0.3368 - val_loss: 0.2197 - val_dice_coef: 0.6789 - val_iou_seg: 0.4715
#
# Epoch 00625: val_loss did not improve from 0.21283
# Epoch 626/2000
# 530/530 [==============================] - 413s 780ms/step - loss: 0.1666 - dice_coef: 0.7809 - iou_seg: 0.3508 - val_loss: 0.2170 - val_dice_coef: 0.6918 - val_iou_seg: 0.4597
#
# Epoch 00626: val_loss did not improve from 0.21283
# Epoch 627/2000
# 530/530 [==============================] - 413s 780ms/step - loss: 0.1609 - dice_coef: 0.7923 - iou_seg: 0.3389 - val_loss: 0.2175 - val_dice_coef: 0.6893 - val_iou_seg: 0.4624
#
# Epoch 00627: val_loss did not improve from 0.21283
# Epoch 628/2000
# 530/530 [==============================] - 415s 784ms/step - loss: 0.1587 - dice_coef: 0.7958 - iou_seg: 0.3339 - val_loss: 0.2193 - val_dice_coef: 0.6842 - val_iou_seg: 0.4690
#
# Epoch 00628: val_loss did not improve from 0.21283
# Epoch 629/2000
# 530/530 [==============================] - 423s 799ms/step - loss: 0.1607 - dice_coef: 0.7922 - iou_seg: 0.3382 - val_loss: 0.2256 - val_dice_coef: 0.6719 - val_iou_seg: 0.4820
#
# Epoch 00629: val_loss did not improve from 0.21283
# Epoch 630/2000
# 530/530 [==============================] - 423s 799ms/step - loss: 0.1661 - dice_coef: 0.7831 - iou_seg: 0.3498 - val_loss: 0.2173 - val_dice_coef: 0.6876 - val_iou_seg: 0.4639
#
# Epoch 00630: val_loss did not improve from 0.21283
# Epoch 631/2000
# 530/530 [==============================] - 425s 802ms/step - loss: 0.1586 - dice_coef: 0.7962 - iou_seg: 0.3337 - val_loss: 0.2210 - val_dice_coef: 0.6856 - val_iou_seg: 0.4674
#
# Epoch 00631: val_loss did not improve from 0.21283
# Epoch 632/2000
# 530/530 [==============================] - 1074s 2s/step - loss: 0.1579 - dice_coef: 0.7963 - iou_seg: 0.3323 - val_loss: 0.2262 - val_dice_coef: 0.6724 - val_iou_seg: 0.4815
#
# Epoch 00632: val_loss did not improve from 0.21283
# Epoch 633/2000
# 530/530 [==============================] - 2375s 4s/step - loss: 0.1593 - dice_coef: 0.7944 - iou_seg: 0.3351 - val_loss: 0.2204 - val_dice_coef: 0.6834 - val_iou_seg: 0.4686
#
# Epoch 00633: val_loss did not improve from 0.21283
# Epoch 634/2000
# 530/530 [==============================] - 2399s 5s/step - loss: 0.1651 - dice_coef: 0.7847 - iou_seg: 0.3480 - val_loss: 0.2420 - val_dice_coef: 0.6380 - val_iou_seg: 0.5153
#
# Epoch 00634: val_loss did not improve from 0.21283
# Epoch 635/2000
# 530/530 [==============================] - 2049s 4s/step - loss: 0.1617 - dice_coef: 0.7899 - iou_seg: 0.3400 - val_loss: 0.2190 - val_dice_coef: 0.6867 - val_iou_seg: 0.4674
#
# Epoch 00635: val_loss did not improve from 0.21283
# Epoch 636/2000
# 530/530 [==============================] - 410s 774ms/step - loss: 0.1613 - dice_coef: 0.7911 - iou_seg: 0.3398 - val_loss: 0.2285 - val_dice_coef: 0.6692 - val_iou_seg: 0.4854
#
# Epoch 00636: val_loss did not improve from 0.21283
# Epoch 637/2000
# 530/530 [==============================] - 407s 768ms/step - loss: 0.1574 - dice_coef: 0.7982 - iou_seg: 0.3310 - val_loss: 0.2228 - val_dice_coef: 0.6790 - val_iou_seg: 0.4743
#
# Epoch 00637: val_loss did not improve from 0.21283
# Epoch 638/2000
# 530/530 [==============================] - 406s 766ms/step - loss: 0.1620 - dice_coef: 0.7889 - iou_seg: 0.3408 - val_loss: 0.2273 - val_dice_coef: 0.6665 - val_iou_seg: 0.4851
#
# Epoch 00638: val_loss did not improve from 0.21283
# Epoch 639/2000
# 530/530 [==============================] - 417s 788ms/step - loss: 0.1609 - dice_coef: 0.7917 - iou_seg: 0.3389 - val_loss: 0.2306 - val_dice_coef: 0.6591 - val_iou_seg: 0.4938
#
# Epoch 00639: val_loss did not improve from 0.21283
# Epoch 640/2000
# 530/530 [==============================] - 426s 804ms/step - loss: 0.1580 - dice_coef: 0.7970 - iou_seg: 0.3325 - val_loss: 0.2247 - val_dice_coef: 0.6754 - val_iou_seg: 0.4791
#
# Epoch 00640: val_loss did not improve from 0.21283
# Epoch 641/2000
# 530/530 [==============================] - 425s 803ms/step - loss: 0.1621 - dice_coef: 0.7901 - iou_seg: 0.3415 - val_loss: 0.2327 - val_dice_coef: 0.6636 - val_iou_seg: 0.4948
#
# Epoch 00641: val_loss did not improve from 0.21283
# Epoch 642/2000
# 530/530 [==============================] - 417s 787ms/step - loss: 0.1610 - dice_coef: 0.7915 - iou_seg: 0.3387 - val_loss: 0.2290 - val_dice_coef: 0.6722 - val_iou_seg: 0.4860
#
# Epoch 00642: val_loss did not improve from 0.21283
# Epoch 643/2000
# 530/530 [==============================] - 414s 781ms/step - loss: 0.1590 - dice_coef: 0.7954 - iou_seg: 0.3346 - val_loss: 0.2235 - val_dice_coef: 0.6762 - val_iou_seg: 0.4766
#
# Epoch 00643: val_loss did not improve from 0.21283
# Epoch 644/2000
# 530/530 [==============================] - 413s 780ms/step - loss: 0.1549 - dice_coef: 0.8024 - iou_seg: 0.3257 - val_loss: 0.2198 - val_dice_coef: 0.6810 - val_iou_seg: 0.4708
#
# Epoch 00644: val_loss did not improve from 0.21283
# Epoch 645/2000
# 530/530 [==============================] - 413s 780ms/step - loss: 0.1596 - dice_coef: 0.7945 - iou_seg: 0.3360 - val_loss: 0.2350 - val_dice_coef: 0.6561 - val_iou_seg: 0.4996
#
# Epoch 00645: val_loss did not improve from 0.21283
# Epoch 00645: early stopping

# %%
model.save(r"models/bactunet_noEmpty_final_dice.hdf5") 
#model.load_weights(r"models/bactunet_3frame_local_dice.hdf5")

# %%
# ##################################
# #IOU
y_pred = model.predict(X_test)
IOUs = []
dices = []
thresh = []

for threshold in range(0, 11):
  threshold = threshold/10
  y_pred_thresholded = y_pred > threshold
  intersection = np.logical_and(y_test, y_pred_thresholded)
  union = np.logical_or(y_test, y_pred_thresholded)
  iou_score = np.sum(intersection) / np.sum(union)
  dice_c = 0#losses.dice_coef(y_test, y_pred)
  print("IoU socre is: ", round(iou_score, 4), "Dice coeff is: ", round(dice_c, 4),"at threshold: ", threshold)
  IOUs.append(iou_score)
  thresh.append(threshold)
  dices.append(dice_c)

#plot IOUs vs threshold
plt.plot(thresh, IOUs, 'r', label='IOU')
plt.plot(thresh, dices, 'b', label='Dice coeff')
plt.title('IOU & dice vs threshold')
plt.xlabel('Threshold')
plt.ylabel('IOU')
plt.show()
# Out:
# IoU socre is:  0.0047 Dice coeff is:  0 at threshold:  0.0
# IoU socre is:  0.5223 Dice coeff is:  0 at threshold:  0.1
# IoU socre is:  0.5225 Dice coeff is:  0 at threshold:  0.2
# IoU socre is:  0.5227 Dice coeff is:  0 at threshold:  0.3
# IoU socre is:  0.5229 Dice coeff is:  0 at threshold:  0.4
# IoU socre is:  0.523 Dice coeff is:  0 at threshold:  0.5
# IoU socre is:  0.5231 Dice coeff is:  0 at threshold:  0.6
# IoU socre is:  0.5233 Dice coeff is:  0 at threshold:  0.7
# IoU socre is:  0.5234 Dice coeff is:  0 at threshold:  0.8
# IoU socre is:  0.5237 Dice coeff is:  0 at threshold:  0.9
# IoU socre is:  0.0 Dice coeff is:  0 at threshold:  1.0

# %%
#######################################################################
#Predict on a few images
#model = get_model()
#model.load_weights('mitochondria_50_plus_100_epochs.hdf5') #Trained for 50 epochs and then additional 100
#model.load_weights('mitochondria_gpu_tf1.4.hdf5')  #Trained for 50 epochs¨
#import pickle
#with open("/content/gdrive/MyDrive/Colab Notebooks/BT0403/model_folder/bactunet_3frame_25ep_history") as fh:
#    history = pickle.load(fh)

idx=random.randint(0, (len(X_test)))

plt.figure(figsize=(16, 8))
plt.subplot(131)
plt.title('Testing Image')
plt.imshow(X_test[idx, 1, :, : ])
plt.subplot(132)
plt.title('Testing Label')
plt.imshow(y_test[idx, 0, : , :])
plt.subplot(133)
plt.title('Prediction on test image')
plt.imshow(y_pred[idx, 0, :, :])

plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['dice_coef']
#acc = history.history['accuracy']
val_acc = history.history['val_dice_coef']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import math 
from patchify import unpatchify

#######
#THERE IS A BUG HERE!!! FIX PREDICTION AND UNPATCHING


def _createOutArr(shape, nrows, ncols, nchannels):
    out_height = int(nrows * shape[-2])
    out_width = int(ncols * shape[-1])
    out_frames = int(shape[0] / (nrows * ncols))
    outshape = (out_frames, nchannels, out_height, out_width)
    out_arr = np.empty(outshape, dtype=np.float32)

    return out_arr

def unpatcher(arr, nrows, ncols, nchannels=1):
    out_arr = _createOutArr(arr.shape, nrows, ncols, nchannels)
    patch_h = arr.shape[-2]
    patch_w = arr.shape[-1]
    n = 0
    for frame in range(out_arr.shape[0]):
        for i in range(nrows):
            for j in range(ncols):
                y = patch_h * i
                x = patch_w * j
                out_arr[frame, :, y:y+patch_h, x:x+patch_w] = arr[n]
                n += 1

    return out_arr

#load unseen data

validation_image_directory = r"C:\Users\analyst\Documents\Python Scripts\BactUnet\Bactnet\Training data\stacks\predict"
result_folder = r"C:\Users\analyst\Documents\Python Scripts\BactUnet\_results"

val_image_dataset = []
val_mask_dataset = []
pred_mask_dataset = []

images = os.listdir(validation_image_directory)

for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'tif'):
        
        image = tiff.imread(os.path.join(validation_image_directory, image_name))
        original_shape = image.shape
        patch = patch_stack(image, SIZE)
        
        patch = normalizePercentile(patch, 0.1, 99.9, clip=True)
        pred_mask_patch = model.predict(patch)
        print(image_name, original_shape, patch.shape, pred_mask_patch.shape)
        #pred_mask_patch = pred_mask_patch[:, 0, :,:]
        image = np.expand_dims(patch[:, 1, :,:], axis=1)
        patch = np.concatenate((image, pred_mask_patch), axis=1)
        unpatched = unpatcher(patch, 8, 8, 2)
        print(patch.shape)
        tiff.imwrite(os.path.join(result_folder, image_name), unpatched, imagej=True, resolution=(1./2.6755, 1./2.6755),
                      metadata={'unit': 'um', 'finterval': 15,
                                'axes': 'TCYX'})
        
        #pred_mask = unpatch_stack(pred_mask_patch, original_shape)
        #tiff.imsave(os.path.join(result_folder, image_name), pred_mask_patch)
        #val_image_dataset.append(image)
        #pred_mask_dataset.append(pred_mask)
# Out:
# BT0398_210.tif (11, 2304, 2304) (576, 3, 288, 288) (576, 1, 288, 288)
# (576, 2, 288, 288)
# BT403_013.tif (12, 2304, 2304) (640, 3, 288, 288) (640, 1, 288, 288)
# (640, 2, 288, 288)
# BT403_216.tif (12, 2304, 2304) (640, 3, 288, 288) (640, 1, 288, 288)
# (640, 2, 288, 288)
# BT404_001.tif (12, 2304, 2304) (640, 3, 288, 288) (640, 1, 288, 288)
# (640, 2, 288, 288)

# %%
#Let's try the full movies

image_directory = r"C:\Users\analyst\Documents\Python Scripts\BactUnet\Bactnet"
result_folder = r"C:\Users\analyst\Documents\Python Scripts\BactUnet\_results"
filelist = []

for dir in os.listdir(image_directory):
    for file in os.listdir(os.path.join(image_directory, dir)):
        if ".tif" in file:
            loadme = os.path.join(image_directory, dir, file)
            image = tiff.imread(loadme)
            original_shape = image.shape
            patch = patch_stack(image, SIZE)
            patchlist = np.split(patch, 238)
            
            for i, p in enumerate(patchlist):
                p = normalizePercentile(p, 0.1, 99.9, clip=True)
                pred_mask_patch = model.predict(p)
                unpatched = unpatcher(pred_mask_patch, 8, 8, 1)
                #unpatched = unpatched.astype('uint8')
                savename = file.split(".")[0]+ "_" + str(i+1) + ".tif"
                print(savename, unpatched.shape)
                tiff.imwrite(os.path.join(result_folder, savename), unpatched, imagej=True, resolution=(1./2.6755, 1./2.6755),
                             metadata={'unit': 'um', 'finterval': 15, 'axes': 'TCYX'})
# Out:
# BT0398_OGM_1.tif (1, 1, 2304, 2304)
# BT0398_OGM_2.tif (1, 1, 2304, 2304)
# BT0398_OGM_3.tif (1, 1, 2304, 2304)
# BT0398_OGM_4.tif (1, 1, 2304, 2304)
# BT0398_OGM_5.tif (1, 1, 2304, 2304)
# BT0398_OGM_6.tif (1, 1, 2304, 2304)
tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_109.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_110.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_111.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_112.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_113.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_114.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_115.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_116.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_117.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_118.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_119.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_120.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_121.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_122.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_123.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_124.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_125.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_126.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_127.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_128.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_129.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_130.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_131.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_132.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_133.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_134.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_135.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_136.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_137.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_138.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_139.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_140.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_141.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_142.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_143.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_144.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_145.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_146.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_147.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_148.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_149.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_150.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_151.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_152.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_153.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_154.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_155.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_156.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_157.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_158.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_159.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_160.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_161.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_162.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_163.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_164.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_165.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_166.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_167.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_168.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_169.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_170.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_171.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_172.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_173.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_174.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_175.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_176.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_177.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_178.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_179.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_180.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_181.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_182.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_183.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_184.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_185.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_186.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_187.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_188.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_189.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_190.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_191.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_192.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_193.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_194.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_195.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_196.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_197.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_198.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_199.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_200.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_201.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_202.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_203.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_204.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_205.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_206.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_207.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_208.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_209.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_210.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_211.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_212.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_213.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_214.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_215.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_216.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_217.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_218.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_219.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_220.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_221.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_222.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_223.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_224.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_225.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_226.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_227.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_228.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_229.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_230.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_231.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_232.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_233.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_234.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_235.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_236.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_237.tif (1, 1, 2304, 2304)
# BT404_ENR+RT_wt_238.tif (1, 1, 2304, 2304)

# %%
loadme = os.path.join(image_directory, fname)
image = tiff.imread(loadme)
original_shape = image.shape
patch = patch_stack(image, SIZE)
print(original_shape, patch.shape)

#split into smaller predictions
patchlist = np.split(patch, 238)
print(patchlist[0].shape)
for i, p in enumerate(patchlist):
    p = normalizePercentile(p, 0.1, 99.9, clip=True)
    pred_mask_patch = model.predict(p)
    unpatched = unpatcher(pred_mask_patch, 8, 8, 1)
    #unpatched = unpatched.astype('uint8')
    savename = "BT404_" + str(i+1) + ".tif"
    print(savename, unpatched.shape)
    tiff.imwrite(os.path.join(result_folder, savename), unpatched, imagej=True, resolution=(1./2.6755, 1./2.6755),
                 metadata={'unit': 'um', 'finterval': 15, 'axes': 'TCYX'})
# Out:
# (240, 2304, 2304) (15232, 3, 288, 288)
# (64, 3, 288, 288)
# BT404_1.tif (1, 1, 2304, 2304)
# BT404_2.tif (1, 1, 2304, 2304)
# BT404_3.tif (1, 1, 2304, 2304)
# BT404_4.tif (1, 1, 2304, 2304)
# BT404_5.tif (1, 1, 2304, 2304)
# BT404_6.tif (1, 1, 2304, 2304)
# BT404_7.tif (1, 1, 2304, 2304)
# BT404_8.tif (1, 1, 2304, 2304)
# BT404_9.tif (1, 1, 2304, 2304)
# BT404_10.tif (1, 1, 2304, 2304)
# BT404_11.tif (1, 1, 2304, 2304)
# BT404_12.tif (1, 1, 2304, 2304)
# BT404_13.tif (1, 1, 2304, 2304)
# BT404_14.tif (1, 1, 2304, 2304)
# BT404_15.tif (1, 1, 2304, 2304)
# BT404_16.tif (1, 1, 2304, 2304)
# BT404_17.tif (1, 1, 2304, 2304)
# BT404_18.tif (1, 1, 2304, 2304)
# BT404_19.tif (1, 1, 2304, 2304)
# BT404_20.tif (1, 1, 2304, 2304)
# BT404_21.tif (1, 1, 2304, 2304)
# BT404_22.tif (1, 1, 2304, 2304)
# BT404_23.tif (1, 1, 2304, 2304)
# BT404_213.tif (1, 1, 2304, 2304)
# BT404_214.tif (1, 1, 2304, 2304)
# BT404_215.tif (1, 1, 2304, 2304)
# BT404_216.tif (1, 1, 2304, 2304)
# BT404_217.tif (1, 1, 2304, 2304)
# BT404_218.tif (1, 1, 2304, 2304)
# BT404_219.tif (1, 1, 2304, 2304)
# BT404_220.tif (1, 1, 2304, 2304)
# BT404_221.tif (1, 1, 2304, 2304)
# BT404_222.tif (1, 1, 2304, 2304)
# BT404_223.tif (1, 1, 2304, 2304)
# BT404_224.tif (1, 1, 2304, 2304)
# BT404_225.tif (1, 1, 2304, 2304)
# BT404_226.tif (1, 1, 2304, 2304)
# BT404_227.tif (1, 1, 2304, 2304)
# BT404_228.tif (1, 1, 2304, 2304)
# BT404_229.tif (1, 1, 2304, 2304)
# BT404_230.tif (1, 1, 2304, 2304)
# BT404_231.tif (1, 1, 2304, 2304)
# BT404_232.tif (1, 1, 2304, 2304)
# BT404_233.tif (1, 1, 2304, 2304)
# BT404_234.tif (1, 1, 2304, 2304)
# BT404_235.tif (1, 1, 2304, 2304)
# BT404_236.tif (1, 1, 2304, 2304)
# BT404_237.tif (1, 1, 2304, 2304)
# BT404_238.tif (1, 1, 2304, 2304)

# %%
for i, layer in enumerate(model.layers):
  if "onv" in layer.name:
    print(i, layer.name, model.layers[i].get_weights()[0].shape)

weights, biases =  model.layers[4].get_weights()
fig1=plt.figure(figsize=(12, 12))


columns = 8 
rows = 8 
n_filters = columns*rows
for i in range(1, n_filters +1):
    f = weights[:, :, (i-1), 0]
    fig1 =plt.subplot(rows, columns, i)
    fig1.set_xticks([])  #Turn off axis
    fig1.set_yticks([])

    #plt.imshow(f[i%3, :, :], cmap='gray')
    plt.imshow(f[:, :], cmap='gray')
    #plt.imshow(f[2, :, :], cmap='gray') #Show only the filters from 0th channel (R)
    #ix += 1
plt.show()
# Out:
# 1 conv2d (3, 3, 3, 64)
# 4 conv2d_1 (3, 3, 64, 64)
# 8 conv2d_2 (3, 3, 64, 128)
# 11 conv2d_3 (3, 3, 128, 128)
# 15 conv2d_4 (3, 3, 128, 256)
# 18 conv2d_5 (3, 3, 256, 256)
# 22 conv2d_6 (3, 3, 256, 512)
# 25 conv2d_7 (3, 3, 512, 512)
# 29 conv2d_8 (3, 3, 512, 1024)
# 32 conv2d_9 (3, 3, 1024, 1024)
# 35 conv2d_transpose (2, 2, 512, 1024)
# 37 conv2d_10 (3, 3, 1024, 512)
# 40 conv2d_11 (3, 3, 512, 512)
# 43 conv2d_transpose_1 (2, 2, 256, 512)
# 45 conv2d_12 (3, 3, 512, 256)
# 48 conv2d_13 (3, 3, 256, 256)
# 51 conv2d_transpose_2 (2, 2, 128, 256)
# 53 conv2d_14 (3, 3, 256, 128)
# 56 conv2d_15 (3, 3, 128, 128)
# 59 conv2d_transpose_3 (2, 2, 64, 128)
# 61 conv2d_16 (3, 3, 128, 64)
# 64 conv2d_17 (3, 3, 64, 64)
# 67 conv2d_18 (1, 1, 64, 1)
