# %%
import tensorflow as tf
from tensorflow import keras

if tf.test.gpu_device_name()=='':
    print('You do not have GPU access.')
    # !nvidia-smi

else:
  print('You have GPU access')
  # !nvidia-smi

# from tensorflow.python.client import device_lib 
# device_lib.list_local_devices()

# print the tensorflow version
print('TensorFlow {}; Keras {}'.format(tf.__version__, keras.__version__))
tf.test.gpu_device_name()
# Out:
# You have GPU access
# Fri Feb 25 16:40:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 471.41       Driver Version: 471.41       CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro P5000       WDDM  | 00000000:91:00.0  On |                  Off |
# | 26%   34C    P8     8W / 180W |  16311MiB / 16384MiB |     11%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1388    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A      3924    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A      4068    C+G   ...nnector\DesktopClient.exe    N/A      |
# |    0   N/A  N/A      6028    C+G   C:\Windows\explorer.exe         N/A      |
# TensorFlow 2.6.0; Keras 2.6.0
# |    0   N/A  N/A      8008    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# '/device:GPU:0'
# |    0   N/A  N/A      8660    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A      9104    C+G   ...ekyb3d8bbwe\YourPhone.exe    N/A      |
# |    0   N/A  N/A      9356    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A     13092    C+G   ...zilla Firefox\firefox.exe    N/A      |
# |    0   N/A  N/A     18452    C+G   ...ffice\program\soffice.bin    N/A      |
# |    0   N/A  N/A     22240    C+G   ...bbwe\Microsoft.Photos.exe    N/A      |
# |    0   N/A  N/A     22608    C+G   ...zilla Firefox\firefox.exe    N/A      |
# |    0   N/A  N/A     28560    C+G   ...wekyb3d8bbwe\Video.UI.exe    N/A      |
# |    0   N/A  N/A     30420    C+G   ...Fiji.app\ImageJ-win64.exe    N/A      |
# |    0   N/A  N/A     55020      C   ...conda3\envs\tf\python.exe    N/A      |
# |    0   N/A  N/A     65036    C+G   ...p-2.9.6\GitHubDesktop.exe    N/A      |
# |    0   N/A  N/A     70488    C+G   ...kyb3d8bbwe\Calculator.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %%
from tensorflow.keras import layers
import os
import tifffile as tiff
import numpy as np
from matplotlib import pyplot as plt
from patchify import patchify
from tensorflow import keras


def patch_image(img, SIZE=288):
    #breaks up image to SIZExSIZE non-overlapping patches, returns reshaped array
    # img.shape = (2304, 2304)
    patches = patchify(img, patch_size=(SIZE, SIZE), step=(SIZE, SIZE))
    #patches.shape = (8, 8, 288, 288)

    #return.shape = (64, 288 ,288)
    return patches.reshape(patches.shape[0]*patches.shape[1], SIZE, SIZE, 1)

def patch_stack(img, SIZE=288, DEPTH=3, STRIDE=1):
    # breaks up image to SIZExSIZE non-overlapping patches, returns reshaped array
    # img.shape = (12, 2304, 2304)
    patches = patchify(img, patch_size=(DEPTH, SIZE, SIZE), step=(STRIDE, SIZE, SIZE))
    # patches.shape = (10, 8, 8, 3, 288, 288)

    # return.shape = (64, 3, 288 ,288)
    return patches.reshape(patches.shape[0] * patches.shape[1] * patches.shape[2], -1,  SIZE, SIZE)


# Normalization functions from Martin Weigert
def normalizePercentile(x, pmin=1, pmax=99.8, axis=None, clip=False, eps=1e-20, dtype=np.float32):
    """This function is adapted from Martin Weigert"""
    """Percentile-based image normalization."""

    mi = np.percentile(x, pmin, axis=axis, keepdims=True)
    ma = np.percentile(x, pmax, axis=axis, keepdims=True)
    return normalize_mi_ma(x, mi, ma, clip=clip, eps=eps, dtype=dtype)


def normalize_mi_ma(x, mi, ma, clip=False, eps=1e-20, dtype=np.float32):  # dtype=np.float32
    """This function is adapted from Martin Weigert"""
    if dtype is not None:
        x = x.astype(dtype, copy=False)
        mi = dtype(mi) if np.isscalar(mi) else mi.astype(dtype, copy=False)
        ma = dtype(ma) if np.isscalar(ma) else ma.astype(dtype, copy=False)
        eps = dtype(eps)

    try:
        import numexpr
        x = numexpr.evaluate("(x - mi) / ( ma - mi + eps )")
    except ImportError:
        x = (x - mi) / (ma - mi + eps)

    if clip:
        x = np.clip(x, 0, 1)

    return x


# Simple normalization to min/max fir the Mask
def normalizeMinMax(x, dtype=np.float32):
    x = x.astype(dtype, copy=False)
    x = (x - np.amin(x)) / (np.amax(x) - np.amin(x))
    return x

def checkEmptyMask(arr):
    #checks if any patches are without masks
    #returns list of indexes where mask is all zeros
    out = []
    for i in range(arr.shape[0]):
        if not arr[i].any():
            out.append(i)

    return out

# %%
def get_model_memory_usage(batch_size, model):
    import numpy as np
    try:
        from keras import backend as K
    except:
        from tensorflow.keras import backend as K

    shapes_mem_count = 0
    internal_model_mem_count = 0
    for l in model.layers:
        layer_type = l.__class__.__name__
        if layer_type == 'Model':
            internal_model_mem_count += get_model_memory_usage(batch_size, l)
        single_layer_mem = 1
        out_shape = l.output_shape
        if type(out_shape) is list:
            out_shape = out_shape[0]
        for s in out_shape:
            if s is None:
                continue
            single_layer_mem *= s
        shapes_mem_count += single_layer_mem

    trainable_count = np.sum([K.count_params(p) for p in model.trainable_weights])
    non_trainable_count = np.sum([K.count_params(p) for p in model.non_trainable_weights])

    number_size = 4.0
    if K.floatx() == 'float16':
        number_size = 2.0
    if K.floatx() == 'float64':
        number_size = 8.0

    total_memory = number_size * (batch_size * shapes_mem_count + trainable_count + non_trainable_count)
    gbytes = np.round(total_memory / (1024.0 ** 3), 3) + internal_model_mem_count
    return gbytes

# %%
train_path = r"Bactnet/Training data/stacks"

batch_size = 16
SIZE = 288
image_dataset = None
mask_dataset = None

def prepare_data(train_path, PATCH_SIZE):
    stacks = os.listdir(os.path.join(train_path, "training_source"))
    image_dataset = None
    mask_dataset = None
    for stack in stacks:
        if (stack.split(".")[-1]=="tif"):
            img = tiff.imread(os.path.join(train_path, "training_source",stack))
            mask = tiff.imread(os.path.join(train_path, "training_target", stack))

            img = patch_stack(img, PATCH_SIZE)
            mask =patch_stack(mask, PATCH_SIZE)
            mask = mask[:, 1, :, :].reshape((mask.shape[0], 1, mask.shape[2], -1))

            #print(stack, img.shape, mask.shape)
            mask = normalizeMinMax(mask)
            not_ok_idxs = checkEmptyMask(mask)
            mask = np.delete(mask, not_ok_idxs, axis=0)
            img = np.delete(img, not_ok_idxs, axis=0)

            img = normalizePercentile(img, 0.1, 99.9, clip=True)

            #print(stack, img.shape, mask.shape)

            if image_dataset is not None:
                image_dataset = np.concatenate((image_dataset, img))

            if mask_dataset is not None:
                mask_dataset = np.concatenate((mask_dataset, mask))

            if image_dataset is None:
                image_dataset = img

            if mask_dataset is None:
                mask_dataset = mask

            #print(image_dataset.shape, mask_dataset.shape)

    return image_dataset, mask_dataset

# %%
image_dataset, mask_dataset = prepare_data(train_path, SIZE)
print(image_dataset.shape, mask_dataset.shape)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size = 0.15, random_state = 8)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1072, 3, 288, 288) (1072, 1, 288, 288)
# (911, 3, 288, 288) (161, 3, 288, 288) (911, 1, 288, 288) (161, 1, 288, 288)

# %%
#Sanity check, view few mages
import random

image_number = random.randint(0, X_test.shape[0])
plt.figure(figsize=(12, 6))
plt.subplot(231)
plt.imshow(X_test[image_number, 0, :, :])
plt.subplot(232)
plt.imshow(X_test[image_number, 1, :, :])
plt.subplot(233)
plt.imshow(X_test[image_number, 2, :, :])
plt.subplot(235)
plt.imshow(y_test[image_number, 0, :, :])
plt.show()

###############################################################

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.layers import Activation, MaxPool2D, Concatenate


def conv_block(input, num_filters):
    t = Conv2D(num_filters, 3, padding="same",  data_format="channels_first", activation='relu')(input)
    t = BatchNormalization()(t)
    t = Dropout(0.1)(t)
    t = Conv2D(num_filters, 3, padding="same",  data_format="channels_first", activation='relu')(t)
    t = BatchNormalization()(t)
    t = Dropout(0.1)(t)
    return t

#Encoder block: Conv block followed by maxpooling

def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = MaxPool2D((2, 2), data_format="channels_first")(x)
    return x, p

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same", data_format="channels_first")(input)
    x = Concatenate(axis=1)([x, skip_features])
    x = conv_block(x, num_filters)
    return x

#Build Unet using the blocks
def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024) #Bridge

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid", data_format="channels_first")(d4)  #Binary (can be multiclass)

    model = Model(inputs, outputs, name="U-Net")
    return model

# %%
keras.backend.clear_session() # Free up RAM in case the model definition cells were run multiple times


#from keras_unet_collection import models
from keras_unet_collection import losses


# Build model
def hybrid_loss(y_true, y_pred):

    loss_focal = losses.focal_tversky(y_true, y_pred, alpha=0.5, gamma=4/3)
    loss_iou = losses.iou_seg(y_true, y_pred)
    
    # (x) 
    #loss_ssim = losses.ms_ssim(y_true, y_pred, max_val=1.0, filter_size=4)
    
    return loss_focal+loss_iou #+loss_ssim

SIZE=288
input_shape = (3, SIZE, SIZE)
batch_size = 8

model = build_unet(input_shape)
model.compile(loss=[hybrid_loss, hybrid_loss, hybrid_loss, hybrid_loss, hybrid_loss],
                  loss_weights=[0.25, 0.25, 0.25, 0.25, 1.0],
                  optimizer=keras.optimizers.Adam(learning_rate=1e-4), metrics=[losses.dice_coef, losses.iou_seg])
model.summary()
print(get_model_memory_usage(batch_size, model))
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 3, 288, 288) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 288, 288) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 288, 288) 1152        conv2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64, 288, 288) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 288, 288) 36928       dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 288, 288) 1152        conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 288, 288) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 144, 144) 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 144, 144 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 144, 144 576         conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128, 144, 144 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 144, 144 147584      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 144, 144 576         conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128, 144, 144 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 72, 72)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 72, 72)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 256, 72, 72)  288         conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 256, 72, 72)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 256, 72, 72)  590080      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 256, 72, 72)  288         conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 256, 72, 72)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 256, 36, 36)  0           dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 512, 36, 36)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 512, 36, 36)  144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512, 36, 36)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 512, 36, 36)  2359808     dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 512, 36, 36)  144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 512, 36, 36)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 512, 18, 18)  0           dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 1024, 18, 18) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 1024, 18, 18) 72          conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 1024, 18, 18) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 1024, 18, 18) 9438208     dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 1024, 18, 18) 72          conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 1024, 18, 18) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 512, 36, 36)  2097664     dropout_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1024, 36, 36) 0           conv2d_transpose[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 512, 36, 36)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 512, 36, 36)  144         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 512, 36, 36)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 512, 36, 36)  2359808     dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 512, 36, 36)  144         conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 512, 36, 36)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 256, 72, 72)  524544      dropout_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 512, 72, 72)  0           conv2d_transpose_1[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 256, 72, 72)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 256, 72, 72)  288         conv2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 256, 72, 72)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 256, 72, 72)  590080      dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 256, 72, 72)  288         conv2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 256, 72, 72)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 144, 144 131200      dropout_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 144, 144 0           conv2d_transpose_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 144, 144 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128, 144, 144 576         conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 128, 144, 144 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 144, 144 147584      dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 144, 144 576         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 128, 144, 144 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 288, 288) 32832       dropout_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 288, 288 0           conv2d_transpose_3[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 288, 288) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 288, 288) 1152        conv2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 64, 288, 288) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 288, 288) 36928       dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 288, 288) 1152        conv2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 64, 288, 288) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 1, 288, 288)  65          dropout_17[0][0]
# ==================================================================================================
# Total params: 31,040,529
# Trainable params: 31,036,137
# Non-trainable params: 4,392
# __________________________________________________________________________________________________
# 4.708

# %%
#New generator with rotation and shear where interpolation that comes with rotation and shear are thresholded in masks. 
#This gives a binary mask rather than a mask with interpolated values. 
seed=1337
from keras.preprocessing.image import ImageDataGenerator

img_data_gen_args = dict(rotation_range=180,
                     width_shift_range=0.3,
                     height_shift_range=0.3,
                     shear_range=0.5,
                     zoom_range=0.3,
                     horizontal_flip=True,
                     vertical_flip=True,
                     fill_mode='reflect',
                     data_format="channels_first")

mask_data_gen_args = dict(rotation_range=180,
                     width_shift_range=0.3,
                     height_shift_range=0.3,
                     shear_range=0.5,
                     zoom_range=0.3,
                     horizontal_flip=True,
                     vertical_flip=True,
                     fill_mode='reflect',
                     data_format="channels_first",
                     preprocessing_function = lambda x: np.where(x>0, 1, 0).astype(x.dtype)) #Binarize the output again. 

image_data_generator = ImageDataGenerator(**img_data_gen_args)
#image_data_generator.fit(X_train, augment=True, seed=seed)

image_generator = image_data_generator.flow(X_train, seed=seed, batch_size=batch_size)
valid_img_generator = image_data_generator.flow(X_test, seed=seed, batch_size=batch_size) #Default batch size 32, if not specified here

mask_data_generator = ImageDataGenerator(**mask_data_gen_args)
#mask_data_generator.fit(y_train, augment=True, seed=seed)
mask_generator = mask_data_generator.flow(y_train, seed=seed, batch_size=batch_size)
valid_mask_generator = mask_data_generator.flow(y_test, seed=seed, batch_size=batch_size)  #Default batch size 32, if not specified here

def my_image_mask_generator(image_generator, mask_generator):
    train_generator = zip(image_generator, mask_generator)
    for (img, mask) in train_generator:
        yield (img, mask)

my_generator = my_image_mask_generator(image_generator, mask_generator)

validation_datagen = my_image_mask_generator(valid_img_generator, valid_mask_generator)


x = valid_img_generator.next()
y = valid_mask_generator.next()
print(x.shape, y.shape)
for i in range(len(x)):
    image = x[i]
    fig1 = plt.subplot(4, 4, i+1)
    fig1.set_xticks([])  #Turn off axis
    fig1.set_yticks([])
    plt.imshow(image[1, :,:], cmap='gray')
    #plt.subplot(4,4,2)
    #plt.imshow(mask[0,:,:])
plt.show()

for i in range(len(x)):
    image = y[i]
    fig1 = plt.subplot(4, 4, i+1)
    fig1.set_xticks([])  #Turn off axis
    fig1.set_yticks([])
    plt.imshow(image[0, :,:], cmap='gray')
    #plt.subplot(4,4,2)
    #plt.imshow(mask[0,:,:])
plt.show()


steps_per_epoch = 3*(len(X_train))//batch_size
# Out:
# (8, 3, 288, 288) (8, 1, 288, 288)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger

epochs = 1000
#model.load_weights(r"/models/bactunet_3frame_local.hdf5")

#ModelCheckpoint callback saves a model at some interval.

filepath=r"models/bactunet_3frame_local_dice.hdf5" 
#Use Mode = max for accuracy and min for loss. 
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

#https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=50, verbose=1)
#This callback will stop the training when there is no improvement in
# the validation loss for 10 consecutive epochs.

#CSVLogger logs epoch, acc, loss, val_acc, val_loss
log_csv = CSVLogger(r'models/bactnet_logs.csv', separator=',', append=True)

callbacks_list = [checkpoint, early_stop, log_csv]

#We can now use these generators to train our model. 
#Give this a name so we can call it later for plotting loss, accuracy etc. as a function of epochs.

history = model.fit(
        my_generator,
        steps_per_epoch=steps_per_epoch,   
        epochs=epochs,
        validation_data=validation_datagen,
        validation_steps=steps_per_epoch,
        callbacks=callbacks_list)

model.save(r"/models/bactunet_3frame_final_dice.hdf5")
# Out:
# Epoch 1/1000
# 341/341 [==============================] - 276s 785ms/step - loss: 0.2513 - dice_coef: 0.6300 - iou_seg: 0.5336 - val_loss: 0.3299 - val_dice_coef: 0.4520 - val_iou_seg: 0.6953
#
# Epoch 00001: val_loss improved from inf to 0.32994, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 2/1000
# 341/341 [==============================] - 265s 778ms/step - loss: 0.2514 - dice_coef: 0.6301 - iou_seg: 0.5339 - val_loss: 0.3172 - val_dice_coef: 0.4798 - val_iou_seg: 0.6695
#
# Epoch 00002: val_loss improved from 0.32994 to 0.31716, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 3/1000
# 341/341 [==============================] - 264s 774ms/step - loss: 0.2475 - dice_coef: 0.6376 - iou_seg: 0.5255 - val_loss: 0.3775 - val_dice_coef: 0.3338 - val_iou_seg: 0.7869
#
# Epoch 00003: val_loss did not improve from 0.31716
# Epoch 4/1000
# 341/341 [==============================] - 264s 774ms/step - loss: 0.2527 - dice_coef: 0.6272 - iou_seg: 0.5364 - val_loss: 0.2732 - val_dice_coef: 0.5711 - val_iou_seg: 0.5878
#
# Epoch 00004: val_loss improved from 0.31716 to 0.27316, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 5/1000
# 341/341 [==============================] - 260s 763ms/step - loss: 0.2476 - dice_coef: 0.6381 - iou_seg: 0.5259 - val_loss: 0.2832 - val_dice_coef: 0.5602 - val_iou_seg: 0.6005
#
# Epoch 00005: val_loss did not improve from 0.27316
# Epoch 6/1000
# 341/341 [==============================] - 260s 763ms/step - loss: 0.2514 - dice_coef: 0.6298 - iou_seg: 0.5338 - val_loss: 0.2620 - val_dice_coef: 0.6055 - val_iou_seg: 0.5552
#
# Epoch 00006: val_loss improved from 0.27316 to 0.26201, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 7/1000
# 341/341 [==============================] - 260s 763ms/step - loss: 0.2446 - dice_coef: 0.6438 - iou_seg: 0.5198 - val_loss: 0.2660 - val_dice_coef: 0.5953 - val_iou_seg: 0.5658
#
# Epoch 00007: val_loss did not improve from 0.26201
# Epoch 8/1000
# 341/341 [==============================] - 259s 761ms/step - loss: 0.2421 - dice_coef: 0.6485 - iou_seg: 0.5143 - val_loss: 0.2697 - val_dice_coef: 0.5905 - val_iou_seg: 0.5722
#
# Epoch 00008: val_loss did not improve from 0.26201
# Epoch 9/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2433 - dice_coef: 0.6457 - iou_seg: 0.5167 - val_loss: 0.2645 - val_dice_coef: 0.5895 - val_iou_seg: 0.5688
#
# Epoch 00009: val_loss did not improve from 0.26201
# Epoch 10/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2436 - dice_coef: 0.6446 - iou_seg: 0.5171 - val_loss: 0.2879 - val_dice_coef: 0.5434 - val_iou_seg: 0.6134
#
# Epoch 00010: val_loss did not improve from 0.26201
# Epoch 11/1000
# 341/341 [==============================] - 259s 761ms/step - loss: 0.2428 - dice_coef: 0.6468 - iou_seg: 0.5157 - val_loss: 0.2786 - val_dice_coef: 0.5697 - val_iou_seg: 0.5883
#
# Epoch 00011: val_loss did not improve from 0.26201
# Epoch 12/1000
# 341/341 [==============================] - 260s 762ms/step - loss: 0.2430 - dice_coef: 0.6466 - iou_seg: 0.5162 - val_loss: 0.2615 - val_dice_coef: 0.6043 - val_iou_seg: 0.5574
#
# Epoch 00012: val_loss improved from 0.26201 to 0.26154, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 13/1000
# 341/341 [==============================] - 260s 762ms/step - loss: 0.2435 - dice_coef: 0.6450 - iou_seg: 0.5169 - val_loss: 0.2740 - val_dice_coef: 0.5731 - val_iou_seg: 0.5833
#
# Epoch 00013: val_loss did not improve from 0.26154
# Epoch 14/1000
# 341/341 [==============================] - 259s 761ms/step - loss: 0.2492 - dice_coef: 0.6331 - iou_seg: 0.5287 - val_loss: 0.2678 - val_dice_coef: 0.5842 - val_iou_seg: 0.5748
#
# Epoch 00014: val_loss did not improve from 0.26154
# Epoch 15/1000
# 341/341 [==============================] - 260s 763ms/step - loss: 0.2395 - dice_coef: 0.6535 - iou_seg: 0.5089 - val_loss: 0.2598 - val_dice_coef: 0.6067 - val_iou_seg: 0.5535
#
# Epoch 00015: val_loss improved from 0.26154 to 0.25979, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 16/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2427 - dice_coef: 0.6470 - iou_seg: 0.5157 - val_loss: 0.2813 - val_dice_coef: 0.5572 - val_iou_seg: 0.6009
#
# Epoch 00016: val_loss did not improve from 0.25979
# Epoch 17/1000
# 341/341 [==============================] - 259s 760ms/step - loss: 0.2396 - dice_coef: 0.6532 - iou_seg: 0.5091 - val_loss: 0.2565 - val_dice_coef: 0.6154 - val_iou_seg: 0.5442
#
# Epoch 00017: val_loss improved from 0.25979 to 0.25646, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 18/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2387 - dice_coef: 0.6551 - iou_seg: 0.5072 - val_loss: 0.2668 - val_dice_coef: 0.5923 - val_iou_seg: 0.5674
#
# Epoch 00018: val_loss did not improve from 0.25646
# Epoch 19/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2398 - dice_coef: 0.6523 - iou_seg: 0.5093 - val_loss: 0.2628 - val_dice_coef: 0.5978 - val_iou_seg: 0.5619
#
# Epoch 00019: val_loss did not improve from 0.25646
# Epoch 20/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2397 - dice_coef: 0.6530 - iou_seg: 0.5090 - val_loss: 0.2565 - val_dice_coef: 0.6139 - val_iou_seg: 0.5462
#
# Epoch 00020: val_loss did not improve from 0.25646
# Epoch 21/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2422 - dice_coef: 0.6472 - iou_seg: 0.5142 - val_loss: 0.2686 - val_dice_coef: 0.5890 - val_iou_seg: 0.5712
#
# Epoch 00021: val_loss did not improve from 0.25646
# Epoch 22/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2413 - dice_coef: 0.6498 - iou_seg: 0.5126 - val_loss: 0.2911 - val_dice_coef: 0.5398 - val_iou_seg: 0.6190
#
# Epoch 00022: val_loss did not improve from 0.25646
# Epoch 23/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2434 - dice_coef: 0.6459 - iou_seg: 0.5170 - val_loss: 0.2526 - val_dice_coef: 0.6214 - val_iou_seg: 0.5387
#
# Epoch 00023: val_loss improved from 0.25646 to 0.25258, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 24/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2389 - dice_coef: 0.6548 - iou_seg: 0.5075 - val_loss: 0.2576 - val_dice_coef: 0.6162 - val_iou_seg: 0.5457
#
# Epoch 00024: val_loss did not improve from 0.25258
# Epoch 25/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2358 - dice_coef: 0.6600 - iou_seg: 0.5009 - val_loss: 0.2595 - val_dice_coef: 0.6070 - val_iou_seg: 0.5519
#
# Epoch 00025: val_loss did not improve from 0.25258
# Epoch 26/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2385 - dice_coef: 0.6551 - iou_seg: 0.5066 - val_loss: 0.2856 - val_dice_coef: 0.5609 - val_iou_seg: 0.6021
#
# Epoch 00026: val_loss did not improve from 0.25258
# Epoch 27/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2382 - dice_coef: 0.6557 - iou_seg: 0.5057 - val_loss: 0.2535 - val_dice_coef: 0.6215 - val_iou_seg: 0.5380
#
# Epoch 00027: val_loss did not improve from 0.25258
# Epoch 28/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2357 - dice_coef: 0.6604 - iou_seg: 0.5008 - val_loss: 0.2728 - val_dice_coef: 0.5804 - val_iou_seg: 0.5784
#
# Epoch 00028: val_loss did not improve from 0.25258
# Epoch 29/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2349 - dice_coef: 0.6622 - iou_seg: 0.4993 - val_loss: 0.2565 - val_dice_coef: 0.6151 - val_iou_seg: 0.5454
#
# Epoch 00029: val_loss did not improve from 0.25258
# Epoch 30/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2355 - dice_coef: 0.6604 - iou_seg: 0.5002 - val_loss: 0.2672 - val_dice_coef: 0.5893 - val_iou_seg: 0.5686
#
# Epoch 00030: val_loss did not improve from 0.25258
# Epoch 31/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2425 - dice_coef: 0.6465 - iou_seg: 0.5147 - val_loss: 0.2563 - val_dice_coef: 0.6088 - val_iou_seg: 0.5499
#
# Epoch 00031: val_loss did not improve from 0.25258
# Epoch 32/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2331 - dice_coef: 0.6655 - iou_seg: 0.4950 - val_loss: 0.2493 - val_dice_coef: 0.6249 - val_iou_seg: 0.5336
#
# Epoch 00032: val_loss improved from 0.25258 to 0.24925, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 33/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2340 - dice_coef: 0.6640 - iou_seg: 0.4973 - val_loss: 0.2577 - val_dice_coef: 0.6063 - val_iou_seg: 0.5526
#
# Epoch 00033: val_loss did not improve from 0.24925
# Epoch 34/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2329 - dice_coef: 0.6659 - iou_seg: 0.4948 - val_loss: 0.2609 - val_dice_coef: 0.6037 - val_iou_seg: 0.5548
#
# Epoch 00034: val_loss did not improve from 0.24925
# Epoch 35/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2357 - dice_coef: 0.6604 - iou_seg: 0.5007 - val_loss: 0.2572 - val_dice_coef: 0.6124 - val_iou_seg: 0.5487
#
# Epoch 00035: val_loss did not improve from 0.24925
# Epoch 36/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2342 - dice_coef: 0.6634 - iou_seg: 0.4976 - val_loss: 0.2564 - val_dice_coef: 0.6163 - val_iou_seg: 0.5439
#
# Epoch 00036: val_loss did not improve from 0.24925
# Epoch 37/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2376 - dice_coef: 0.6564 - iou_seg: 0.5047 - val_loss: 0.2513 - val_dice_coef: 0.6246 - val_iou_seg: 0.5359
#
# Epoch 00037: val_loss did not improve from 0.24925
# Epoch 38/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2329 - dice_coef: 0.6656 - iou_seg: 0.4947 - val_loss: 0.2475 - val_dice_coef: 0.6260 - val_iou_seg: 0.5324
#
# Epoch 00038: val_loss improved from 0.24925 to 0.24747, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 39/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2279 - dice_coef: 0.6759 - iou_seg: 0.4846 - val_loss: 0.2501 - val_dice_coef: 0.6221 - val_iou_seg: 0.5363
#
# Epoch 00039: val_loss did not improve from 0.24747
# Epoch 40/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2322 - dice_coef: 0.6668 - iou_seg: 0.4932 - val_loss: 0.2509 - val_dice_coef: 0.6320 - val_iou_seg: 0.5281
#
# Epoch 00040: val_loss did not improve from 0.24747
# Epoch 41/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2293 - dice_coef: 0.6726 - iou_seg: 0.4872 - val_loss: 0.2456 - val_dice_coef: 0.6323 - val_iou_seg: 0.5265
#
# Epoch 00041: val_loss improved from 0.24747 to 0.24555, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 42/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2384 - dice_coef: 0.6559 - iou_seg: 0.5065 - val_loss: 0.2518 - val_dice_coef: 0.6250 - val_iou_seg: 0.5355
#
# Epoch 00042: val_loss did not improve from 0.24555
# Epoch 43/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2320 - dice_coef: 0.6668 - iou_seg: 0.4927 - val_loss: 0.2508 - val_dice_coef: 0.6221 - val_iou_seg: 0.5363
#
# Epoch 00043: val_loss did not improve from 0.24555
# Epoch 44/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2323 - dice_coef: 0.6670 - iou_seg: 0.4935 - val_loss: 0.2447 - val_dice_coef: 0.6450 - val_iou_seg: 0.5163
#
# Epoch 00044: val_loss improved from 0.24555 to 0.24475, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 45/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2317 - dice_coef: 0.6681 - iou_seg: 0.4920 - val_loss: 0.2496 - val_dice_coef: 0.6261 - val_iou_seg: 0.5345
#
# Epoch 00045: val_loss did not improve from 0.24475
# Epoch 46/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2274 - dice_coef: 0.6764 - iou_seg: 0.4831 - val_loss: 0.2544 - val_dice_coef: 0.6159 - val_iou_seg: 0.5433
#
# Epoch 00046: val_loss did not improve from 0.24475
# Epoch 47/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2223 - dice_coef: 0.6855 - iou_seg: 0.4723 - val_loss: 0.2550 - val_dice_coef: 0.6083 - val_iou_seg: 0.5509
#
# Epoch 00047: val_loss did not improve from 0.24475
# Epoch 48/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2301 - dice_coef: 0.6710 - iou_seg: 0.4889 - val_loss: 0.2465 - val_dice_coef: 0.6321 - val_iou_seg: 0.5275
#
# Epoch 00048: val_loss did not improve from 0.24475
# Epoch 49/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2239 - dice_coef: 0.6834 - iou_seg: 0.4757 - val_loss: 0.2485 - val_dice_coef: 0.6303 - val_iou_seg: 0.5279
#
# Epoch 00049: val_loss did not improve from 0.24475
# Epoch 50/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2274 - dice_coef: 0.6760 - iou_seg: 0.4829 - val_loss: 0.2482 - val_dice_coef: 0.6293 - val_iou_seg: 0.5300
#
# Epoch 00050: val_loss did not improve from 0.24475
# Epoch 51/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2252 - dice_coef: 0.6805 - iou_seg: 0.4785 - val_loss: 0.2419 - val_dice_coef: 0.6426 - val_iou_seg: 0.5149
#
# Epoch 00051: val_loss improved from 0.24475 to 0.24186, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 52/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2302 - dice_coef: 0.6710 - iou_seg: 0.4892 - val_loss: 0.2534 - val_dice_coef: 0.6231 - val_iou_seg: 0.5373
#
# Epoch 00052: val_loss did not improve from 0.24186
# Epoch 53/1000
# 341/341 [==============================] - 258s 757ms/step - loss: 0.2258 - dice_coef: 0.6793 - iou_seg: 0.4798 - val_loss: 0.2627 - val_dice_coef: 0.6070 - val_iou_seg: 0.5563
#
# Epoch 00053: val_loss did not improve from 0.24186
# Epoch 54/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2271 - dice_coef: 0.6774 - iou_seg: 0.4826 - val_loss: 0.2428 - val_dice_coef: 0.6378 - val_iou_seg: 0.5208
#
# Epoch 00054: val_loss did not improve from 0.24186
# Epoch 55/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2248 - dice_coef: 0.6814 - iou_seg: 0.4777 - val_loss: 0.2442 - val_dice_coef: 0.6317 - val_iou_seg: 0.5272
#
# Epoch 00055: val_loss did not improve from 0.24186
# Epoch 56/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2234 - dice_coef: 0.6840 - iou_seg: 0.4747 - val_loss: 0.2535 - val_dice_coef: 0.6223 - val_iou_seg: 0.5381
#
# Epoch 00056: val_loss did not improve from 0.24186
# Epoch 57/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2227 - dice_coef: 0.6857 - iou_seg: 0.4732 - val_loss: 0.2438 - val_dice_coef: 0.6446 - val_iou_seg: 0.5169
#
# Epoch 00057: val_loss did not improve from 0.24186
# Epoch 58/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2251 - dice_coef: 0.6807 - iou_seg: 0.4782 - val_loss: 0.2387 - val_dice_coef: 0.6463 - val_iou_seg: 0.5113
#
# Epoch 00058: val_loss improved from 0.24186 to 0.23872, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 59/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2258 - dice_coef: 0.6789 - iou_seg: 0.4793 - val_loss: 0.2453 - val_dice_coef: 0.6373 - val_iou_seg: 0.5221
#
# Epoch 00059: val_loss did not improve from 0.23872
# Epoch 60/1000
# 341/341 [==============================] - 258s 757ms/step - loss: 0.2222 - dice_coef: 0.6870 - iou_seg: 0.4723 - val_loss: 0.2406 - val_dice_coef: 0.6443 - val_iou_seg: 0.5135
#
# Epoch 00060: val_loss did not improve from 0.23872
# Epoch 61/1000
# 341/341 [==============================] - 259s 760ms/step - loss: 0.2255 - dice_coef: 0.6802 - iou_seg: 0.4791 - val_loss: 0.2492 - val_dice_coef: 0.6251 - val_iou_seg: 0.5343
#
# Epoch 00061: val_loss did not improve from 0.23872
# Epoch 62/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2221 - dice_coef: 0.6863 - iou_seg: 0.4719 - val_loss: 0.2466 - val_dice_coef: 0.6342 - val_iou_seg: 0.5256
#
# Epoch 00062: val_loss did not improve from 0.23872
# Epoch 63/1000
# 341/341 [==============================] - 258s 757ms/step - loss: 0.2219 - dice_coef: 0.6873 - iou_seg: 0.4716 - val_loss: 0.2663 - val_dice_coef: 0.5981 - val_iou_seg: 0.5636
#
# Epoch 00063: val_loss did not improve from 0.23872
# Epoch 64/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2224 - dice_coef: 0.6860 - iou_seg: 0.4726 - val_loss: 0.2409 - val_dice_coef: 0.6448 - val_iou_seg: 0.5142
#
# Epoch 00064: val_loss did not improve from 0.23872
# Epoch 65/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2220 - dice_coef: 0.6864 - iou_seg: 0.4717 - val_loss: 0.2430 - val_dice_coef: 0.6445 - val_iou_seg: 0.5145
#
# Epoch 00065: val_loss did not improve from 0.23872
# Epoch 66/1000
# 341/341 [==============================] - 258s 757ms/step - loss: 0.2198 - dice_coef: 0.6904 - iou_seg: 0.4668 - val_loss: 0.2358 - val_dice_coef: 0.6534 - val_iou_seg: 0.5039
#
# Epoch 00066: val_loss improved from 0.23872 to 0.23583, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 67/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2225 - dice_coef: 0.6859 - iou_seg: 0.4728 - val_loss: 0.2408 - val_dice_coef: 0.6427 - val_iou_seg: 0.5151
#
# Epoch 00067: val_loss did not improve from 0.23583
# Epoch 68/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2269 - dice_coef: 0.6771 - iou_seg: 0.4819 - val_loss: 0.2411 - val_dice_coef: 0.6398 - val_iou_seg: 0.5177
#
# Epoch 00068: val_loss did not improve from 0.23583
# Epoch 69/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2237 - dice_coef: 0.6829 - iou_seg: 0.4751 - val_loss: 0.2417 - val_dice_coef: 0.6448 - val_iou_seg: 0.5150
#
# Epoch 00069: val_loss did not improve from 0.23583
# Epoch 70/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2222 - dice_coef: 0.6862 - iou_seg: 0.4721 - val_loss: 0.2468 - val_dice_coef: 0.6315 - val_iou_seg: 0.5279
#
# Epoch 00070: val_loss did not improve from 0.23583
# Epoch 71/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2201 - dice_coef: 0.6900 - iou_seg: 0.4675 - val_loss: 0.2410 - val_dice_coef: 0.6466 - val_iou_seg: 0.5132
#
# Epoch 00071: val_loss did not improve from 0.23583
# Epoch 72/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2198 - dice_coef: 0.6905 - iou_seg: 0.4668 - val_loss: 0.2432 - val_dice_coef: 0.6435 - val_iou_seg: 0.5169
#
# Epoch 00072: val_loss did not improve from 0.23583
# Epoch 73/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2206 - dice_coef: 0.6895 - iou_seg: 0.4687 - val_loss: 0.2422 - val_dice_coef: 0.6488 - val_iou_seg: 0.5113
#
# Epoch 00073: val_loss did not improve from 0.23583
# Epoch 74/1000
# 341/341 [==============================] - 258s 757ms/step - loss: 0.2231 - dice_coef: 0.6848 - iou_seg: 0.4741 - val_loss: 0.2447 - val_dice_coef: 0.6377 - val_iou_seg: 0.5226
#
# Epoch 00074: val_loss did not improve from 0.23583
# Epoch 75/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2191 - dice_coef: 0.6923 - iou_seg: 0.4656 - val_loss: 0.2481 - val_dice_coef: 0.6320 - val_iou_seg: 0.5286
#
# Epoch 00075: val_loss did not improve from 0.23583
# Epoch 76/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2217 - dice_coef: 0.6868 - iou_seg: 0.4711 - val_loss: 0.2436 - val_dice_coef: 0.6457 - val_iou_seg: 0.5153
#
# Epoch 00076: val_loss did not improve from 0.23583
# Epoch 77/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2210 - dice_coef: 0.6890 - iou_seg: 0.4698 - val_loss: 0.2410 - val_dice_coef: 0.6412 - val_iou_seg: 0.5173
#
# Epoch 00077: val_loss did not improve from 0.23583
# Epoch 78/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2205 - dice_coef: 0.6892 - iou_seg: 0.4684 - val_loss: 0.2400 - val_dice_coef: 0.6498 - val_iou_seg: 0.5097
#
# Epoch 00078: val_loss did not improve from 0.23583
# Epoch 79/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2212 - dice_coef: 0.6881 - iou_seg: 0.4699 - val_loss: 0.2436 - val_dice_coef: 0.6384 - val_iou_seg: 0.5228
#
# Epoch 00079: val_loss did not improve from 0.23583
# Epoch 80/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2188 - dice_coef: 0.6922 - iou_seg: 0.4647 - val_loss: 0.2412 - val_dice_coef: 0.6389 - val_iou_seg: 0.5193
#
# Epoch 00080: val_loss did not improve from 0.23583
# Epoch 81/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2167 - dice_coef: 0.6959 - iou_seg: 0.4601 - val_loss: 0.2402 - val_dice_coef: 0.6466 - val_iou_seg: 0.5126
#
# Epoch 00081: val_loss did not improve from 0.23583
# Epoch 82/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2218 - dice_coef: 0.6865 - iou_seg: 0.4711 - val_loss: 0.2426 - val_dice_coef: 0.6483 - val_iou_seg: 0.5129
#
# Epoch 00082: val_loss did not improve from 0.23583
# Epoch 83/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2191 - dice_coef: 0.6918 - iou_seg: 0.4654 - val_loss: 0.2415 - val_dice_coef: 0.6429 - val_iou_seg: 0.5156
#
# Epoch 00083: val_loss did not improve from 0.23583
# Epoch 84/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2186 - dice_coef: 0.6927 - iou_seg: 0.4643 - val_loss: 0.2403 - val_dice_coef: 0.6443 - val_iou_seg: 0.5143
#
# Epoch 00084: val_loss did not improve from 0.23583
# Epoch 85/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2162 - dice_coef: 0.6974 - iou_seg: 0.4594 - val_loss: 0.2373 - val_dice_coef: 0.6498 - val_iou_seg: 0.5087
#
# Epoch 00085: val_loss did not improve from 0.23583
# Epoch 86/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2157 - dice_coef: 0.6987 - iou_seg: 0.4582 - val_loss: 0.2509 - val_dice_coef: 0.6250 - val_iou_seg: 0.5357
#
# Epoch 00086: val_loss did not improve from 0.23583
# Epoch 87/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2191 - dice_coef: 0.6916 - iou_seg: 0.4652 - val_loss: 0.2385 - val_dice_coef: 0.6538 - val_iou_seg: 0.5052
#
# Epoch 00087: val_loss did not improve from 0.23583
# Epoch 88/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2165 - dice_coef: 0.6970 - iou_seg: 0.4600 - val_loss: 0.2378 - val_dice_coef: 0.6512 - val_iou_seg: 0.5080
#
# Epoch 00088: val_loss did not improve from 0.23583
# Epoch 89/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2153 - dice_coef: 0.6987 - iou_seg: 0.4573 - val_loss: 0.2409 - val_dice_coef: 0.6398 - val_iou_seg: 0.5181
#
# Epoch 00089: val_loss did not improve from 0.23583
# Epoch 90/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2150 - dice_coef: 0.6998 - iou_seg: 0.4567 - val_loss: 0.2389 - val_dice_coef: 0.6491 - val_iou_seg: 0.5095
#
# Epoch 00090: val_loss did not improve from 0.23583
# Epoch 91/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2173 - dice_coef: 0.6949 - iou_seg: 0.4615 - val_loss: 0.2425 - val_dice_coef: 0.6440 - val_iou_seg: 0.5160
#
# Epoch 00091: val_loss did not improve from 0.23583
# Epoch 92/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2184 - dice_coef: 0.6931 - iou_seg: 0.4639 - val_loss: 0.2392 - val_dice_coef: 0.6503 - val_iou_seg: 0.5095
#
# Epoch 00092: val_loss did not improve from 0.23583
# Epoch 93/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2150 - dice_coef: 0.6992 - iou_seg: 0.4566 - val_loss: 0.2456 - val_dice_coef: 0.6319 - val_iou_seg: 0.5268
#
# Epoch 00093: val_loss did not improve from 0.23583
# Epoch 94/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2195 - dice_coef: 0.6909 - iou_seg: 0.4663 - val_loss: 0.2418 - val_dice_coef: 0.6456 - val_iou_seg: 0.5156
#
# Epoch 00094: val_loss did not improve from 0.23583
# Epoch 95/1000
# 341/341 [==============================] - 258s 757ms/step - loss: 0.2108 - dice_coef: 0.7073 - iou_seg: 0.4480 - val_loss: 0.2347 - val_dice_coef: 0.6617 - val_iou_seg: 0.4972
#
# Epoch 00095: val_loss improved from 0.23583 to 0.23471, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 96/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2132 - dice_coef: 0.7032 - iou_seg: 0.4529 - val_loss: 0.2409 - val_dice_coef: 0.6442 - val_iou_seg: 0.5136
#
# Epoch 00096: val_loss did not improve from 0.23471
# Epoch 97/1000
# 341/341 [==============================] - 258s 756ms/step - loss: 0.2154 - dice_coef: 0.6990 - iou_seg: 0.4576 - val_loss: 0.2324 - val_dice_coef: 0.6612 - val_iou_seg: 0.4952
#
# Epoch 00097: val_loss improved from 0.23471 to 0.23238, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 98/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2159 - dice_coef: 0.6982 - iou_seg: 0.4588 - val_loss: 0.2342 - val_dice_coef: 0.6578 - val_iou_seg: 0.5004
#
# Epoch 00098: val_loss did not improve from 0.23238
# Epoch 99/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2132 - dice_coef: 0.7030 - iou_seg: 0.4530 - val_loss: 0.2368 - val_dice_coef: 0.6448 - val_iou_seg: 0.5122
#
# Epoch 00099: val_loss did not improve from 0.23238
# Epoch 100/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2127 - dice_coef: 0.7034 - iou_seg: 0.4515 - val_loss: 0.2400 - val_dice_coef: 0.6438 - val_iou_seg: 0.5152
#
# Epoch 00100: val_loss did not improve from 0.23238
# Epoch 101/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2137 - dice_coef: 0.7017 - iou_seg: 0.4537 - val_loss: 0.2295 - val_dice_coef: 0.6646 - val_iou_seg: 0.4926
#
# Epoch 00101: val_loss improved from 0.23238 to 0.22954, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 102/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2160 - dice_coef: 0.6978 - iou_seg: 0.4589 - val_loss: 0.2393 - val_dice_coef: 0.6512 - val_iou_seg: 0.5087
#
# Epoch 00102: val_loss did not improve from 0.22954
# Epoch 103/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2152 - dice_coef: 0.6991 - iou_seg: 0.4570 - val_loss: 0.2424 - val_dice_coef: 0.6473 - val_iou_seg: 0.5112
#
# Epoch 00103: val_loss did not improve from 0.22954
# Epoch 104/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2137 - dice_coef: 0.7023 - iou_seg: 0.4542 - val_loss: 0.2335 - val_dice_coef: 0.6554 - val_iou_seg: 0.5016
#
# Epoch 00104: val_loss did not improve from 0.22954
# Epoch 105/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2123 - dice_coef: 0.7049 - iou_seg: 0.4509 - val_loss: 0.2454 - val_dice_coef: 0.6329 - val_iou_seg: 0.5250
#
# Epoch 00105: val_loss did not improve from 0.22954
# Epoch 106/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2153 - dice_coef: 0.6984 - iou_seg: 0.4572 - val_loss: 0.2325 - val_dice_coef: 0.6606 - val_iou_seg: 0.4971
#
# Epoch 00106: val_loss did not improve from 0.22954
# Epoch 107/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2093 - dice_coef: 0.7106 - iou_seg: 0.4447 - val_loss: 0.2391 - val_dice_coef: 0.6515 - val_iou_seg: 0.5077
#
# Epoch 00107: val_loss did not improve from 0.22954
# Epoch 108/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2122 - dice_coef: 0.7051 - iou_seg: 0.4506 - val_loss: 0.2383 - val_dice_coef: 0.6527 - val_iou_seg: 0.5066
#
# Epoch 00108: val_loss did not improve from 0.22954
# Epoch 109/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2125 - dice_coef: 0.7046 - iou_seg: 0.4514 - val_loss: 0.2312 - val_dice_coef: 0.6650 - val_iou_seg: 0.4931
#
# Epoch 00109: val_loss did not improve from 0.22954
# Epoch 110/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2062 - dice_coef: 0.7159 - iou_seg: 0.4377 - val_loss: 0.2325 - val_dice_coef: 0.6539 - val_iou_seg: 0.5018
#
# Epoch 00110: val_loss did not improve from 0.22954
# Epoch 111/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2104 - dice_coef: 0.7083 - iou_seg: 0.4469 - val_loss: 0.2358 - val_dice_coef: 0.6517 - val_iou_seg: 0.5048
#
# Epoch 00111: val_loss did not improve from 0.22954
# Epoch 112/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2100 - dice_coef: 0.7087 - iou_seg: 0.4458 - val_loss: 0.2327 - val_dice_coef: 0.6586 - val_iou_seg: 0.4998
#
# Epoch 00112: val_loss did not improve from 0.22954
# Epoch 113/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2116 - dice_coef: 0.7061 - iou_seg: 0.4494 - val_loss: 0.2469 - val_dice_coef: 0.6329 - val_iou_seg: 0.5264
#
# Epoch 00113: val_loss did not improve from 0.22954
# Epoch 114/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2117 - dice_coef: 0.7057 - iou_seg: 0.4497 - val_loss: 0.2334 - val_dice_coef: 0.6649 - val_iou_seg: 0.4928
#
# Epoch 00114: val_loss did not improve from 0.22954
# Epoch 115/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2093 - dice_coef: 0.7102 - iou_seg: 0.4446 - val_loss: 0.2337 - val_dice_coef: 0.6624 - val_iou_seg: 0.4961
#
# Epoch 00115: val_loss did not improve from 0.22954
# Epoch 116/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2150 - dice_coef: 0.6999 - iou_seg: 0.4569 - val_loss: 0.2384 - val_dice_coef: 0.6543 - val_iou_seg: 0.5052
#
# Epoch 00116: val_loss did not improve from 0.22954
# Epoch 117/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2106 - dice_coef: 0.7079 - iou_seg: 0.4476 - val_loss: 0.2381 - val_dice_coef: 0.6508 - val_iou_seg: 0.5076
#
# Epoch 00117: val_loss did not improve from 0.22954
# Epoch 118/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2097 - dice_coef: 0.7089 - iou_seg: 0.4452 - val_loss: 0.2307 - val_dice_coef: 0.6683 - val_iou_seg: 0.4906
#
# Epoch 00118: val_loss did not improve from 0.22954
# Epoch 119/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2093 - dice_coef: 0.7101 - iou_seg: 0.4444 - val_loss: 0.2368 - val_dice_coef: 0.6547 - val_iou_seg: 0.5046
#
# Epoch 00119: val_loss did not improve from 0.22954
# Epoch 120/1000
# 341/341 [==============================] - 259s 760ms/step - loss: 0.2102 - dice_coef: 0.7085 - iou_seg: 0.4463 - val_loss: 0.2322 - val_dice_coef: 0.6622 - val_iou_seg: 0.4960
#
# Epoch 00120: val_loss did not improve from 0.22954
# Epoch 121/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2076 - dice_coef: 0.7127 - iou_seg: 0.4407 - val_loss: 0.2397 - val_dice_coef: 0.6486 - val_iou_seg: 0.5119
#
# Epoch 00121: val_loss did not improve from 0.22954
# Epoch 122/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2120 - dice_coef: 0.7051 - iou_seg: 0.4502 - val_loss: 0.2387 - val_dice_coef: 0.6520 - val_iou_seg: 0.5081
#
# Epoch 00122: val_loss did not improve from 0.22954
# Epoch 123/1000
# 341/341 [==============================] - 258s 757ms/step - loss: 0.2049 - dice_coef: 0.7182 - iou_seg: 0.4349 - val_loss: 0.2357 - val_dice_coef: 0.6459 - val_iou_seg: 0.5105
#
# Epoch 00123: val_loss did not improve from 0.22954
# Epoch 124/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2071 - dice_coef: 0.7139 - iou_seg: 0.4396 - val_loss: 0.2481 - val_dice_coef: 0.6318 - val_iou_seg: 0.5299
#
# Epoch 00124: val_loss did not improve from 0.22954
# Epoch 125/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2083 - dice_coef: 0.7120 - iou_seg: 0.4424 - val_loss: 0.2299 - val_dice_coef: 0.6680 - val_iou_seg: 0.4902
#
# Epoch 00125: val_loss did not improve from 0.22954
# Epoch 126/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2067 - dice_coef: 0.7148 - iou_seg: 0.4390 - val_loss: 0.2323 - val_dice_coef: 0.6574 - val_iou_seg: 0.4992
#
# Epoch 00126: val_loss did not improve from 0.22954
# Epoch 127/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2056 - dice_coef: 0.7172 - iou_seg: 0.4365 - val_loss: 0.2461 - val_dice_coef: 0.6324 - val_iou_seg: 0.5271
#
# Epoch 00127: val_loss did not improve from 0.22954
# Epoch 128/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2066 - dice_coef: 0.7146 - iou_seg: 0.4387 - val_loss: 0.2370 - val_dice_coef: 0.6521 - val_iou_seg: 0.5064
#
# Epoch 00128: val_loss did not improve from 0.22954
# Epoch 129/1000
# 341/341 [==============================] - 259s 760ms/step - loss: 0.2065 - dice_coef: 0.7151 - iou_seg: 0.4385 - val_loss: 0.2358 - val_dice_coef: 0.6601 - val_iou_seg: 0.4997
#
# Epoch 00129: val_loss did not improve from 0.22954
# Epoch 130/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2019 - dice_coef: 0.7238 - iou_seg: 0.4288 - val_loss: 0.2334 - val_dice_coef: 0.6584 - val_iou_seg: 0.4972
#
# Epoch 00130: val_loss did not improve from 0.22954
# Epoch 131/1000
# 341/341 [==============================] - 258s 757ms/step - loss: 0.2074 - dice_coef: 0.7138 - iou_seg: 0.4406 - val_loss: 0.2324 - val_dice_coef: 0.6593 - val_iou_seg: 0.4983
#
# Epoch 00131: val_loss did not improve from 0.22954
# Epoch 132/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2064 - dice_coef: 0.7155 - iou_seg: 0.4380 - val_loss: 0.2379 - val_dice_coef: 0.6541 - val_iou_seg: 0.5056
#
# Epoch 00132: val_loss did not improve from 0.22954
# Epoch 133/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2087 - dice_coef: 0.7111 - iou_seg: 0.4433 - val_loss: 0.2333 - val_dice_coef: 0.6562 - val_iou_seg: 0.5016
#
# Epoch 00133: val_loss did not improve from 0.22954
# Epoch 134/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2106 - dice_coef: 0.7072 - iou_seg: 0.4471 - val_loss: 0.2318 - val_dice_coef: 0.6628 - val_iou_seg: 0.4944
#
# Epoch 00134: val_loss did not improve from 0.22954
# Epoch 135/1000
# 341/341 [==============================] - 259s 760ms/step - loss: 0.2043 - dice_coef: 0.7190 - iou_seg: 0.4336 - val_loss: 0.2326 - val_dice_coef: 0.6545 - val_iou_seg: 0.5025
#
# Epoch 00135: val_loss did not improve from 0.22954
# Epoch 136/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2020 - dice_coef: 0.7234 - iou_seg: 0.4288 - val_loss: 0.2276 - val_dice_coef: 0.6693 - val_iou_seg: 0.4867
#
# Epoch 00136: val_loss improved from 0.22954 to 0.22765, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 137/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2051 - dice_coef: 0.7173 - iou_seg: 0.4353 - val_loss: 0.2265 - val_dice_coef: 0.6730 - val_iou_seg: 0.4839
#
# Epoch 00137: val_loss improved from 0.22765 to 0.22649, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 138/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2056 - dice_coef: 0.7162 - iou_seg: 0.4364 - val_loss: 0.2323 - val_dice_coef: 0.6500 - val_iou_seg: 0.5055
#
# Epoch 00138: val_loss did not improve from 0.22649
# Epoch 139/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2045 - dice_coef: 0.7190 - iou_seg: 0.4341 - val_loss: 0.2383 - val_dice_coef: 0.6550 - val_iou_seg: 0.5053
#
# Epoch 00139: val_loss did not improve from 0.22649
# Epoch 140/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2042 - dice_coef: 0.7197 - iou_seg: 0.4335 - val_loss: 0.2274 - val_dice_coef: 0.6742 - val_iou_seg: 0.4826
#
# Epoch 00140: val_loss did not improve from 0.22649
# Epoch 141/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2044 - dice_coef: 0.7191 - iou_seg: 0.4341 - val_loss: 0.2371 - val_dice_coef: 0.6549 - val_iou_seg: 0.5041
#
# Epoch 00141: val_loss did not improve from 0.22649
# Epoch 142/1000
# 341/341 [==============================] - 258s 757ms/step - loss: 0.2057 - dice_coef: 0.7162 - iou_seg: 0.4368 - val_loss: 0.2329 - val_dice_coef: 0.6560 - val_iou_seg: 0.5010
#
# Epoch 00142: val_loss did not improve from 0.22649
# Epoch 143/1000
# 341/341 [==============================] - 259s 760ms/step - loss: 0.1988 - dice_coef: 0.7292 - iou_seg: 0.4219 - val_loss: 0.2302 - val_dice_coef: 0.6580 - val_iou_seg: 0.4976
#
# Epoch 00143: val_loss did not improve from 0.22649
# Epoch 144/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2035 - dice_coef: 0.7203 - iou_seg: 0.4319 - val_loss: 0.2321 - val_dice_coef: 0.6598 - val_iou_seg: 0.4979
#
# Epoch 00144: val_loss did not improve from 0.22649
# Epoch 145/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2024 - dice_coef: 0.7230 - iou_seg: 0.4299 - val_loss: 0.2303 - val_dice_coef: 0.6641 - val_iou_seg: 0.4934
#
# Epoch 00145: val_loss did not improve from 0.22649
# Epoch 146/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2002 - dice_coef: 0.7266 - iou_seg: 0.4249 - val_loss: 0.2371 - val_dice_coef: 0.6551 - val_iou_seg: 0.5043
#
# Epoch 00146: val_loss did not improve from 0.22649
# Epoch 147/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2011 - dice_coef: 0.7251 - iou_seg: 0.4266 - val_loss: 0.2339 - val_dice_coef: 0.6615 - val_iou_seg: 0.4958
#
# Epoch 00147: val_loss did not improve from 0.22649
# Epoch 148/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2007 - dice_coef: 0.7258 - iou_seg: 0.4260 - val_loss: 0.2378 - val_dice_coef: 0.6550 - val_iou_seg: 0.5035
#
# Epoch 00148: val_loss did not improve from 0.22649
# Epoch 149/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1991 - dice_coef: 0.7287 - iou_seg: 0.4225 - val_loss: 0.2251 - val_dice_coef: 0.6720 - val_iou_seg: 0.4836
#
# Epoch 00149: val_loss improved from 0.22649 to 0.22509, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 150/1000
# 341/341 [==============================] - 258s 757ms/step - loss: 0.1990 - dice_coef: 0.7285 - iou_seg: 0.4221 - val_loss: 0.2335 - val_dice_coef: 0.6612 - val_iou_seg: 0.4967
#
# Epoch 00150: val_loss did not improve from 0.22509
# Epoch 151/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2003 - dice_coef: 0.7269 - iou_seg: 0.4253 - val_loss: 0.2435 - val_dice_coef: 0.6372 - val_iou_seg: 0.5219
#
# Epoch 00151: val_loss did not improve from 0.22509
# Epoch 152/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2018 - dice_coef: 0.7238 - iou_seg: 0.4284 - val_loss: 0.2270 - val_dice_coef: 0.6715 - val_iou_seg: 0.4853
#
# Epoch 00152: val_loss did not improve from 0.22509
# Epoch 153/1000
# 341/341 [==============================] - 259s 760ms/step - loss: 0.2018 - dice_coef: 0.7236 - iou_seg: 0.4284 - val_loss: 0.2317 - val_dice_coef: 0.6698 - val_iou_seg: 0.4883
#
# Epoch 00153: val_loss did not improve from 0.22509
# Epoch 154/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1971 - dice_coef: 0.7323 - iou_seg: 0.4182 - val_loss: 0.2329 - val_dice_coef: 0.6675 - val_iou_seg: 0.4901
#
# Epoch 00154: val_loss did not improve from 0.22509
# Epoch 155/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.2005 - dice_coef: 0.7259 - iou_seg: 0.4254 - val_loss: 0.2272 - val_dice_coef: 0.6703 - val_iou_seg: 0.4861
#
# Epoch 00155: val_loss did not improve from 0.22509
# Epoch 156/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.1975 - dice_coef: 0.7320 - iou_seg: 0.4191 - val_loss: 0.2249 - val_dice_coef: 0.6782 - val_iou_seg: 0.4786
#
# Epoch 00156: val_loss improved from 0.22509 to 0.22493, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 157/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.1960 - dice_coef: 0.7339 - iou_seg: 0.4155 - val_loss: 0.2363 - val_dice_coef: 0.6465 - val_iou_seg: 0.5087
#
# Epoch 00157: val_loss did not improve from 0.22493
# Epoch 158/1000
# 341/341 [==============================] - 258s 757ms/step - loss: 0.1974 - dice_coef: 0.7312 - iou_seg: 0.4189 - val_loss: 0.2370 - val_dice_coef: 0.6488 - val_iou_seg: 0.5088
#
# Epoch 00158: val_loss did not improve from 0.22493
# Epoch 159/1000
# 341/341 [==============================] - 259s 760ms/step - loss: 0.2011 - dice_coef: 0.7256 - iou_seg: 0.4271 - val_loss: 0.2338 - val_dice_coef: 0.6637 - val_iou_seg: 0.4967
#
# Epoch 00159: val_loss did not improve from 0.22493
# Epoch 160/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1994 - dice_coef: 0.7281 - iou_seg: 0.4233 - val_loss: 0.2306 - val_dice_coef: 0.6581 - val_iou_seg: 0.4975
#
# Epoch 00160: val_loss did not improve from 0.22493
# Epoch 161/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1983 - dice_coef: 0.7298 - iou_seg: 0.4207 - val_loss: 0.2298 - val_dice_coef: 0.6656 - val_iou_seg: 0.4910
#
# Epoch 00161: val_loss did not improve from 0.22493
# Epoch 162/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1987 - dice_coef: 0.7292 - iou_seg: 0.4215 - val_loss: 0.2339 - val_dice_coef: 0.6630 - val_iou_seg: 0.4939
#
# Epoch 00162: val_loss did not improve from 0.22493
# Epoch 163/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1979 - dice_coef: 0.7306 - iou_seg: 0.4200 - val_loss: 0.2276 - val_dice_coef: 0.6702 - val_iou_seg: 0.4875
# Epoch 00163: val_loss did not improve from 0.22493
# Epoch 164/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2008 - dice_coef: 0.7259 - iou_seg: 0.4263 - val_loss: 0.2256 - val_dice_coef: 0.6779 - val_iou_seg: 0.4784
#
# Epoch 00164: val_loss did not improve from 0.22493
# Epoch 165/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1971 - dice_coef: 0.7320 - iou_seg: 0.4183 - val_loss: 0.2325 - val_dice_coef: 0.6553 - val_iou_seg: 0.5014
#
# Epoch 00165: val_loss did not improve from 0.22493
# Epoch 166/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1951 - dice_coef: 0.7359 - iou_seg: 0.4138 - val_loss: 0.2292 - val_dice_coef: 0.6654 - val_iou_seg: 0.4927
#
# Epoch 00166: val_loss did not improve from 0.22493
# Epoch 167/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.1958 - dice_coef: 0.7346 - iou_seg: 0.4152 - val_loss: 0.2222 - val_dice_coef: 0.6794 - val_iou_seg: 0.4763
#
# Epoch 00167: val_loss improved from 0.22493 to 0.22219, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 168/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1971 - dice_coef: 0.7316 - iou_seg: 0.4180 - val_loss: 0.2234 - val_dice_coef: 0.6796 - val_iou_seg: 0.4761
#
# Epoch 00168: val_loss did not improve from 0.22219
# Epoch 169/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.1956 - dice_coef: 0.7349 - iou_seg: 0.4149 - val_loss: 0.2279 - val_dice_coef: 0.6735 - val_iou_seg: 0.4836
#
# Epoch 00169: val_loss did not improve from 0.22219
# Epoch 170/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1963 - dice_coef: 0.7333 - iou_seg: 0.4163 - val_loss: 0.2290 - val_dice_coef: 0.6710 - val_iou_seg: 0.4871
#
# Epoch 00170: val_loss did not improve from 0.22219
# Epoch 171/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.1943 - dice_coef: 0.7373 - iou_seg: 0.4122 - val_loss: 0.2313 - val_dice_coef: 0.6638 - val_iou_seg: 0.4948
#
# Epoch 00171: val_loss did not improve from 0.22219
# Epoch 172/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1995 - dice_coef: 0.7269 - iou_seg: 0.4232 - val_loss: 0.2322 - val_dice_coef: 0.6548 - val_iou_seg: 0.5018
#
# Epoch 00172: val_loss did not improve from 0.22219
# Epoch 173/1000
# 341/341 [==============================] - 258s 757ms/step - loss: 0.1996 - dice_coef: 0.7275 - iou_seg: 0.4236 - val_loss: 0.2282 - val_dice_coef: 0.6646 - val_iou_seg: 0.4908
#
# Epoch 00173: val_loss did not improve from 0.22219
# Epoch 174/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1981 - dice_coef: 0.7311 - iou_seg: 0.4205 - val_loss: 0.2253 - val_dice_coef: 0.6762 - val_iou_seg: 0.4801
#
# Epoch 00174: val_loss did not improve from 0.22219
# Epoch 175/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.1966 - dice_coef: 0.7333 - iou_seg: 0.4172 - val_loss: 0.2355 - val_dice_coef: 0.6520 - val_iou_seg: 0.5058
#
# Epoch 00175: val_loss did not improve from 0.22219
# Epoch 176/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1965 - dice_coef: 0.7332 - iou_seg: 0.4170 - val_loss: 0.2339 - val_dice_coef: 0.6536 - val_iou_seg: 0.5045
#
# Epoch 00176: val_loss did not improve from 0.22219
# Epoch 177/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.1932 - dice_coef: 0.7394 - iou_seg: 0.4097 - val_loss: 0.2242 - val_dice_coef: 0.6788 - val_iou_seg: 0.4769
#
# Epoch 00177: val_loss did not improve from 0.22219
# Epoch 178/1000
# 341/341 [==============================] - 258s 757ms/step - loss: 0.1938 - dice_coef: 0.7379 - iou_seg: 0.4110 - val_loss: 0.2269 - val_dice_coef: 0.6643 - val_iou_seg: 0.4909
#
# Epoch 00178: val_loss did not improve from 0.22219
# Epoch 179/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1956 - dice_coef: 0.7349 - iou_seg: 0.4150 - val_loss: 0.2292 - val_dice_coef: 0.6624 - val_iou_seg: 0.4922
#
# Epoch 00179: val_loss did not improve from 0.22219
# Epoch 180/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1940 - dice_coef: 0.7377 - iou_seg: 0.4115 - val_loss: 0.2392 - val_dice_coef: 0.6464 - val_iou_seg: 0.5116
#
# Epoch 00180: val_loss did not improve from 0.22219
# Epoch 181/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1952 - dice_coef: 0.7354 - iou_seg: 0.4142 - val_loss: 0.2541 - val_dice_coef: 0.6215 - val_iou_seg: 0.5402
#
# Epoch 00181: val_loss did not improve from 0.22219
# Epoch 182/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.2048 - dice_coef: 0.7180 - iou_seg: 0.4348 - val_loss: 0.2299 - val_dice_coef: 0.6653 - val_iou_seg: 0.4923
#
# Epoch 00182: val_loss did not improve from 0.22219
# Epoch 183/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.1938 - dice_coef: 0.7381 - iou_seg: 0.4111 - val_loss: 0.2297 - val_dice_coef: 0.6650 - val_iou_seg: 0.4917
#
# Epoch 00183: val_loss did not improve from 0.22219
# Epoch 184/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1908 - dice_coef: 0.7436 - iou_seg: 0.4048 - val_loss: 0.2271 - val_dice_coef: 0.6690 - val_iou_seg: 0.4871
#
# Epoch 00184: val_loss did not improve from 0.22219
# Epoch 185/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1923 - dice_coef: 0.7412 - iou_seg: 0.4079 - val_loss: 0.2227 - val_dice_coef: 0.6854 - val_iou_seg: 0.4725
#
# Epoch 00185: val_loss did not improve from 0.22219
# Epoch 186/1000
# 341/341 [==============================] - 258s 757ms/step - loss: 0.1915 - dice_coef: 0.7420 - iou_seg: 0.4059 - val_loss: 0.2258 - val_dice_coef: 0.6789 - val_iou_seg: 0.4794
#
# Epoch 00186: val_loss did not improve from 0.22219
# Epoch 187/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1918 - dice_coef: 0.7415 - iou_seg: 0.4067 - val_loss: 0.2406 - val_dice_coef: 0.6419 - val_iou_seg: 0.5168
#
# Epoch 00187: val_loss did not improve from 0.22219
# Epoch 188/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1910 - dice_coef: 0.7434 - iou_seg: 0.4050 - val_loss: 0.2216 - val_dice_coef: 0.6812 - val_iou_seg: 0.4743
#
# Epoch 00188: val_loss improved from 0.22219 to 0.22156, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 189/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.1894 - dice_coef: 0.7456 - iou_seg: 0.4017 - val_loss: 0.2219 - val_dice_coef: 0.6784 - val_iou_seg: 0.4768
#
# Epoch 00189: val_loss did not improve from 0.22156
# Epoch 190/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1936 - dice_coef: 0.7382 - iou_seg: 0.4106 - val_loss: 0.2283 - val_dice_coef: 0.6689 - val_iou_seg: 0.4881
#
# Epoch 00190: val_loss did not improve from 0.22156
# Epoch 191/1000
# 341/341 [==============================] - 259s 760ms/step - loss: 0.1917 - dice_coef: 0.7420 - iou_seg: 0.4066 - val_loss: 0.2271 - val_dice_coef: 0.6653 - val_iou_seg: 0.4899
#
# Epoch 00191: val_loss did not improve from 0.22156
# Epoch 192/1000
# ...
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1804 - dice_coef: 0.7614 - iou_seg: 0.3821 - val_loss: 0.2302 - val_dice_coef: 0.6702 - val_iou_seg: 0.4885
#
# Epoch 00246: val_loss did not improve from 0.22015
# Epoch 247/1000
# 341/341 [==============================] - 259s 759ms/step - loss: 0.1828 - dice_coef: 0.7571 - iou_seg: 0.3873 - val_loss: 0.2310 - val_dice_coef: 0.6668 - val_iou_seg: 0.4926
#
# Epoch 00247: val_loss did not improve from 0.22015
# Epoch 248/1000
# 341/341 [==============================] - 270s 793ms/step - loss: 0.1801 - dice_coef: 0.7619 - iou_seg: 0.3813 - val_loss: 0.2293 - val_dice_coef: 0.6676 - val_iou_seg: 0.4898
#
# Epoch 00248: val_loss did not improve from 0.22015
# Epoch 249/1000
# 341/341 [==============================] - 271s 797ms/step - loss: 0.1870 - dice_coef: 0.7497 - iou_seg: 0.3962 - val_loss: 0.2253 - val_dice_coef: 0.6742 - val_iou_seg: 0.4830
#
# Epoch 00249: val_loss did not improve from 0.22015
# Epoch 250/1000
# 341/341 [==============================] - 270s 791ms/step - loss: 0.1794 - dice_coef: 0.7632 - iou_seg: 0.3796 - val_loss: 0.2278 - val_dice_coef: 0.6668 - val_iou_seg: 0.4887
#
# Epoch 00250: val_loss did not improve from 0.22015
# Epoch 251/1000
# 341/341 [==============================] - 269s 789ms/step - loss: 0.1813 - dice_coef: 0.7599 - iou_seg: 0.3839 - val_loss: 0.2186 - val_dice_coef: 0.6865 - val_iou_seg: 0.4681
#
# Epoch 00251: val_loss improved from 0.22015 to 0.21864, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 252/1000
# 341/341 [==============================] - 270s 792ms/step - loss: 0.1839 - dice_coef: 0.7552 - iou_seg: 0.3895 - val_loss: 0.2248 - val_dice_coef: 0.6663 - val_iou_seg: 0.4880
#
# Epoch 00252: val_loss did not improve from 0.21864
# Epoch 253/1000
# 341/341 [==============================] - 270s 793ms/step - loss: 0.1830 - dice_coef: 0.7571 - iou_seg: 0.3877 - val_loss: 0.2220 - val_dice_coef: 0.6836 - val_iou_seg: 0.4731
#
# Epoch 00253: val_loss did not improve from 0.21864
# Epoch 254/1000
# 341/341 [==============================] - 269s 789ms/step - loss: 0.1774 - dice_coef: 0.7664 - iou_seg: 0.3754 - val_loss: 0.2291 - val_dice_coef: 0.6681 - val_iou_seg: 0.4895
#
# Epoch 00254: val_loss did not improve from 0.21864
# Epoch 255/1000
# 341/341 [==============================] - 267s 783ms/step - loss: 0.1822 - dice_coef: 0.7583 - iou_seg: 0.3858 - val_loss: 0.2222 - val_dice_coef: 0.6832 - val_iou_seg: 0.4725
#
# Epoch 00255: val_loss did not improve from 0.21864
# Epoch 256/1000
# 341/341 [==============================] - 270s 792ms/step - loss: 0.1778 - dice_coef: 0.7657 - iou_seg: 0.3763 - val_loss: 0.2240 - val_dice_coef: 0.6788 - val_iou_seg: 0.4770
#
# Epoch 00256: val_loss did not improve from 0.21864
# Epoch 257/1000
# 341/341 [==============================] - 269s 788ms/step - loss: 0.1770 - dice_coef: 0.7672 - iou_seg: 0.3745 - val_loss: 0.2289 - val_dice_coef: 0.6672 - val_iou_seg: 0.4902
#
# Epoch 00257: val_loss did not improve from 0.21864
# Epoch 258/1000
# 341/341 [==============================] - 269s 791ms/step - loss: 0.1805 - dice_coef: 0.7611 - iou_seg: 0.3821 - val_loss: 0.2253 - val_dice_coef: 0.6772 - val_iou_seg: 0.4796
#
# Epoch 00258: val_loss did not improve from 0.21864
# Epoch 259/1000
# 341/341 [==============================] - 271s 796ms/step - loss: 0.1788 - dice_coef: 0.7644 - iou_seg: 0.3786 - val_loss: 0.2239 - val_dice_coef: 0.6763 - val_iou_seg: 0.4789
#
# Epoch 00259: val_loss did not improve from 0.21864
# Epoch 260/1000
# 341/341 [==============================] - 272s 799ms/step - loss: 0.1807 - dice_coef: 0.7610 - iou_seg: 0.3828 - val_loss: 0.2174 - val_dice_coef: 0.6920 - val_iou_seg: 0.4630
#
# Epoch 00260: val_loss improved from 0.21864 to 0.21735, saving model to models\bactunet_3frame_local_dice.hdf5
# Epoch 261/1000
# 341/341 [==============================] - 261s 767ms/step - loss: 0.1830 - dice_coef: 0.7568 - iou_seg: 0.3876 - val_loss: 0.2232 - val_dice_coef: 0.6856 - val_iou_seg: 0.4722
#
# Epoch 00261: val_loss did not improve from 0.21735
# Epoch 262/1000
# 341/341 [==============================] - 265s 778ms/step - loss: 0.1804 - dice_coef: 0.7617 - iou_seg: 0.3819 - val_loss: 0.2228 - val_dice_coef: 0.6827 - val_iou_seg: 0.4739
#
# Epoch 00262: val_loss did not improve from 0.21735
# Epoch 263/1000
# 341/341 [==============================] - 271s 794ms/step - loss: 0.1777 - dice_coef: 0.7660 - iou_seg: 0.3761 - val_loss: 0.2276 - val_dice_coef: 0.6714 - val_iou_seg: 0.4849
# Epoch 00263: val_loss did not improve from 0.21735
# Epoch 264/1000
# 341/341 [==============================] - 269s 788ms/step - loss: 0.1766 - dice_coef: 0.7678 - iou_seg: 0.3736 - val_loss: 0.2229 - val_dice_coef: 0.6763 - val_iou_seg: 0.4785
#
# Epoch 00264: val_loss did not improve from 0.21735
# Epoch 265/1000
# 341/341 [==============================] - 260s 764ms/step - loss: 0.1806 - dice_coef: 0.7610 - iou_seg: 0.3824 - val_loss: 0.2305 - val_dice_coef: 0.6648 - val_iou_seg: 0.4937
#
# Epoch 00265: val_loss did not improve from 0.21735
# Epoch 266/1000
# 341/341 [==============================] - 268s 785ms/step - loss: 0.1789 - dice_coef: 0.7641 - iou_seg: 0.3787 - val_loss: 0.2199 - val_dice_coef: 0.6900 - val_iou_seg: 0.4658
#
# Epoch 00266: val_loss did not improve from 0.21735
# Epoch 267/1000
# 341/341 [==============================] - 263s 772ms/step - loss: 0.1830 - dice_coef: 0.7572 - iou_seg: 0.3876 - val_loss: 0.2184 - val_dice_coef: 0.6888 - val_iou_seg: 0.4666
#
# Epoch 00267: val_loss did not improve from 0.21735
# Epoch 268/1000
# 341/341 [==============================] - 270s 793ms/step - loss: 0.1773 - dice_coef: 0.7669 - iou_seg: 0.3752 - val_loss: 0.2258 - val_dice_coef: 0.6718 - val_iou_seg: 0.4835
#
# Epoch 00268: val_loss did not improve from 0.21735
# Epoch 269/1000
# 341/341 [==============================] - 271s 795ms/step - loss: 0.1817 - dice_coef: 0.7591 - iou_seg: 0.3847 - val_loss: 0.2220 - val_dice_coef: 0.6850 - val_iou_seg: 0.4712
#
# Epoch 00269: val_loss did not improve from 0.21735
# Epoch 270/1000
# 341/341 [==============================] - 270s 792ms/step - loss: 0.1777 - dice_coef: 0.7660 - iou_seg: 0.3760 - val_loss: 0.2220 - val_dice_coef: 0.6778 - val_iou_seg: 0.4769
#
# Epoch 00270: val_loss did not improve from 0.21735
# Epoch 271/1000
# 341/341 [==============================] - 270s 792ms/step - loss: 0.1742 - dice_coef: 0.7723 - iou_seg: 0.3685 - val_loss: 0.2230 - val_dice_coef: 0.6733 - val_iou_seg: 0.4818
#
# Epoch 00271: val_loss did not improve from 0.21735
# Epoch 272/1000
# 341/341 [==============================] - 268s 787ms/step - loss: 0.1788 - dice_coef: 0.7640 - iou_seg: 0.3784 - val_loss: 0.2233 - val_dice_coef: 0.6783 - val_iou_seg: 0.4783
#
# Epoch 00272: val_loss did not improve from 0.21735
# Epoch 273/1000
# 341/341 [==============================] - 267s 784ms/step - loss: 0.1792 - dice_coef: 0.7631 - iou_seg: 0.3793 - val_loss: 0.2248 - val_dice_coef: 0.6730 - val_iou_seg: 0.4828
#
# Epoch 00273: val_loss did not improve from 0.21735
# Epoch 274/1000
# 341/341 [==============================] - 271s 795ms/step - loss: 0.1785 - dice_coef: 0.7647 - iou_seg: 0.3776 - val_loss: 0.2230 - val_dice_coef: 0.6743 - val_iou_seg: 0.4801
#
# Epoch 00274: val_loss did not improve from 0.21735
# Epoch 275/1000
# 341/341 [==============================] - 271s 794ms/step - loss: 0.1764 - dice_coef: 0.7681 - iou_seg: 0.3733 - val_loss: 0.2199 - val_dice_coef: 0.6824 - val_iou_seg: 0.4732
#
# Epoch 00275: val_loss did not improve from 0.21735
# Epoch 276/1000
# 341/341 [==============================] - 272s 797ms/step - loss: 0.1735 - dice_coef: 0.7730 - iou_seg: 0.3670 - val_loss: 0.2202 - val_dice_coef: 0.6834 - val_iou_seg: 0.4713
#
# Epoch 00276: val_loss did not improve from 0.21735
# Epoch 277/1000
# 341/341 [==============================] - 266s 780ms/step - loss: 0.1791 - dice_coef: 0.7637 - iou_seg: 0.3792 - val_loss: 0.2236 - val_dice_coef: 0.6813 - val_iou_seg: 0.4745
#
# Epoch 00277: val_loss did not improve from 0.21735
# Epoch 278/1000
# 341/341 [==============================] - 264s 774ms/step - loss: 0.1748 - dice_coef: 0.7708 - iou_seg: 0.3698 - val_loss: 0.2207 - val_dice_coef: 0.6852 - val_iou_seg: 0.4708
#
# Epoch 00278: val_loss did not improve from 0.21735
# Epoch 279/1000
# 341/341 [==============================] - 271s 795ms/step - loss: 0.1765 - dice_coef: 0.7682 - iou_seg: 0.3734 - val_loss: 0.2474 - val_dice_coef: 0.6339 - val_iou_seg: 0.5259
#
# Epoch 00279: val_loss did not improve from 0.21735
# Epoch 280/1000
# 341/341 [==============================] - 262s 769ms/step - loss: 0.1784 - dice_coef: 0.7648 - iou_seg: 0.3777 - val_loss: 0.2217 - val_dice_coef: 0.6790 - val_iou_seg: 0.4755
#
# Epoch 00280: val_loss did not improve from 0.21735
# Epoch 281/1000
# 341/341 [==============================] - 261s 767ms/step - loss: 0.1763 - dice_coef: 0.7683 - iou_seg: 0.3732 - val_loss: 0.2193 - val_dice_coef: 0.6837 - val_iou_seg: 0.4703
#
# Epoch 00281: val_loss did not improve from 0.21735
# Epoch 282/1000
# 341/341 [==============================] - 259s 761ms/step - loss: 0.1799 - dice_coef: 0.7619 - iou_seg: 0.3807 - val_loss: 0.2232 - val_dice_coef: 0.6778 - val_iou_seg: 0.4771
#
# Epoch 00282: val_loss did not improve from 0.21735
# Epoch 283/1000
# 341/341 [==============================] - 260s 762ms/step - loss: 0.1773 - dice_coef: 0.7664 - iou_seg: 0.3751 - val_loss: 0.2262 - val_dice_coef: 0.6788 - val_iou_seg: 0.4794
#
# Epoch 00283: val_loss did not improve from 0.21735
# Epoch 284/1000
# 341/341 [==============================] - 260s 764ms/step - loss: 0.1732 - dice_coef: 0.7739 - iou_seg: 0.3662 - val_loss: 0.2273 - val_dice_coef: 0.6653 - val_iou_seg: 0.4909
#
# Epoch 00284: val_loss did not improve from 0.21735
# Epoch 285/1000
# 341/341 [==============================] - 260s 762ms/step - loss: 0.1760 - dice_coef: 0.7688 - iou_seg: 0.3722 - val_loss: 0.2247 - val_dice_coef: 0.6736 - val_iou_seg: 0.4823
#
# Epoch 00285: val_loss did not improve from 0.21735
# Epoch 286/1000
# 341/341 [==============================] - 260s 762ms/step - loss: 0.1770 - dice_coef: 0.7673 - iou_seg: 0.3744 - val_loss: 0.2350 - val_dice_coef: 0.6533 - val_iou_seg: 0.5034
#
# Epoch 00286: val_loss did not improve from 0.21735
# Epoch 287/1000
# 341/341 [==============================] - 260s 762ms/step - loss: 0.1757 - dice_coef: 0.7693 - iou_seg: 0.3719 - val_loss: 0.2216 - val_dice_coef: 0.6882 - val_iou_seg: 0.4679
#
# Epoch 00287: val_loss did not improve from 0.21735
# Epoch 288/1000
# 341/341 [==============================] - 259s 761ms/step - loss: 0.1759 - dice_coef: 0.7691 - iou_seg: 0.3721 - val_loss: 0.2235 - val_dice_coef: 0.6784 - val_iou_seg: 0.4787
#
# Epoch 00288: val_loss did not improve from 0.21735
# Epoch 289/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1781 - dice_coef: 0.7648 - iou_seg: 0.3769 - val_loss: 0.2186 - val_dice_coef: 0.6801 - val_iou_seg: 0.4741
#
# Epoch 00289: val_loss did not improve from 0.21735
# Epoch 290/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1745 - dice_coef: 0.7711 - iou_seg: 0.3691 - val_loss: 0.2221 - val_dice_coef: 0.6848 - val_iou_seg: 0.4716
#
# Epoch 00290: val_loss did not improve from 0.21735
# Epoch 291/1000
# 341/341 [==============================] - 258s 758ms/step - loss: 0.1753 - dice_coef: 0.7701 - iou_seg: 0.3709 - val_loss: 0.2280 - val_dice_coef: 0.6718 - val_iou_seg: 0.4859
#
# Epoch 00291: val_loss did not improve from 0.21735
# Epoch 292/1000
# 341/341 [==============================] - 261s 765ms/step - loss: 0.1755 - dice_coef: 0.7700 - iou_seg: 0.3713 - val_loss: 0.2226 - val_dice_coef: 0.6841 - val_iou_seg: 0.4725
#
# Epoch 00292: val_loss did not improve from 0.21735
# Epoch 293/1000
# 341/341 [==============================] - 262s 769ms/step - loss: 0.1755 - dice_coef: 0.7696 - iou_seg: 0.3713 - val_loss: 0.2234 - val_dice_coef: 0.6791 - val_iou_seg: 0.4773
#
# Epoch 00293: val_loss did not improve from 0.21735
# Epoch 294/1000
# 341/341 [==============================] - 261s 767ms/step - loss: 0.1779 - dice_coef: 0.7655 - iou_seg: 0.3763 - val_loss: 0.2281 - val_dice_coef: 0.6709 - val_iou_seg: 0.4866
#
# Epoch 00294: val_loss did not improve from 0.21735
# Epoch 295/1000
# 341/341 [==============================] - 267s 782ms/step - loss: 0.1733 - dice_coef: 0.7733 - iou_seg: 0.3663 - val_loss: 0.2180 - val_dice_coef: 0.6862 - val_iou_seg: 0.4678
#
# Epoch 00295: val_loss did not improve from 0.21735
# Epoch 296/1000
# 341/341 [==============================] - 269s 790ms/step - loss: 0.1783 - dice_coef: 0.7648 - iou_seg: 0.3773 - val_loss: 0.2232 - val_dice_coef: 0.6801 - val_iou_seg: 0.4770
#
# Epoch 00296: val_loss did not improve from 0.21735
# Epoch 297/1000
# 341/341 [==============================] - 268s 785ms/step - loss: 0.1726 - dice_coef: 0.7745 - iou_seg: 0.3648 - val_loss: 0.2273 - val_dice_coef: 0.6704 - val_iou_seg: 0.4870
#
# Epoch 00297: val_loss did not improve from 0.21735
# Epoch 298/1000
# 341/341 [==============================] - 263s 771ms/step - loss: 0.1756 - dice_coef: 0.7693 - iou_seg: 0.3712 - val_loss: 0.2238 - val_dice_coef: 0.6803 - val_iou_seg: 0.4762
#
# Epoch 00298: val_loss did not improve from 0.21735
# Epoch 299/1000
# 341/341 [==============================] - 263s 772ms/step - loss: 0.1735 - dice_coef: 0.7730 - iou_seg: 0.3668 - val_loss: 0.2179 - val_dice_coef: 0.6915 - val_iou_seg: 0.4634
#
# Epoch 00299: val_loss did not improve from 0.21735
# Epoch 300/1000
# 341/341 [==============================] - 262s 769ms/step - loss: 0.1734 - dice_coef: 0.7732 - iou_seg: 0.3667 - val_loss: 0.2225 - val_dice_coef: 0.6753 - val_iou_seg: 0.4790
#
# Epoch 00300: val_loss did not improve from 0.21735
# Epoch 301/1000
# 341/341 [==============================] - 263s 773ms/step - loss: 0.1732 - dice_coef: 0.7737 - iou_seg: 0.3661 - val_loss: 0.2187 - val_dice_coef: 0.6783 - val_iou_seg: 0.4753
#
# Epoch 00301: val_loss did not improve from 0.21735
# Epoch 302/1000
# 341/341 [==============================] - 267s 783ms/step - loss: 0.1721 - dice_coef: 0.7756 - iou_seg: 0.3639 - val_loss: 0.2233 - val_dice_coef: 0.6788 - val_iou_seg: 0.4772
#
# Epoch 00302: val_loss did not improve from 0.21735
# Epoch 303/1000
# 341/341 [==============================] - 266s 781ms/step - loss: 0.1712 - dice_coef: 0.7767 - iou_seg: 0.3616 - val_loss: 0.2235 - val_dice_coef: 0.6794 - val_iou_seg: 0.4772
#
# Epoch 00303: val_loss did not improve from 0.21735
# Epoch 304/1000
# 341/341 [==============================] - 264s 775ms/step - loss: 0.1720 - dice_coef: 0.7756 - iou_seg: 0.3636 - val_loss: 0.2188 - val_dice_coef: 0.6828 - val_iou_seg: 0.4711
#
# Epoch 00304: val_loss did not improve from 0.21735
# Epoch 305/1000
# 341/341 [==============================] - 265s 777ms/step - loss: 0.1727 - dice_coef: 0.7741 - iou_seg: 0.3649 - val_loss: 0.2188 - val_dice_coef: 0.6885 - val_iou_seg: 0.4657
#
# Epoch 00305: val_loss did not improve from 0.21735
# Epoch 306/1000
# 341/341 [==============================] - 263s 773ms/step - loss: 0.1749 - dice_coef: 0.7704 - iou_seg: 0.3697 - val_loss: 0.2234 - val_dice_coef: 0.6819 - val_iou_seg: 0.4744
#
# Epoch 00306: val_loss did not improve from 0.21735
# Epoch 307/1000
# 341/341 [==============================] - 263s 773ms/step - loss: 0.1736 - dice_coef: 0.7730 - iou_seg: 0.3671 - val_loss: 0.2232 - val_dice_coef: 0.6862 - val_iou_seg: 0.4706
#
# Epoch 00307: val_loss did not improve from 0.21735
# Epoch 308/1000
# 341/341 [==============================] - 262s 770ms/step - loss: 0.1727 - dice_coef: 0.7742 - iou_seg: 0.3650 - val_loss: 0.2186 - val_dice_coef: 0.6932 - val_iou_seg: 0.4627
#
# Epoch 00308: val_loss did not improve from 0.21735
# Epoch 309/1000
# 341/341 [==============================] - 264s 773ms/step - loss: 0.1724 - dice_coef: 0.7750 - iou_seg: 0.3644 - val_loss: 0.2308 - val_dice_coef: 0.6683 - val_iou_seg: 0.4890
#
# Epoch 00309: val_loss did not improve from 0.21735
# Epoch 310/1000
# 341/341 [==============================] - 264s 774ms/step - loss: 0.1728 - dice_coef: 0.7746 - iou_seg: 0.3654 - val_loss: 0.2191 - val_dice_coef: 0.6850 - val_iou_seg: 0.4696
#
# Epoch 00310: val_loss did not improve from 0.21735
# Epoch 00310: early stopping

# %%
model.load_weights(r"models/bactunet_3frame_local_dice.hdf5")

# %%
# ##################################
# #IOU
y_pred = model.predict(X_test)
IOUs = []
dices = []
thresh = []

for threshold in range(0, 11):
  threshold = threshold/10
  y_pred_thresholded = y_pred > threshold
  intersection = np.logical_and(y_test, y_pred_thresholded)
  union = np.logical_or(y_test, y_pred_thresholded)
  iou_score = np.sum(intersection) / np.sum(union)
  dice_c = 0#losses.dice_coef(y_test, y_pred)
  print("IoU socre is: ", round(iou_score, 4), "Dice coeff is: ", round(dice_c, 4),"at threshold: ", threshold)
  IOUs.append(iou_score)
  thresh.append(threshold)
  dices.append(dice_c)

#plot IOUs vs threshold
plt.plot(thresh, IOUs, 'r', label='IOU')
plt.plot(thresh, dices, 'b', label='Dice coeff')
plt.title('IOU & dice vs threshold')
plt.xlabel('Threshold')
plt.ylabel('IOU')
plt.show()
# Out:
# IoU socre is:  0.0072 Dice coeff is:  0 at threshold:  0.0
# IoU socre is:  0.5253 Dice coeff is:  0 at threshold:  0.1
# IoU socre is:  0.5257 Dice coeff is:  0 at threshold:  0.2
# IoU socre is:  0.526 Dice coeff is:  0 at threshold:  0.3
# IoU socre is:  0.5262 Dice coeff is:  0 at threshold:  0.4
# IoU socre is:  0.5264 Dice coeff is:  0 at threshold:  0.5
# IoU socre is:  0.5265 Dice coeff is:  0 at threshold:  0.6
# IoU socre is:  0.5267 Dice coeff is:  0 at threshold:  0.7
# IoU socre is:  0.5269 Dice coeff is:  0 at threshold:  0.8
# IoU socre is:  0.5272 Dice coeff is:  0 at threshold:  0.9
# IoU socre is:  0.0 Dice coeff is:  0 at threshold:  1.0

# %%
#######################################################################
#Predict on a few images
#model = get_model()
#model.load_weights('mitochondria_50_plus_100_epochs.hdf5') #Trained for 50 epochs and then additional 100
#model.load_weights('mitochondria_gpu_tf1.4.hdf5')  #Trained for 50 epochs¨
#import pickle
#with open("/content/gdrive/MyDrive/Colab Notebooks/BT0403/model_folder/bactunet_3frame_25ep_history") as fh:
#    history = pickle.load(fh)

idx=random.randint(0, (len(X_test)))

plt.figure(figsize=(16, 8))
plt.subplot(131)
plt.title('Testing Image')
plt.imshow(X_test[idx, 1, :, : ])
plt.subplot(132)
plt.title('Testing Label')
plt.imshow(y_test[idx, 0, : , :])
plt.subplot(133)
plt.title('Prediction on test image')
plt.imshow(y_pred[idx, 0, :, :])

plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['dice_coef']
#acc = history.history['accuracy']
val_acc = history.history['val_dice_coef']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import math 
from patchify import unpatchify

#######
#THERE IS A BUG HERE!!! FIX PREDICTION AND UNPATCHING


def _createOutArr(shape, nrows, ncols, nchannels):
    out_height = int(nrows * shape[-2])
    out_width = int(ncols * shape[-1])
    out_frames = int(shape[0] / (nrows * ncols))
    outshape = (out_frames, nchannels, out_height, out_width)
    out_arr = np.empty(outshape, dtype=np.float32)

    return out_arr

def unpatcher(arr, nrows, ncols, nchannels=1):
    out_arr = _createOutArr(arr.shape, nrows, ncols, nchannels)
    patch_h = arr.shape[-2]
    patch_w = arr.shape[-1]
    n = 0
    for frame in range(out_arr.shape[0]):
        for i in range(nrows):
            for j in range(ncols):
                y = patch_h * i
                x = patch_w * j
                out_arr[frame, :, y:y+patch_h, x:x+patch_w] = arr[n]
                n += 1

    return out_arr

#load unseen data

validation_image_directory = r"C:\Users\analyst\Documents\Python Scripts\BactUnet\Bactnet\Training data\stacks\predict"
result_folder = r"C:\Users\analyst\Documents\Python Scripts\BactUnet\_results"

val_image_dataset = []
val_mask_dataset = []
pred_mask_dataset = []

images = os.listdir(validation_image_directory)

for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'tif'):
        
        image = tiff.imread(os.path.join(validation_image_directory, image_name))
        original_shape = image.shape
        patch = patch_stack(image, SIZE)
        
        patch = normalizePercentile(patch, 0.1, 99.9, clip=True)
        pred_mask_patch = model.predict(patch)
        print(image_name, original_shape, patch.shape, pred_mask_patch.shape)
        #pred_mask_patch = pred_mask_patch[:, 0, :,:]
        image = np.expand_dims(patch[:, 1, :,:], axis=1)
        patch = np.concatenate((image, pred_mask_patch), axis=1)
        unpatched = unpatcher(patch, 8, 8, 2)
        print(patch.shape)
        tiff.imwrite(os.path.join(result_folder, image_name), unpatched, imagej=True, resolution=(1./2.6755, 1./2.6755),
                      metadata={'unit': 'um', 'finterval': 15,
                                'axes': 'TCYX'})
        
        #pred_mask = unpatch_stack(pred_mask_patch, original_shape)
        #tiff.imsave(os.path.join(result_folder, image_name), pred_mask_patch)
        #val_image_dataset.append(image)
        #pred_mask_dataset.append(pred_mask)
# Out:
# BT0398_210.tif (11, 2304, 2304) (576, 3, 288, 288) (576, 1, 288, 288)
# (576, 2, 288, 288)
# BT403_013.tif (12, 2304, 2304) (640, 3, 288, 288) (640, 1, 288, 288)
# (640, 2, 288, 288)
# BT403_216.tif (12, 2304, 2304) (640, 3, 288, 288) (640, 1, 288, 288)
# (640, 2, 288, 288)
# BT404_001.tif (12, 2304, 2304) (640, 3, 288, 288) (640, 1, 288, 288)
# (640, 2, 288, 288)

# %%
#Let's try a full movie

image_directory = r"C:\Users\analyst\Documents\Python Scripts\BactUnet\Bactnet\BT404_ENRRT_wt"
fname = "BT404_ENR+RT_wt.tif"
result_folder = r"C:\Users\analyst\Documents\Python Scripts\BactUnet\_results\BT404"

loadme = os.path.join(image_directory, fname)
image = tiff.imread(loadme)
original_shape = image.shape
patch = patch_stack(image, SIZE)
print(original_shape, patch.shape)

#split into smaller predictions
patchlist = np.split(patch, 238)
print(patchlist[0].shape)
for i, p in enumerate(patchlist):
    p = normalizePercentile(p, 0.1, 99.9, clip=True)
    pred_mask_patch = model.predict(p)
    unpatched = unpatcher(pred_mask_patch, 8, 8, 1)
    #unpatched = unpatched.astype('uint8')
    savename = "BT404_" + str(i+1) + ".tif"
    print(savename, unpatched.shape)
    tiff.imwrite(os.path.join(result_folder, savename), unpatched, imagej=True, resolution=(1./2.6755, 1./2.6755),
                 metadata={'unit': 'um', 'finterval': 15, 'axes': 'TCYX'})
# Out:
# (240, 2304, 2304) (15232, 3, 288, 288)
# (64, 3, 288, 288)
# BT404_1.tif (1, 1, 2304, 2304)
# BT404_2.tif (1, 1, 2304, 2304)
# BT404_3.tif (1, 1, 2304, 2304)
# BT404_4.tif (1, 1, 2304, 2304)
# BT404_5.tif (1, 1, 2304, 2304)
# BT404_6.tif (1, 1, 2304, 2304)
# BT404_7.tif (1, 1, 2304, 2304)
# BT404_8.tif (1, 1, 2304, 2304)
# BT404_9.tif (1, 1, 2304, 2304)
# BT404_10.tif (1, 1, 2304, 2304)
# BT404_11.tif (1, 1, 2304, 2304)
# BT404_12.tif (1, 1, 2304, 2304)
# BT404_13.tif (1, 1, 2304, 2304)
# BT404_14.tif (1, 1, 2304, 2304)
# BT404_15.tif (1, 1, 2304, 2304)
# BT404_16.tif (1, 1, 2304, 2304)
# BT404_17.tif (1, 1, 2304, 2304)
# BT404_18.tif (1, 1, 2304, 2304)
# BT404_19.tif (1, 1, 2304, 2304)
# BT404_20.tif (1, 1, 2304, 2304)
# BT404_21.tif (1, 1, 2304, 2304)
# BT404_22.tif (1, 1, 2304, 2304)
# BT404_23.tif (1, 1, 2304, 2304)
# BT404_24.tif (1, 1, 2304, 2304)
# BT404_25.tif (1, 1, 2304, 2304)
# BT404_26.tif (1, 1, 2304, 2304)
# BT404_27.tif (1, 1, 2304, 2304)
# BT404_28.tif (1, 1, 2304, 2304)
# BT404_29.tif (1, 1, 2304, 2304)
# BT404_30.tif (1, 1, 2304, 2304)
# BT404_31.tif (1, 1, 2304, 2304)
# BT404_32.tif (1, 1, 2304, 2304)
# BT404_33.tif (1, 1, 2304, 2304)
# BT404_34.tif (1, 1, 2304, 2304)
# BT404_35.tif (1, 1, 2304, 2304)
# BT404_36.tif (1, 1, 2304, 2304)
# BT404_37.tif (1, 1, 2304, 2304)
# BT404_38.tif (1, 1, 2304, 2304)
# BT404_39.tif (1, 1, 2304, 2304)
# BT404_40.tif (1, 1, 2304, 2304)
# BT404_41.tif (1, 1, 2304, 2304)
# BT404_42.tif (1, 1, 2304, 2304)
# BT404_43.tif (1, 1, 2304, 2304)
# BT404_44.tif (1, 1, 2304, 2304)
# BT404_45.tif (1, 1, 2304, 2304)
# BT404_46.tif (1, 1, 2304, 2304)
# BT404_47.tif (1, 1, 2304, 2304)
# BT404_48.tif (1, 1, 2304, 2304)
# BT404_49.tif (1, 1, 2304, 2304)
# BT404_50.tif (1, 1, 2304, 2304)
# BT404_51.tif (1, 1, 2304, 2304)
# BT404_52.tif (1, 1, 2304, 2304)
# BT404_53.tif (1, 1, 2304, 2304)
# BT404_54.tif (1, 1, 2304, 2304)
# BT404_55.tif (1, 1, 2304, 2304)
# BT404_56.tif (1, 1, 2304, 2304)
# BT404_57.tif (1, 1, 2304, 2304)
# BT404_58.tif (1, 1, 2304, 2304)
# BT404_59.tif (1, 1, 2304, 2304)
# BT404_60.tif (1, 1, 2304, 2304)
# BT404_61.tif (1, 1, 2304, 2304)
# BT404_62.tif (1, 1, 2304, 2304)
# BT404_63.tif (1, 1, 2304, 2304)
# BT404_64.tif (1, 1, 2304, 2304)
# BT404_65.tif (1, 1, 2304, 2304)
# BT404_66.tif (1, 1, 2304, 2304)
# BT404_67.tif (1, 1, 2304, 2304)
# BT404_68.tif (1, 1, 2304, 2304)
# BT404_69.tif (1, 1, 2304, 2304)
# BT404_70.tif (1, 1, 2304, 2304)
# BT404_71.tif (1, 1, 2304, 2304)
# BT404_72.tif (1, 1, 2304, 2304)
# BT404_73.tif (1, 1, 2304, 2304)
# BT404_74.tif (1, 1, 2304, 2304)
# BT404_75.tif (1, 1, 2304, 2304)
# BT404_76.tif (1, 1, 2304, 2304)
# BT404_77.tif (1, 1, 2304, 2304)
# BT404_78.tif (1, 1, 2304, 2304)
# BT404_79.tif (1, 1, 2304, 2304)
# BT404_80.tif (1, 1, 2304, 2304)
# BT404_81.tif (1, 1, 2304, 2304)
# BT404_82.tif (1, 1, 2304, 2304)
# BT404_83.tif (1, 1, 2304, 2304)
# BT404_84.tif (1, 1, 2304, 2304)
# BT404_85.tif (1, 1, 2304, 2304)
# BT404_86.tif (1, 1, 2304, 2304)
# BT404_87.tif (1, 1, 2304, 2304)
# BT404_88.tif (1, 1, 2304, 2304)
# BT404_89.tif (1, 1, 2304, 2304)
# BT404_90.tif (1, 1, 2304, 2304)
# BT404_91.tif (1, 1, 2304, 2304)
# BT404_92.tif (1, 1, 2304, 2304)
# BT404_93.tif (1, 1, 2304, 2304)
# BT404_94.tif (1, 1, 2304, 2304)
# BT404_95.tif (1, 1, 2304, 2304)
# BT404_96.tif (1, 1, 2304, 2304)
# BT404_97.tif (1, 1, 2304, 2304)
# BT404_98.tif (1, 1, 2304, 2304)
# BT404_99.tif (1, 1, 2304, 2304)
# BT404_100.tif (1, 1, 2304, 2304)
# BT404_101.tif (1, 1, 2304, 2304)
# BT404_102.tif (1, 1, 2304, 2304)
# BT404_103.tif (1, 1, 2304, 2304)
# BT404_104.tif (1, 1, 2304, 2304)
# BT404_105.tif (1, 1, 2304, 2304)
# BT404_106.tif (1, 1, 2304, 2304)
# BT404_107.tif (1, 1, 2304, 2304)
# BT404_108.tif (1, 1, 2304, 2304)
# BT404_109.tif (1, 1, 2304, 2304)
# BT404_110.tif (1, 1, 2304, 2304)
# BT404_111.tif (1, 1, 2304, 2304)
# BT404_112.tif (1, 1, 2304, 2304)
# BT404_113.tif (1, 1, 2304, 2304)
# BT404_114.tif (1, 1, 2304, 2304)
# BT404_115.tif (1, 1, 2304, 2304)
# BT404_116.tif (1, 1, 2304, 2304)
# BT404_117.tif (1, 1, 2304, 2304)
# BT404_118.tif (1, 1, 2304, 2304)
# BT404_119.tif (1, 1, 2304, 2304)
# BT404_120.tif (1, 1, 2304, 2304)
# BT404_121.tif (1, 1, 2304, 2304)
# BT404_122.tif (1, 1, 2304, 2304)
# BT404_123.tif (1, 1, 2304, 2304)
# BT404_124.tif (1, 1, 2304, 2304)
# BT404_125.tif (1, 1, 2304, 2304)
# BT404_126.tif (1, 1, 2304, 2304)
# BT404_127.tif (1, 1, 2304, 2304)
# BT404_128.tif (1, 1, 2304, 2304)
# BT404_129.tif (1, 1, 2304, 2304)
# BT404_130.tif (1, 1, 2304, 2304)
# BT404_131.tif (1, 1, 2304, 2304)
# BT404_132.tif (1, 1, 2304, 2304)
# BT404_133.tif (1, 1, 2304, 2304)
# BT404_134.tif (1, 1, 2304, 2304)
# BT404_135.tif (1, 1, 2304, 2304)
# BT404_136.tif (1, 1, 2304, 2304)
# BT404_137.tif (1, 1, 2304, 2304)
# BT404_138.tif (1, 1, 2304, 2304)
# BT404_139.tif (1, 1, 2304, 2304)
# BT404_140.tif (1, 1, 2304, 2304)
# BT404_141.tif (1, 1, 2304, 2304)
# BT404_142.tif (1, 1, 2304, 2304)
# BT404_143.tif (1, 1, 2304, 2304)
# BT404_144.tif (1, 1, 2304, 2304)
# BT404_145.tif (1, 1, 2304, 2304)
# BT404_146.tif (1, 1, 2304, 2304)
# BT404_147.tif (1, 1, 2304, 2304)
# BT404_148.tif (1, 1, 2304, 2304)
# BT404_149.tif (1, 1, 2304, 2304)
# BT404_150.tif (1, 1, 2304, 2304)
# BT404_151.tif (1, 1, 2304, 2304)
# BT404_152.tif (1, 1, 2304, 2304)
# BT404_153.tif (1, 1, 2304, 2304)
# BT404_154.tif (1, 1, 2304, 2304)
# BT404_155.tif (1, 1, 2304, 2304)
# BT404_156.tif (1, 1, 2304, 2304)
# BT404_157.tif (1, 1, 2304, 2304)
# BT404_158.tif (1, 1, 2304, 2304)
# BT404_159.tif (1, 1, 2304, 2304)
# BT404_160.tif (1, 1, 2304, 2304)
# BT404_161.tif (1, 1, 2304, 2304)
# BT404_162.tif (1, 1, 2304, 2304)
# BT404_163.tif (1, 1, 2304, 2304)
# BT404_164.tif (1, 1, 2304, 2304)
# BT404_165.tif (1, 1, 2304, 2304)
# BT404_166.tif (1, 1, 2304, 2304)
# BT404_167.tif (1, 1, 2304, 2304)
# BT404_168.tif (1, 1, 2304, 2304)
# BT404_169.tif (1, 1, 2304, 2304)
# BT404_170.tif (1, 1, 2304, 2304)
# BT404_171.tif (1, 1, 2304, 2304)
# BT404_172.tif (1, 1, 2304, 2304)
# BT404_173.tif (1, 1, 2304, 2304)
# BT404_174.tif (1, 1, 2304, 2304)
# BT404_175.tif (1, 1, 2304, 2304)
# BT404_176.tif (1, 1, 2304, 2304)
# BT404_177.tif (1, 1, 2304, 2304)
# BT404_178.tif (1, 1, 2304, 2304)
# BT404_179.tif (1, 1, 2304, 2304)
# BT404_180.tif (1, 1, 2304, 2304)
# BT404_181.tif (1, 1, 2304, 2304)
# BT404_182.tif (1, 1, 2304, 2304)
# BT404_183.tif (1, 1, 2304, 2304)
# BT404_184.tif (1, 1, 2304, 2304)
# BT404_185.tif (1, 1, 2304, 2304)
# BT404_186.tif (1, 1, 2304, 2304)
# BT404_187.tif (1, 1, 2304, 2304)
# BT404_188.tif (1, 1, 2304, 2304)
# BT404_189.tif (1, 1, 2304, 2304)
# BT404_190.tif (1, 1, 2304, 2304)
# BT404_191.tif (1, 1, 2304, 2304)
# BT404_192.tif (1, 1, 2304, 2304)
# BT404_193.tif (1, 1, 2304, 2304)
# BT404_194.tif (1, 1, 2304, 2304)
# BT404_195.tif (1, 1, 2304, 2304)
# BT404_196.tif (1, 1, 2304, 2304)
# BT404_197.tif (1, 1, 2304, 2304)
# BT404_198.tif (1, 1, 2304, 2304)
# BT404_199.tif (1, 1, 2304, 2304)
# BT404_200.tif (1, 1, 2304, 2304)
# BT404_201.tif (1, 1, 2304, 2304)
# BT404_202.tif (1, 1, 2304, 2304)
# BT404_203.tif (1, 1, 2304, 2304)
# BT404_204.tif (1, 1, 2304, 2304)
# BT404_205.tif (1, 1, 2304, 2304)
# BT404_206.tif (1, 1, 2304, 2304)
# BT404_207.tif (1, 1, 2304, 2304)
# BT404_208.tif (1, 1, 2304, 2304)
# BT404_209.tif (1, 1, 2304, 2304)
# BT404_210.tif (1, 1, 2304, 2304)
# BT404_211.tif (1, 1, 2304, 2304)
# BT404_212.tif (1, 1, 2304, 2304)
# BT404_213.tif (1, 1, 2304, 2304)
# BT404_214.tif (1, 1, 2304, 2304)
# BT404_215.tif (1, 1, 2304, 2304)
# BT404_216.tif (1, 1, 2304, 2304)
# BT404_217.tif (1, 1, 2304, 2304)
# BT404_218.tif (1, 1, 2304, 2304)
# BT404_219.tif (1, 1, 2304, 2304)
# BT404_220.tif (1, 1, 2304, 2304)
# BT404_221.tif (1, 1, 2304, 2304)
# BT404_222.tif (1, 1, 2304, 2304)
# BT404_223.tif (1, 1, 2304, 2304)
# BT404_224.tif (1, 1, 2304, 2304)
# BT404_225.tif (1, 1, 2304, 2304)
# BT404_226.tif (1, 1, 2304, 2304)
# BT404_227.tif (1, 1, 2304, 2304)
# BT404_228.tif (1, 1, 2304, 2304)
# BT404_229.tif (1, 1, 2304, 2304)
# BT404_230.tif (1, 1, 2304, 2304)
# BT404_231.tif (1, 1, 2304, 2304)
# BT404_232.tif (1, 1, 2304, 2304)
# BT404_233.tif (1, 1, 2304, 2304)
# BT404_234.tif (1, 1, 2304, 2304)
# BT404_235.tif (1, 1, 2304, 2304)
# BT404_236.tif (1, 1, 2304, 2304)
# BT404_237.tif (1, 1, 2304, 2304)
# BT404_238.tif (1, 1, 2304, 2304)

# %%
for i, layer in enumerate(model.layers):
  if "onv" in layer.name:
    print(i, layer.name, model.layers[i].get_weights()[0].shape)

weights, biases =  model.layers[4].get_weights()
fig1=plt.figure(figsize=(12, 12))


columns = 8 
rows = 8 
n_filters = columns*rows
for i in range(1, n_filters +1):
    f = weights[:, :, (i-1), 0]
    fig1 =plt.subplot(rows, columns, i)
    fig1.set_xticks([])  #Turn off axis
    fig1.set_yticks([])

    #plt.imshow(f[i%3, :, :], cmap='gray')
    plt.imshow(f[:, :], cmap='gray')
    #plt.imshow(f[2, :, :], cmap='gray') #Show only the filters from 0th channel (R)
    #ix += 1
plt.show()
# Out:
# 1 conv2d (3, 3, 3, 64)
# 4 conv2d_1 (3, 3, 64, 64)
# 8 conv2d_2 (3, 3, 64, 128)
# 11 conv2d_3 (3, 3, 128, 128)
# 15 conv2d_4 (3, 3, 128, 256)
# 18 conv2d_5 (3, 3, 256, 256)
# 22 conv2d_6 (3, 3, 256, 512)
# 25 conv2d_7 (3, 3, 512, 512)
# 29 conv2d_8 (3, 3, 512, 1024)
# 32 conv2d_9 (3, 3, 1024, 1024)
# 35 conv2d_transpose (2, 2, 512, 1024)
# 37 conv2d_10 (3, 3, 1024, 512)
# 40 conv2d_11 (3, 3, 512, 512)
# 43 conv2d_transpose_1 (2, 2, 256, 512)
# 45 conv2d_12 (3, 3, 512, 256)
# 48 conv2d_13 (3, 3, 256, 256)
# 51 conv2d_transpose_2 (2, 2, 128, 256)
# 53 conv2d_14 (3, 3, 256, 128)
# 56 conv2d_15 (3, 3, 128, 128)
# 59 conv2d_transpose_3 (2, 2, 64, 128)
# 61 conv2d_16 (3, 3, 128, 64)
# 64 conv2d_17 (3, 3, 64, 64)
# 67 conv2d_18 (1, 1, 64, 1)
